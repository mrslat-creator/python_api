# %% [markdown]
# # WeatherPy
#
# Data Analysis:
# -Cities with a high humidity and cloudiness had a lower wind speed than those with a lower humidity and cloudiness. It is as if the amount of clouds dictates the level of humidity  and windspeed.
# -A city's latitude dictates the their heat level or max temperature. I got this from the scatter plots, because I noted the way the latitude, temperature and cloudiness seemed to move in a certain way across the plot.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from scipy import stats

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []
country_codes =[]

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.00, size=1500)
lat_lngs = zip(lats, lngs)
city = citipy

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 597

# %%
print(cities)
# Out:
# ['albany', 'bambous virieux', 'tuktoyaktuk', 'mataura', 'la rioja', 'nanortalik', 'hobyo', 'taolanaro', 'namatanai', 'bethel', 'upernavik', 'constitucion', 'ribeira grande', 'corinth', 'bayan', 'srednekolymsk', 'rikitea', 'saint-pierre', 'auki', 'ushuaia', 'college', 'lasa', 'pingliang', 'marmaron', 'puerto ayora', 'miraflores', 'portland', 'lavrentiya', 'avarua', 'vaini', 'saldanha', 'young', 'shingu', 'qaanaaq', 'busselton', 'gewane', 'jalu', 'krasnaya polyana', 'hobart', 'ajaccio', 'okhotsk', 'airai', 'port alfred', 'clyde river', 'cururupu', 'butaritari', 'amuntai', 'tigil', 'victoria', 'starotimoshkino', 'ilulissat', 'baykit', 'punta arenas', 'saryshagan', 'alghero', 'malokakhovka', 'karauzyak', 'morondava', 'yarkovo', 'fortuna', 'coquimbo', 'carauari', 'antofagasta', 'sao filipe', 'leningradskiy', 'lolua', 'teahupoo', 'saint george', 'cabo san lucas', 'shimoda', 'plettenberg bay', 'cedar city', 'saleaula', 'lompoc', 'dmitriyevka', 'barrow', 'berezovyy', 'jamestown', 'ponta do sol', 'yerbogachen', 'puerto el triunfo', 'grand river south east', 'umzimvubu', 'dikson', 'hermanus', 'ancud', 'port blair', 'nikolskoye', 'tahoua', 'padang', 'bluff', 'chokurdakh', 'westport', 'kapaa', 'saskylakh', 'kyzyl-suu', 'georgetown', 'sompeta', 'belushya guba', 'torbay', 'hithadhoo', 'tuatapere', 'norman wells', 'san jeronimo', 'lorengau', 'nuuk', 'yellowknife', 'luocheng', 'paramonga', 'thompson', 'amapa', 'muli', 'provideniya', 'saint-philippe', 'galveston', 'pangnirtung', 'meyungs', 'shush', 'sidrolandia', 'tiksi', 'bredasdorp', 'port elizabeth', 'cherskiy', 'illoqqortoormiut', 'atikokan', 'constantine', 'east london', 'ikongo', 'port lincoln', 'havre-saint-pierre', 'jaisinghnagar', 'yanam', 'new norfolk', 'shashi', 'ketchikan', 'khorinsk', 'solovetskiy', 'ardmore', 'santa cruz de la palma', 'henties bay', 'gerash', 'faanui', 'castro', 'sinnamary', 'japura', 'biak', 'barma', 'carnarvon', 'maun', 'mizpe ramon', 'kuybyshevo', 'geraldton', 'hilo', 'hasaki', 'barawe', 'kaitangata', 'marcona', 'magrath', 'atka', 'flinders', 'pamanukan', 'arraial do cabo', 'esil', 'nizhneyansk', 'karachi', 'tabiauea', 'balimo', 'togur', 'nuqui', 'soyo', 'katsuura', 'saint-georges', 'faya', 'petropavlovsk-kamchatskiy', 'loa janan', 'mao', 'key west', 'khatanga', 'yanan', 'port hardy', 'half moon bay', 'atar', 'mahadday weyne', 'karatau', 'kruisfontein', 'talara', 'ambilobe', 'udachnyy', 'mutata', 'saint anthony', 'ribeirao preto', 'ibra', 'phonhong', 'kieta', 'pevek', 'general roca', 'tumannyy', 'bonavista', 'yulara', 'longyearbyen', 'sao joao da barra', 'tabuk', 'coahuayana', 'naryan-mar', 'tahe', 'fort nelson', 'luderitz', 'kavaratti', 'diamantino', 'barentsburg', 'skibbereen', 'maravatio', 'tawau', 'atuona', 'jega', 'avera', 'rafai', 'comodoro rivadavia', 'ambon', 'mys shmidta', 'road town', 'codrington', 'tsihombe', 'pacific grove', 'sitka', 'abu dhabi', 'bathsheba', 'sorvag', 'cape town', 'kushiro', 'mount isa', 'pemberton', 'souillac', 'gold coast', 'tasiilaq', 'filadelfia', 'pisco', 'tres arroyos', 'morehead', 'galgani', 'chuchkovo', 'beira', 'ignatovka', 'mar del plata', 'alberdi', 'hirara', 'evensk', 'taybad', 'talnakh', 'bengkulu', 'nhulunbuy', 'byron bay', 'nushki', 'kodiak', 'tautira', 'mezen', 'jamame', 'lebu', 'deputatskiy', 'paita', 'yeppoon', 'sorland', 'moree', 'whyalla', 'touros', 'weiser', 'kayan', 'the valley', 'krosno odrzanskie', 'banjar', 'lakatoro', 'el monte', 'camopi', 'san cristobal', 'rio grande', 'attawapiskat', 'chuy', 'san patricio', 'manaus', 'astipalaia', 'kavieng', 'vao', 'ulaanbaatar', 'praia', 'port dickson', 'pineville', 'sangmelima', 'amderma', 'cidreira', 'urengoy', 'tura', 'cockburn town', 'ucluelet', 'rakitovo', 'litoral del san juan', 'kununurra', 'natal', 'aklavik', 'chamba', 'muktagachha', 'severo-kurilsk', 'belaya gora', 'antalaha', 'korla', 'manono', 'nuevo progreso', 'iqaluit', 'zurrieq', 'marica', 'patiya', 'mindelo', 'grand gaube', 'charters towers', 'ardakan', 'chkalovskoye', 'pemangkat', 'palabuhanratu', 'barg ...

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?q="

# Data list of Cities
city_list = []
lat_list = []
lng_list = []
max_temp_list = []
humidity_list = []
cloudiness_list = []
windspeed_list = []
date = []
counter = 0
record_counter = 0
setcount = 1


for city in cities:
    counter += 1
    if (counter % 50 == 0):
        setcount += 1
        record_counter =0
        print(setcount)
        print(record_counter)
        print(counter)
    record_counter += 1
    print("processing record" + str(record_counter) +"of Set" + str(setcount) +"|" +city)
    try: 
        weather_response = requests.get(f"{url}{city}&appid={weather_api_key}").json()
        city_list.append(weather_response['name'])
        lat_list.append(weather_response['coord']['lat'])
        lng_list.append(weather_response['coord']['lon'])
        max_temp_list.append(weather_response['main']['temp_max'])
        humidity_list.append(weather_response['main']['humidity'])
        cloudiness_list.append(weather_response['clouds']['all'])
        windspeed_list.append(weather_response['wind']['speed'])
    except:
        print("City Not Found, Pass...:" + city)

        
print(len(weather_response))
# Out:
# processing record1of Set1|albany
# processing record2of Set1|bambous virieux
# processing record3of Set1|tuktoyaktuk
# processing record4of Set1|mataura
# processing record5of Set1|la rioja
# processing record6of Set1|nanortalik
# processing record7of Set1|hobyo
# processing record8of Set1|taolanaro
# City Not Found, Pass...:taolanaro
# processing record9of Set1|namatanai
# processing record10of Set1|bethel
# processing record11of Set1|upernavik
# processing record12of Set1|constitucion
# processing record13of Set1|ribeira grande
# processing record14of Set1|corinth
# processing record15of Set1|bayan
# processing record16of Set1|srednekolymsk
# processing record17of Set1|rikitea
# processing record18of Set1|saint-pierre
# processing record19of Set1|auki
# processing record20of Set1|ushuaia
# processing record21of Set1|college
# processing record22of Set1|lasa
# processing record23of Set1|pingliang
# processing record24of Set1|marmaron
# City Not Found, Pass...:marmaron
# processing record25of Set1|puerto ayora
# processing record26of Set1|miraflores
# processing record27of Set1|portland
# processing record28of Set1|lavrentiya
# processing record29of Set1|avarua
# processing record30of Set1|vaini
# processing record31of Set1|saldanha
# processing record32of Set1|young
# processing record33of Set1|shingu
# processing record34of Set1|qaanaaq
# processing record35of Set1|busselton
# processing record36of Set1|gewane
# processing record37of Set1|jalu
# processing record38of Set1|krasnaya polyana
# processing record39of Set1|hobart
# processing record40of Set1|ajaccio
# processing record41of Set1|okhotsk
# processing record42of Set1|airai
# processing record43of Set1|port alfred
# processing record44of Set1|clyde river
# processing record45of Set1|cururupu
# processing record46of Set1|butaritari
# processing record47of Set1|amuntai
# processing record48of Set1|tigil
# processing record49of Set1|victoria
# 2
# 0
# 50
# processing record1of Set2|starotimoshkino
# processing record2of Set2|ilulissat
# processing record3of Set2|baykit
# processing record4of Set2|punta arenas
# processing record5of Set2|saryshagan
# City Not Found, Pass...:saryshagan
# processing record6of Set2|alghero
# processing record7of Set2|malokakhovka
# processing record8of Set2|karauzyak
# City Not Found, Pass...:karauzyak
# processing record9of Set2|morondava
# processing record10of Set2|yarkovo
# processing record11of Set2|fortuna
# processing record12of Set2|coquimbo
# processing record13of Set2|carauari
# processing record14of Set2|antofagasta
# processing record15of Set2|sao filipe
# processing record16of Set2|leningradskiy
# processing record17of Set2|lolua
# City Not Found, Pass...:lolua
# processing record18of Set2|teahupoo
# processing record19of Set2|saint george
# processing record20of Set2|cabo san lucas
# processing record21of Set2|shimoda
# processing record22of Set2|plettenberg bay
# processing record23of Set2|cedar city
# processing record24of Set2|saleaula
# City Not Found, Pass...:saleaula
# processing record25of Set2|lompoc
# processing record26of Set2|dmitriyevka
# processing record27of Set2|barrow
# processing record28of Set2|berezovyy
# processing record29of Set2|jamestown
# processing record30of Set2|ponta do sol
# processing record31of Set2|yerbogachen
# processing record32of Set2|puerto el triunfo
# processing record33of Set2|grand river south east
# City Not Found, Pass...:grand river south east
# processing record34of Set2|umzimvubu
# City Not Found, Pass...:umzimvubu
# processing record35of Set2|dikson
# processing record36of Set2|hermanus
# processing record37of Set2|ancud
# processing record38of Set2|port blair
# processing record39of Set2|nikolskoye
# processing record40of Set2|tahoua
# processing record41of Set2|padang
# processing record42of Set2|bluff
# processing record43of Set2|chokurdakh
# processing record44of Set2|westport
# processing record45of Set2|kapaa
# processing record46of Set2|saskylakh
# processing record47of Set2|kyzyl-suu
# processing record48of Set2|georgetown
# processing record49of Set2|sompeta
# processing record50of Set2|belushya guba
# City Not Found, Pass...:belushya guba
# 3
# 0
# 100
# processing record1of Set3|torbay
# processing record2of Set3|hithadhoo
# processing record3of Set3|tuatapere
# processing record4of Set3|norman wells
# processing record5of Set3|san jeronimo
# processing record6of Set3|lorengau
# processing record7of Set3|nuuk
# processing record8of Set3|yellowknife
# processing record9of Set3|luocheng
# processing record10of Set3|paramonga
# processing record11of Set3|thompson
# processing record12of Set3|amapa
# processing record13of Set3|muli
# processing record14of Set3|provideniya
# processing record15of Set3|saint-philippe
# processing record16of Set3|galveston
# processing record17of Set3|pangnirtung
# processing record18of Set3|meyungs
# City Not Found, Pass...:meyungs
# processing record19of Set3|shush
# processing record20of Set3|sidrolandia
# processing record21of Set3|tiksi
# processing record22of Set3|bredasdorp
# processing record23of Set3|port elizabeth
# processing record24of Set3|cherskiy
# processing record25of Set3|illoqqortoormiut
# City Not Found, Pass...:illoqqortoormiut
# processing record26of Set3|atikokan
# processing record27of Set3|constantine
# processing record28of Set3|east london
# processing record29of Set3|ikongo
# processing record30of Set3|port lincoln
# processing record31of Set3|havre-saint-pierre
# processing record32of Set3|jaisinghnagar
# processing record33of Set3|yanam
# processing record34of Set3|new norfolk
# processing record35of Set3|shashi
# processing record36of Set3|ketchikan
# processing record37of Set3|khorinsk
# processing record38of Set3|solovetskiy
# City Not Found, Pass...:solovetskiy
# processing record39of Set3|ardmore
# processing record40of Set3|santa cruz de la palma
# processing record41of Set3|henties bay
# processing record42of Set3|gerash
# processing record43of Set3|faanui
# processing record44of Set3|castro
# processing record45of Set3|sinnamary
# processing record46of Set3|japura
# processing record47of Set3|biak
# processing record48of Set3|barma
# processing record49of Set3|carnarvon
# processing record50of Set3|maun
# 4
# 0
# 150
# processing record1of Set4|mizpe ramon
# City Not Found, Pass...:mizpe ramon
# processing record2of Set4|kuybyshevo
# processing record3of Set4|geraldton
# processing record4of Set4|hilo
# processing record5of Set4|hasaki
# processing record6of Set4|barawe
# City Not Found, Pass...:barawe
# processing record7of Set4|kaitangata
# processing record8of Set4|marcona
# City Not Found, Pass...:marcona
# processing record9of Set4|magrath
# processing record10of Set4|atka
# City Not Found, Pass...:atka
# processing record11of Set4|flinders
# processing record12of Set4|pamanukan
# processing record13of Set4|arraial do cabo
# processing record14of Set4|esil
# processing record15of Set4|nizhneyansk
# City Not Found, Pass...:nizhneyansk
# processing record16of Set4|karachi
# processing record17of Set4|tabiauea
# City Not Found, Pass...:tabiauea
# processing record18of Set4|balimo
# City Not Found, Pass...:balimo
# processing record19of Set4|togur
# processing record20of Set4|nuqui
# processing record21of Set4|soyo
# processing record22of Set4|katsuura
# processing record23of Set4|saint-georges
# processing record24of Set4|faya
# processing record25of Set4|petropavlovsk-kamchatskiy
# processing record26of Set4|loa janan
# processing record27of Set4|mao
# processing record28of Set4|key west
# processing record29of Set4|khatanga
# processing record30of Set4|yanan
# City Not Found, Pass...:yanan
# processing record31of Set4|port hardy
# processing record32of Set4|half moon bay
# processing record33of Set4|atar
# processing record34of Set4|mahadday weyne
# City Not Found, Pass...:mahadday weyne
# processing record35of Set4|karatau
# processing record36of Set4|kruisfontein
# processing record37of Set4|talara
# processing record38of Set4|ambilobe
# processing record39of Set4|udachnyy
# processing record40of Set4|mutata
# processing record41of Set4|saint anthony
# processing record42of Set4|ribeirao preto
# processing record43of Set4|ibra
# processing record44of Set4|phonhong
# processing record45of Set4|kieta
# processing record46of Set4|pevek
# processing record47of Set4|general roca
# processing record48of Set4|tumannyy
# City Not Found, Pass...:tumannyy
# processing record49of Set4|bonavista
# processing record50of Set4|yulara
# 5
# 0
# 200
# processing record1of Set5|longyearbyen
# processing record2of Set5|sao joao da barra
# processing record3of Set5|tabuk
# processing record4of Set5|coahuayana
# processing record5of Set5|naryan-mar
# processing record6of Set5|tahe
# processing record7of Set5|fort nelson
# processing record8of Set5|luderitz
# processing record9of Set5|kavaratti
# processing record10of Set5|diamantino
# processing record11of Set5|barentsburg
# City Not Found, Pass...:barentsburg
# processing record12of Set5|skibbereen
# processing record13of Set5|maravatio
# processing record14of Set5|tawau
# processing record15of Set5|atuona
# processing record16of Set5|jega
# processing record17of Set5|avera
# processing record18of Set5|rafai
# processing record19of Set5|comodoro rivadavia
# processing record20of Set5|ambon
# processing record21of Set5|mys shmidta
# City Not Found, Pass...:mys shmidta
# processing record22of Set5|road town
# processing record23of Set5|codrington
# processing record24of Set5|tsihombe
# City Not Found, Pass...:tsihombe
# processing record25of Set5|pacific grove
# processing record26of Set5|sitka
# processing record27of Set5|abu dhabi
# processing record28of Set5|bathsheba
# processing record29of Set5|sorvag
# City Not Found, Pass...:sorvag
# processing record30of Set5|cape town
# processing record31of Set5|kushiro
# processing record32of Set5|mount isa
# processing record33of Set5|pemberton
# processing record34of Set5|souillac
# processing record35of Set5|gold coast
# processing record36of Set5|tasiilaq
# processing record37of Set5|filadelfia
# processing record38of Set5|pisco
# processing record39of Set5|tres arroyos
# processing record40of Set5|morehead
# processing record41of Set5|galgani
# City Not Found, Pass...:galgani
# processing record42of Set5|chuchkovo
# processing record43of Set5|beira
# processing record44of Set5|ignatovka
# processing record45of Set5|mar del plata
# processing record46of Set5|alberdi
# processing record47of Set5|hirara
# processing record48of Set5|evensk
# processing record49of Set5|taybad
# processing record50of Set5|talnakh
# 6
# 0
# 250
# processing record1of Set6|bengkulu
# processing record2of Set6|nhulunbuy
# processing record3of Set6|byron bay
# processing record4of Set6|nushki
# processing record5of Set6|kodiak
# processing record6of Set6|tautira
# processing record7of Set6|mezen
# processing record8of Set6|jamame
# processing record9of Set6|lebu
# processing record10of Set6|deputatskiy
# processing record11of Set6|paita
# processing record12of Set6|yeppoon
# processing record13of Set6|sorland
# processing record14of Set6|moree
# processing record15of Set6|whyalla
# processing record16of Set6|touros
# processing record17of Set6|weiser
# processing record18of Set6|kayan
# processing record19of Set6|the valley
# processing record20of Set6|krosno odrzanskie
# processing record21of Set6|banjar
# processing record22of Set6|lakatoro
# processing record23of Set6|el monte
# processing record24of Set6|camopi
# processing record25of Set6|san cristobal
# processing record26of Set6|rio grande
# processing record27of Set6|attawapiskat
# City Not Found, Pass...:attawapiskat
# processing record28of Set6|chuy
# processing record29of Set6|san patricio
# processing record30of Set6|manaus
# processing record31of Set6|astipalaia
# City Not Found, Pass...:astipalaia
# processing record32of Set6|kavieng
# processing record33of Set6|vao
# processing record34of Set6|ulaanbaatar
# processing record35of Set6|praia
# processing record36of Set6|port dickson
# processing record37of Set6|pineville
# processing record38of Set6|sangmelima
# processing record39of Set6|amderma
# City Not Found, Pass...:amderma
# processing record40of Set6|cidreira
# processing record41of Set6|urengoy
# processing record42of Set6|tura
# processing record43of Set6|cockburn town
# processing record44of Set6|ucluelet
# processing record45of Set6|rakitovo
# processing record46of Set6|litoral del san juan
# City Not Found, Pass...:litoral del san juan
# processing record47of Set6|kununurra
# processing record48of Set6|natal
# processing record49of Set6|aklavik
# processing record50of Set6|chamba
# 7
# 0
# 300
# processing record1of Set7|muktagachha
# City Not Found, Pass...:muktagachha
# processing record2of Set7|severo-kurilsk
# processing record3of Set7|belaya gora
# processing record4of Set7|antalaha
# processing record5of Set7|korla
# processing record6of Set7|manono
# processing record7of Set7|nuevo progreso
# processing record8of Set7|iqaluit
# processing record9of Set7|zurrieq
# processing record10of Set7|marica
# processing record11of Set7|patiya
# processing record12of Set7|mindelo
# processing record13of Set7|grand gaube
# processing record14of Set7|charters towers
# processing record15of Set7|ardakan
# processing record16of Set7|chkalovskoye
# processing record17of Set7|pemangkat
# processing record18of Set7|palabuhanratu
# City Not Found, Pass...:palabuhanratu
# processing record19of Set7|bargal
# City Not Found, Pass...:bargal
# processing record20of Set7|quatre cocos
# processing record21of Set7|caohai
# processing record22of Set7|hay river
# processing record23of Set7|paidha
# processing record24of Set7|kargasok
# processing record25of Set7|tessalit
# processing record26of Set7|zapolyarnyy
# processing record27of Set7|biltine
# processing record28of Set7|hamilton
# processing record29of Set7|elizabeth city
# processing record30of Set7|mayumba
# processing record31of Set7|laborie
# processing record32of Set7|alexandria
# processing record33of Set7|bandrele
# processing record34of Set7|olga
# processing record35of Set7|ulaangom
# processing record36of Set7|neryungri
# processing record37of Set7|sola
# processing record38of Set7|hinton
# processing record39of Set7|pusad
# processing record40of Set7|vaitupu
# City Not Found, Pass...:vaitupu
# processing record41of Set7|pilar
# processing record42of Set7|fairview
# processing record43of Set7|qaqortoq
# processing record44of Set7|kalmunai
# processing record45of Set7|kahului
# processing record46of Set7|karratha
# processing record47of Set7|we
# City Not Found, Pass...:we
# processing record48of Set7|entebbe
# processing record49of Set7|robertson
# processing record50of Set7|sembe
# 8
# 0
# 350
# processing record1of Set8|cruzeiro do sul
# processing record2of Set8|paranapanema
# processing record3of Set8|lodwar
# processing record4of Set8|margate
# processing record5of Set8|bay roberts
# processing record6of Set8|kars
# processing record7of Set8|morden
# processing record8of Set8|sault sainte marie
# processing record9of Set8|ixtapa
# processing record10of Set8|verkhnevilyuysk
# processing record11of Set8|mitzic
# processing record12of Set8|southbridge
# processing record13of Set8|shangrao
# processing record14of Set8|samusu
# City Not Found, Pass...:samusu
# processing record15of Set8|providencia
# processing record16of Set8|falealupo
# City Not Found, Pass...:falealupo
# processing record17of Set8|hofn
# processing record18of Set8|marawi
# processing record19of Set8|turukhansk
# processing record20of Set8|dao
# processing record21of Set8|gornopravdinsk
# processing record22of Set8|didwana
# processing record23of Set8|muhoroni
# processing record24of Set8|fredericksburg
# processing record25of Set8|fairbanks
# processing record26of Set8|nouadhibou
# processing record27of Set8|port-gentil
# processing record28of Set8|oudtshoorn
# processing record29of Set8|salalah
# processing record30of Set8|high level
# processing record31of Set8|pachmarhi
# processing record32of Set8|fort-shevchenko
# processing record33of Set8|opunake
# processing record34of Set8|hudson bay
# processing record35of Set8|klaksvik
# processing record36of Set8|puerto del rosario
# processing record37of Set8|champerico
# processing record38of Set8|virginia beach
# processing record39of Set8|kysyl-syr
# processing record40of Set8|nexo
# processing record41of Set8|huarmey
# processing record42of Set8|bethanien
# processing record43of Set8|zelenogradsk
# processing record44of Set8|maceio
# processing record45of Set8|ornskoldsvik
# processing record46of Set8|yeovil
# processing record47of Set8|staryy biser
# City Not Found, Pass...:staryy biser
# processing record48of Set8|cap malheureux
# processing record49of Set8|guilin
# processing record50of Set8|artyk
# City Not Found, Pass...:artyk
# 9
# 0
# 400
# processing record1of Set9|vanavara
# processing record2of Set9|mitsamiouli
# processing record3of Set9|noumea
# processing record4of Set9|amga
# processing record5of Set9|ritchie
# processing record6of Set9|nadym
# processing record7of Set9|pervomayskoye
# processing record8of Set9|orlik
# processing record9of Set9|sentyabrskiy
# City Not Found, Pass...:sentyabrskiy
# processing record10of Set9|gumla
# processing record11of Set9|borovoy
# processing record12of Set9|inhapim
# processing record13of Set9|ilo
# processing record14of Set9|jaciara
# processing record15of Set9|dedham
# processing record16of Set9|takoradi
# processing record17of Set9|kulu
# processing record18of Set9|grand centre
# City Not Found, Pass...:grand centre
# processing record19of Set9|kashi
# processing record20of Set9|forbes
# processing record21of Set9|grimstad
# processing record22of Set9|rio branco do sul
# processing record23of Set9|sur
# processing record24of Set9|mount gambier
# processing record25of Set9|jardim do serido
# processing record26of Set9|glendive
# processing record27of Set9|lostice
# processing record28of Set9|karaul
# City Not Found, Pass...:karaul
# processing record29of Set9|brae
# processing record30of Set9|batagay
# processing record31of Set9|narsaq
# processing record32of Set9|borama
# City Not Found, Pass...:borama
# processing record33of Set9|bara
# processing record34of Set9|omboue
# processing record35of Set9|nanding
# processing record36of Set9|lichuan
# processing record37of Set9|salamanca
# processing record38of Set9|tilichiki
# processing record39of Set9|payo
# processing record40of Set9|tual
# processing record41of Set9|kemin
# processing record42of Set9|bristol
# processing record43of Set9|hutchinson
# processing record44of Set9|san vicente
# processing record45of Set9|manali
# processing record46of Set9|dezhou
# processing record47of Set9|luwuk
# processing record48of Set9|praia da vitoria
# processing record49of Set9|armacao dos buzios
# City Not Found, Pass...:armacao dos buzios
# processing record50of Set9|tshikapa
# 10
# 0
# 450
# processing record1of Set10|tateyama
# processing record2of Set10|beringovskiy
# processing record3of Set10|salobrena
# processing record4of Set10|ariquemes
# processing record5of Set10|smithers
# processing record6of Set10|areia branca
# processing record7of Set10|ijaki
# City Not Found, Pass...:ijaki
# processing record8of Set10|yantal
# processing record9of Set10|mahebourg
# processing record10of Set10|luganville
# processing record11of Set10|romanshorn
# processing record12of Set10|winsum
# processing record13of Set10|gonen
# processing record14of Set10|tashtyp
# processing record15of Set10|ulluaya
# processing record16of Set10|ulladulla
# processing record17of Set10|hervey bay
# processing record18of Set10|coria
# processing record19of Set10|maridi
# processing record20of Set10|warqla
# City Not Found, Pass...:warqla
# processing record21of Set10|muisne
# processing record22of Set10|honiara
# processing record23of Set10|nemuro
# processing record24of Set10|coihaique
# processing record25of Set10|harper
# processing record26of Set10|husavik
# processing record27of Set10|medicine hat
# processing record28of Set10|olafsvik
# processing record29of Set10|ihosy
# processing record30of Set10|jyvaskyla
# processing record31of Set10|lagoa
# processing record32of Set10|goderich
# processing record33of Set10|kamaishi
# processing record34of Set10|iskateley
# processing record35of Set10|maragogi
# processing record36of Set10|novaya ladoga
# processing record37of Set10|benghazi
# processing record38of Set10|qufu
# processing record39of Set10|berlevag
# processing record40of Set10|leh
# processing record41of Set10|kalispell
# processing record42of Set10|antsohihy
# processing record43of Set10|barcelos
# processing record44of Set10|burnie
# processing record45of Set10|taltal
# processing record46of Set10|saint-augustin
# processing record47of Set10|choya
# processing record48of Set10|mudigere
# processing record49of Set10|dunedin
# processing record50of Set10|cantanhede
# 11
# 0
# 500
# processing record1of Set11|alofi
# processing record2of Set11|thongwa
# processing record3of Set11|dangriga
# processing record4of Set11|kamenskoye
# City Not Found, Pass...:kamenskoye
# processing record5of Set11|vila
# processing record6of Set11|ukiah
# processing record7of Set11|kasese
# processing record8of Set11|baijiantan
# processing record9of Set11|dicabisagan
# processing record10of Set11|nizhniy tsasuchey
# processing record11of Set11|ciudad bolivar
# processing record12of Set11|naftah
# City Not Found, Pass...:naftah
# processing record13of Set11|eureka
# processing record14of Set11|chitral
# processing record15of Set11|gualaquiza
# processing record16of Set11|kasongo-lunda
# processing record17of Set11|murgab
# processing record18of Set11|hualmay
# processing record19of Set11|tabialan
# City Not Found, Pass...:tabialan
# processing record20of Set11|kaniama
# processing record21of Set11|barbar
# City Not Found, Pass...:barbar
# processing record22of Set11|camacha
# processing record23of Set11|shaunavon
# processing record24of Set11|hami
# processing record25of Set11|shetpe
# processing record26of Set11|yarada
# processing record27of Set11|bulgan
# processing record28of Set11|tocoa
# processing record29of Set11|jiroft
# City Not Found, Pass...:jiroft
# processing record30of Set11|novoagansk
# processing record31of Set11|pringsewu
# processing record32of Set11|nioro
# processing record33of Set11|vostok
# processing record34of Set11|te anau
# processing record35of Set11|kidal
# processing record36of Set11|vestmannaeyjar
# processing record37of Set11|pula
# processing record38of Set11|sydney
# processing record39of Set11|nalut
# processing record40of Set11|tutoia
# processing record41of Set11|urdzhar
# City Not Found, Pass...:urdzhar
# processing record42of Set11|keti bandar
# processing record43of Set11|bambanglipuro
# processing record44of Set11|paradwip
# City Not Found, Pass...:paradwip
# processing record45of Set11|ecoporanga
# processing record46of Set11|amahai
# processing record47of Set11|mora
# processing record48of Set11|torit
# processing record49of Set11|karabulak
# processing record50of Set11|kasrawad
# 12
# 0
# 550
# processing record1of Set12|chute-aux-outardes
# processing record2of Set12|innisfail
# processing record3of Set12|stokmarknes
# processing record4of Set12|butembo
# processing record5of Set12|birjand
# processing record6of Set12|yelan
# processing record7of Set12|raudeberg
# processing record8of Set12|linapacan
# City Not Found, Pass...:linapacan
# processing record9of Set12|colchester
# processing record10of Set12|terney
# processing record11of Set12|laguna
# processing record12of Set12|wellington
# processing record13of Set12|havelock
# processing record14of Set12|mikhaylovka
# processing record15of Set12|dongsheng
# processing record16of Set12|santiago del estero
# processing record17of Set12|parabel
# processing record18of Set12|guerrero negro
# processing record19of Set12|muros
# processing record20of Set12|shache
# processing record21of Set12|khandyga
# processing record22of Set12|los llanos de aridane
# processing record23of Set12|alotau
# City Not Found, Pass...:alotau
# processing record24of Set12|chino valley
# processing record25of Set12|melfort
# processing record26of Set12|voh
# processing record27of Set12|odweyne
# processing record28of Set12|calama
# processing record29of Set12|tawkar
# City Not Found, Pass...:tawkar
# processing record30of Set12|waitati
# processing record31of Set12|abha
# processing record32of Set12|oranjemund
# processing record33of Set12|komsomolskiy
# processing record34of Set12|matara
# processing record35of Set12|solnechnyy
# processing record36of Set12|moron
# processing record37of Set12|oistins
# processing record38of Set12|santa maria del oro
# processing record39of Set12|sisimiut
# processing record40of Set12|tancheng
# processing record41of Set12|luan
# processing record42of Set12|homer
# processing record43of Set12|tarakan
# processing record44of Set12|russell
# processing record45of Set12|kamina
# processing record46of Set12|praya
# processing record47of Set12|vestbygda
# City Not Found, Pass...:vestbygda
# processing record48of Set12|garden city
# 13

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Creating a DataFrame
city_data_df = pd.DataFrame({"City":city_list,
                         "Lat":lat_list,
                         "Lng":lng_list,
                         "Max Temp":max_temp_list,
                         "Humidity":humidity_list,
                         "Cloudiness":cloudiness_list,
                         "Wind Speed":windspeed_list,
                            })

pd.DataFrame.to_csv(city_data_df, 'city_data.csv')

city_data_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Albany  42.6001  -73.9662    296.51        89         100
# 1  Bambous Virieux -20.3428   57.7575    293.27        62          79
# 2      Tuktoyaktuk  69.4541 -133.0374    275.09        84           5
# 3          Mataura -46.1927  168.8643    282.86        61          20
# 4         La Rioja  42.2500   -2.5000    283.73        95         100
#
#    Wind Speed
# 0        1.05
# 1        7.65
# 2        8.49
# 3        1.23
# 4        0.64

# %%
weather_dict = {"City":city_list,
                         "Lat":lat_list,
                         "Lng":lng_list,
                         "Max Temp":max_temp_list,
                         "Humidity":humidity_list,
                         "Cloudiness":cloudiness_list,
                         "Wind Speed":windspeed_list,
}
weather_dict
# Out:
# {'City': ['Albany',
#   'Bambous Virieux',
#   'Tuktoyaktuk',
#   'Mataura',
#   'La Rioja',
#   'Nanortalik',
#   'Hobyo',
#   'Namatanai',
#   'Bethel',
#   'Upernavik',
#   'Constitución',
#   'Ribeira Grande',
#   'Corinth',
#   'Bayan',
#   'Srednekolymsk',
#   'Rikitea',
#   'Saint-Pierre',
#   'Auki',
#   'Ushuaia',
#   'College',
#   'Laas',
#   'Pingliang',
#   'Puerto Ayora',
#   'Miraflores',
#   'Portland',
#   'Lavrentiya',
#   'Avarua',
#   'Vaini',
#   'Saldanha',
#   'Young',
#   'Shingū',
#   'Qaanaaq',
#   'Busselton',
#   'Gewanē',
#   'Jalu',
#   'Krasnaya Polyana',
#   'Hobart',
#   "Arrondissement d'Ajaccio",
#   'Okhotsk',
#   'Airai',
#   'Port Alfred',
#   'Clyde River',
#   'Cururupu',
#   'Butaritari',
#   'Amuntai',
#   "Tigil'",
#   'Hong Kong',
#   'Starotimoshkino',
#   'Ilulissat',
#   'Baykit',
#   'Punta Arenas',
#   'Alghero',
#   'Malokakhovka',
#   'Morondava',
#   'Yarkovo',
#   'Fortuna',
#   'Coquimbo',
#   'Carauari',
#   'Antofagasta',
#   'São Filipe',
#   'Leningradskiy',
#   'Teahupoo',
#   'Saint George',
#   'Cabo San Lucas',
#   'Shimoda',
#   'Plettenberg Bay',
#   'Cedar City',
#   'Lompoc',
#   'Dmitriyevka',
#   'Barrow',
#   'Berezovyy',
#   'Jamestown',
#   'Ponta do Sol',
#   'Yerbogachën',
#   'Puerto El Triunfo',
#   'Dikson',
#   'Hermanus',
#   'Ancud',
#   'Port Blair',
#   'Nikolskoye',
#   'Tahoua',
#   'Padang',
#   'Bluff',
#   'Chokurdakh',
#   'Westport',
#   'Kapaa',
#   'Saskylakh',
#   'Kyzyl-Suu',
#   'George Town',
#   'Sompeta',
#   'Torbay',
#   'Hithadhoo',
#   'Tuatapere',
#   'Norman Wells',
#   'San Jerónimo',
#   'Lorengau',
#   'Nuuk',
#   'Yellowknife',
#   'Luocheng',
#   'Paramonga',
#   'Thompson',
#   'Amapá',
#   'Muli',
#   'Provideniya',
#   'Saint-Philippe',
#   'Galveston',
#   'Pangnirtung',
#   'Susa',
#   'Sidrolândia',
#   'Tiksi',
#   'Bredasdorp',
#   'Port Elizabeth',
#   'Cherskiy',
#   'Atikokan',
#   'Constantine',
#   'East London',
#   'Ikongo',
#   'Port Lincoln',
#   'Havre-St-Pierre',
#   'Jaisinghnagar',
#   'Yanam',
#   'New Norfolk',
#   'Shashi',
#   'Ketchikan',
#   'Khorinsk',
#   'Ardmore',
#   'Santa Cruz de La Palma',
#   'Henties Bay',
#   'Gerāsh',
#   'Faanui',
#   'Castro',
#   'Sinnamary',
#   'Japura',
#   'Biak',
#   'Barma',
#   'Carnarvon',
#   'Maun',
#   'Kuybyshevo',
#   'Geraldton',
#   'Hilo',
#   'Hasaki',
#   'Kaitangata',
#   'Magrath',
#   'Flinders',
#   'Pamanukan',
#   'Arraial do Cabo',
#   'Esil',
#   'Karachi',
#   'Togur',
#   'Nuquí',
#   'Soyo',
#   'Katsuura',
#   "St. George's",
#   'Faya',
#   'Petropavlovsk-Kamchatskiy',
#   'Loa Janan',
#   'Mahon',
#   'Key West',
#   'Khatanga',
#   'Port Hardy',
#   'Half Moon Bay',
#   'Atar',
#   'Karatau',
#   'Kruisfontein',
#   'Talara',
#   'Ambilobe',
#   'Udachny',
#   'Mutatá',
#   'Saint Anthony',
#   'Ribeirão Preto',
#   'Ibrā’',
#   'Phonhong',
#   'Kieta',
#   'Pevek',
#   'General Roca',
#   'Bonavista',
#   'Yulara',
#   'Longyearbyen',
#   'São João da Barra',
#   'Tabuk',
#   'Coahuayana Viejo',
#   'Naryan-Mar',
#   'Tahe',
#   'Fort Nelson',
#   'Lüderitz',
#   'Kavaratti',
#   'Diamantino',
#   'Skibbereen',
#   'Maravatío de Ocampo',
#   'Tawao',
#   'Atuona',
#   'Jega',
#   'Avera',
#   'Rafai',
#   'Comodoro Rivadavia',
#   'Ambon City',
#   'Road Town',
#   'Codrington',
#   'Pacific Grove',
#   'Sitka',
#   'Abu Dhabi',
#   'Bathsheba',
#   'Cape Town',
#   'Kushiro',
#   'Mount Isa',
#   'Pemberton',
#   'Souillac',
#   'Gold Coast',
#   'Tasiilaq',
#   'Philadelphia',
#   'Pisco',
#   'Tres Arroyos',
#   'Morehead',
#   'Chuchkovo',
#   'Beira',
#   'Ignatovka',
#   'Mar del Plata',
#   'Alberdi',
#   'Hirara',
#   'Evensk',
#   'Tāybād',
#   'Talnakh',
#   'Bengkulu',
#   'Nhulunbuy',
#   'Byron Bay',
#   'Nushki',
#   'Saint Paul Harbor',
#   'Tautira',
#   "Mezen'",
#   'Jamame',
#   'Lebu',
#   'Deputatsky',
#   'Paita',
#   'Yeppoon',
#   'Sørland',
#   'Moree',
#   'Whyalla',
#   'Touros',
#   'Weiser',
#   'Kayan',
#   'The Valley',
#   'Krosno Odrzańskie',
#   'Banjar',
#   'Lakatoro',
#   'El Monte',
#   'Camopi',
#   'San Cristobal',
#   'Rio Grande',
#   'Chui',
#   'San Patricio',
#   'Manaus',
#   'Kavieng',
#   'Vao',
#   'Ulaanbaatar',
#   'Praia',
#   'Port Dickson',
#   'Pineville',
#   'Sangmélima',
#   'Cidreira',
#   'Urengoy',
#   'Tura',
#   'Cockburn Town',
#   'Ucluelet',
#   'Rakitovo',
#   'Kununurra',
#   'Natal',
#   'Aklavik',
#   'Chamba',
#   "Severo-Kuril'sk",
#   'Belaya Gora',
#   'Antalaha',
#   'Korla',
#   'Manono',
#   'Nuevo Progreso',
#   'Iqaluit',
#   'Żurrieq',
#   'Maricá',
#   'Patiya',
#   'Mindelo',
#   'Grand Gaube',
#   'Charters Towers',
#   'Ardakān',
#   'Chkalovskoye',
#   'Pemangkat',
#   'Quatre Cocos',
#   'Caohai',
#   'Hay River',
#   'Paidha',
#   'Kargasok',
#   'Tessalit',
#   'Zapolyarnyy',
#   'Biltine',
#   'Hamilton',
#   'Elizabeth City',
#   'Mayumba',
#   'Laborie',
#   'Alexandria',
#   'Bandrele',
#   "Ol'ga",
#   'Ulaangom',
#   'Neryungri',
#   'Sola',
#   'Hinton',
#   'Pusad',
#   'Pilar',
#   'Fairview',
#   'Qaqortoq',
#   'Kalmunai',
#   'Kahului',
#   'Karratha',
#   'Entebbe',
#   'Robertson',
#   'Sémbé',
#   'Cruzeiro do Sul',
#   'Paranapanema',
#   'Lodwar',
#   'Margate',
#   'Bay Roberts',
#   'Kars',
#   'Morden',
#   'Sault Ste. Marie',
#   'Ixtapa',
#   'Verkhnevilyuysk',
#   'Mitzic',
#   'Southbridge',
#   'Shangrao',
#   'La Providencia',
#   'Hofn',
#   'Marawi',
#   'Turukhansk',
#   'Dao',
#   'Gornopravdinsk',
#   'Dīdwāna',
#   'Muhoroni',
#   'Fredericksburg',
#   'Fairbanks',
#   'Nouadhibou',
#   'Port-Gentil',
#   'Oudtshoorn',
#   'Salalah',
#   'High Level',
#   'Pachmarhi',
#   'Fort-Shevchenko',
#   'Opunake',
#   'Hudson Bay',
#   'Klaksvík',
#   'Puerto del Rosario',
#   'Champerico',
#   'Virginia Beach',
#   'Kysyl-Syr',
#   'Nexø',
#   'Huarmey',
#   'Bethanien',
#   'Zelenogradsk',
#   'Maceió',
#   'Örnsköldsvik',
#   'Yeovil',
#   'Cap Malheureux',
#   'Guilin',
#   'Vanavara',
#   'Mitsamiouli',
#   'Noumea',
#   'Amga',
#   'Ritchie',
#   'Nadym',
#   'Pervomayskoye',
#   'Orlik',
#   'Gumlā',
#   'Borovoy',
#   'Inhapim',
#   'Ilo',
#   'Jaciara',
#   'Dedham',
#   'Takoradze',
#   'Kulu',
#   'Kashgar',
#   'Forbes',
#   'Grimstad',
#   'Rio Branco do Sul',
#   'Sur',
#   'Mount Gambier',
#   'Jardim do Seridó',
#   'Glendive',
#   'Loštice',
#   'Brae',
#   'Batagay',
#   'Narsaq',
#   'Bara',
#   'Omboué',
#   'Nanding',
#   'Lichuan',
#   'Salamanca',
#   'Tilichiki',
#   'Payo',
#   'Tual',
#   'Kemin',
#   'Bristol',
#   'Hutchinson',
#   'San Vicente',
#   'Manali',
#   'Dezhou',
#   'Luwuk',
#   'Praia da Vitória',
#   'Tshikapa',
#   'Tateyama',
#   'Beringovskiy',
#   'Salobreña',
#   'Ariquemes',
#   'Smithers',
#   'Areia Branca',
#   "Yantal'",
#   'Mahébourg',
#   'Luganville',
#   'Romanshorn',
#   'Winsum',
#   'Gönen',
#   'Tashtyp',
#   'Ulluaya',
#   'Ulladulla',
#   'Hervey Bay',
#   'Coria',
#   'Maridi',
#   'Muisne',
#   'Honiara',
#   'Nemuro',
#   'Coyhaique',
#   'Harper',
#   'Husavik',
#   'Medicine Hat',
#   'Olafsvik',
#   'Ihosy',
#   'Jyvaskyla',
#   'Lagoa',
#   'Goderich',
#   'Kamaishi',
#   'Iskateley',
#   'Maragogi',
#   'Novaya Ladoga',
#   'Benghazi',
#   'Qufu',
#   'Berlevåg',
#   'Leh',
#   'Kalispell',
#   'Antsohihy',
#   'Barcelos',
#   'Burnie',
#   'Taltal',
#   'Saint-Augustin',
#   'Choya',
#   'Mudgere',
#   'Dunedin',
#   'Cantanhede',
#   'Alofi',
#   'Thongwa',
#   'Stann Creek Town',
#   'Vila',
#   'Ukiah',
#   'Kasese',
#   'Baijiantan',
#   'Dicabisagan',
#   'Nizhniy Tsasuchey',
#   'Ciudad Bolivar',
#   'Eureka',
#   'Chitral',
#   'Gualaquiza',
#   'Kasongo-Lunda',
#   'Murgab',
#   'Hualmay',
#   'Kaniama',
#   'Camacha',
#   'Shaunavon',
#   'Kumul',
#   'Shetpe',
#   'Yārāda',
#   'Bulgan',
#   'Tocoa',
#   'Novoagansk',
#   'Pringsewu',
#   'Nioro',
#   'Vostok',
#   'Te Anau',
#   'Kidal',
#   'Vestmannaeyjar',
#   'Pula',
#   'Sydney',
#   'Nālūt',
#   'Tutóia',
#   'Keti Bandar',
#   'Bambanglipuro',
#   'Ecoporanga',
#   'Amahai',
#   'Mora',
#   'Torit',
#   'Karabulak',
#   'Kasrāwad',
#   'Chute-aux-Outardes',
#   'Innisfail',
#   'Stokmarknes',
#   'Butembo',
#   'Birjand',
#   "Yelan'",
#   'Raudeberg',
#   'Colchester',
#   'Terney',
#   'Laguna',
#   'Wellington',
#   'Havelock',
#   'Mikhaylovka',
#   'Dongsheng',
#   'Santiago del Estero',
#   "Parabel'",
#   'Guerrero Negro',
#   'Muros',
#   'Shache',
#   'Khandyga',
#   'Los Llanos de Aridane',
#   'Chino Valley',
#   'Melfort',
#   'Voh',
#   'Oodweyne',
#   'Calama',
#   'Waitati',
#   'Abhā',
#   'Oranjemund',
#   'Yangi Marg`ilon',
#   'Matara',
#   'Solnechnyy',
#   'Morón',
#   'Oistins',
#   'Santa María del Oro',
#   'Sisimiut',
#   'Tancheng',
#   'Luan',
#   'Homer',
#   'Tarakan',
#   'Russell',
#   'Kamina',
#   'Praia',
#   'Garden City'],
#  'Lat': [42.6001,
#   -20.3428,
#   69.4541,
#   -46.1927,
#   42.25,
#   60.1432,
#   5.3505,
#   -3.6667,
#   41.3712,
#   72.7868,
#   -35.3333,
#   38.5167,
#   37.9407,
#   46.0833,
#   67.45,
#   -23.1203,
#   -21.3393,
#   -8.7676,
#   -54.8,
#   64.8569,
#   46.6166,
#   35.5392,
#   -0.7393,
#   19.2167,
#   45.5234,
#   65.5833,
#   -21.2078,
#   -21.2,
#   -33.0117,
#   -32.6833,
#   33.7333,
#   77.484,
#   -33.65,
#   10.1664,
#   29.0331,
#   56.242,
#   -42.8794,
#   42,
#   59.3833,
#   -8.9266,
#   -33.5906,
#   70.4692,
#   -1.8283,
#   3.0707,
#   -2.4177,
#   57.8,
#   22.2855,
#   53.7191,
#   69.2167,
#   61.67,
#   -53.15,
#   40.5589,
#   46.7814,
#   -20.2833,
#   57.4028,
#   40.5982,
#   -29.9533,
#   -4.8828,
#   -23.65,
#   14.8961,
#   69.3833,
#   -17.8333,
#   37.1041,
#   22.8909,
#   34.6667,
#   -34.0527,
#   37.6775,
#   34.6391,
#   54.75,
#   71.2906,
#   51.6667,
#   42.097,
#   32.6667,
#   61.2767,
#   13.2833,
#   73.5069,
#   -34.4187,
#   -41.8697,
#   11.6667,
#   59.7035,
#   14.8888,
#   -0.9492,
#   -46.6,
#   70.6333,
#   41.1415,
#   22.0752,
#   71.9167,
#   42.3414,
#   5.4112,
#   18.9333,
#   47.6666,
#   -0.6,
#   -46.1333,
#   65.282,
#   -11.9472,
#   -2.0226,
#   64.1835,
#   62.456,
#   29.3848,
#   -10.6667,
#   55.7435,
#   1,
#   2.9167,
#   64.3833,
#   -21.3585,
#   29.3669,
#   66.1451,
#   32.1942,
#   -20.9319,
#   71.6872,
#   -34.5322,
#   -33.918,
#   68.75,
#   48.7555,
#   36.365,
#   -33.0153,
#   -21.8833,
#   -34.7333,
#   50.2334,
#   23.7,
#   16.7333,
#   -42.7826,
#   30.3072,
#   55.3422,
#   52.1657,
#   34.1743,
#   28.6835,
#   -22.116,
#   27.6652,
#   -16.4833,
#   -24.7911,
#   5.3833,
#   -0.3167,
#   -0.9131,
#   8.35,
#   -24.8667,
#   -19.9833,
#   47.8123,
#   -28.7667,
#   19.7297,
#   35.7333,
#   -46.2817,
#   49.4167,
#   -34.5833,
#   -6.2842,
#   -22.9661,
#   51.9556,
#   24.9056,
#   58.3631,
#   5.7125,
#   -6.1349,
#   35.1333,
#   12.0564,
#   18.3851,
#   53.0452,
#   -0.583,
#   39.8885,
#   24.5557,
#   71.9667,
#   50.6996,
#   37.4636,
#   20.5169,
#   43.1667,
#   -34.0033,
#   -4.5772,
#   -13.2,
#   66.4167,
#   7.2441,
#   45.0205,
#   -21.1775,
#   22.6906,
#   18.5007,
#   -6.2167,
#   69.7008,
#   -39.0333,
#   48.6499,
#   -25.2406,
#   78.2186,
#   -21.6403,
#   17.4189,
#   18.7333,
#   67.6713,
#   52.3333,
#   58.8053,
#   -26.6481,
#   10.5669,
#   -14.4086,
#   51.55,
#   19.9,
#   4.2498,
#   -9.8,
#   12.2175,
#   33.194,
#   4.95,
#   -45.8667,
#   -3.6954,
#   18.4167,
#   -38.2667,
#   36.6177,
#   57.0531,
#   24.4667,
#   13.2167,
#   -33.9258,
#   42.975,
#   -20.7333,
#   50.3164,
#   -20.5167,
#   -28,
#   65.6145,
#   39.9523,
#   -13.7,
#   -38.3739,
#   37.2711,
#   54.2693,
#   -19.8436,
#   53.9479,
#   -38.0023,
#   -32.8899,
#   24.8,
#   61.95,
#   34.74,
#   69.4865,
#   -3.8004,
#   -12.2333,
#   -28.65,
#   29.5542,
#   57.79,
#   -17.7333,
#   65.8522,
#   0.0722,
#   -37.6167,
#   69.3,
#   -5.0892,
#   -23.1333,
#   67.667,
#   -29.4667,
#   -33.0333,
#   -5.1989,
#   44.251,
#   16.9056,
#   18.217,
#   52.0549,
#   -8.19,
#   -16.0999,
#   34.0686,
#   3.1655,
#   7.7669,
#   -32.035,
#   -33.6971,
#   28.017,
#   -3.1019,
#   -2.5744,
#   -22.6667,
#   47.9077,
#   14.9215,
#   2.5228,
#   31.3224,
#   2.9333,
#   -30.1811,
#   65.9667,
#   25.5198,
#   21.4612,
#   48.9329,
#   41.9833,
#   -15.7667,
#   -5.795,
#   68.2191,
#   32.5667,
#   50.6789,
#   68.5333,
#   -14.9003,
#   41.7597,
#   -7.3,
#   23.1667,
#   63.7506,
#   35.8311,
#   -22.9194,
#   22.2931,
#   16.8901,
#   -20.0064,
#   -20.1,
#   32.31,
#   44.8392,
#   1.1667,
#   -20.2078,
#   26.8661,
#   60.8156,
#   2.4167,
#   59.0556,
#   20.1986,
#   69.4154,
#   14.5333,
#   39.1834,
#   36.2946,
#   -3.432,
#   13.75,
#   31.2156,
#   -12.9067,
#   43.7444,
#   49.9811,
#   56.6709,
#   -13.8833,
#   53.4001,
#   19.9,
#   -9.5972,
#   40.8126,
#   60.7167,
#   7.4167,
#   20.8947,
#   -20.7377,
#   0.0644,
#   36.5167,
#   1.6481,
#   -29.5128,
#   -23.3886,
#   3.1191,
#   51.3813,
#   47.5999,
#   40.602,
#   49.1919,
#   46.5168,
#   20.7,
#   63.4453,
#   0.7821,
#   42.0751,
#   28.4532,
#   28.7167,
#   64.2539,
#   7.9986,
#   65.8167,
#   11.3937,
#   60.05,
#   27.4,
#   -0.1541,
#   38.3032,
#   64.8378,
#   20.931,
#   -0.7193,
#   -33.5907,
#   17.0151,
#   58.5169,
#   22.4667,
#   44.5086,
#   -39.4556,
#   52.85,
#   62.2266,
#   28.5004,
#   14.3,
#   36.8529,
#   63.8986,
#   55.0607,
#   -10.0681,
#   -26.502,
#   54.9589,
#   -9.6658,
#   63.2909,
#   50.9416,
#   -19.9842,
#   25.2819,
#   60.34,
#   -11.3847,
#   -22.2763,
#   60.8953,
#   -29.038,
#   65.5333,
#   43.919,
#   52.5178,
#   23.05,
#   55.4333,
#   -19.5492,
#   -17.6394,
#   -15.9653,
#   42.2418,
#   4.8845,
#   39.0951,
#   39.4547,
#   -33.3833,
#   58.3405,
#   -25.19,
#   22.5667,
#   -37.8333,
#   -6.5844,
#   47.1053,
#   49.7447,
#   60.3964,
#   67.6333,
#   60.9167,
#   10.3744,
#   -1.5746,
#   36.7483,
#   30.3,
#   40.8333,
#   60.4667,
#   -3.7508,
#   -5.6667,
#   42.7846,
#   41.8334,
#   38.0608,
#   -26.6167,
#   13.1667,
#   37.4486,
#   -0.9516,
#   38.7333,
#   -6.4167,
#   34.9833,
#   63.05,
#   36.7428,
#   -9.9133,
#   54.7804,
#   -4.9561,
#   56.8471,
#   -20.4081,
#   -15.5333,
#   47.5659,
#   53.33,
#   40.1049,
#   52.7939,
#   42.3738,
#   -35.35,
#   -25.2986,
#   39.9879,
#   4.9158,
#   0.6,
#   -9.4333,
#   43.3236,
#   -45.5752,
#   4.375,
#   66.0449,
#   50.0501,
#   64.8945,
#   -22.4,
#   62.2415,
#   39.05,
#   43.7501,
#   39.2667,
#   67.6803,
#   -9.0122,
#   60.1025,
#   32.1167,
#   35.5967,
#   70.8578,
#   34.1667,
#   48.1958,
#   -14.8796,
#   41.5388,
#   -41.0667,
#   -25.4,
#   51.226,
#   52.0108,
#   13.1333,
#   -45.8742,
#   -3.6333,
#   -19.0595,
#   16.7619,
#   16.9692,
#   42.0304,
#   39.1502,
#   0.1833,
#   45.6333,
#   17.0818,
#   50.5167,
#   8.1222,
#   40.8021,
#   35.8462,
#   -3.4,
#   -6.4667,
#   37.4966,
#   -11.0964,
#   -7.5667,
#   33.0833,
#   49.6501,
#   42.8,
#   44.1667,
#   17.65,
#   48.8125,
#   15.6833,
#   61.9449,
#   -5.3582,
#   13.35,
#   46.4856,
#   -45.4167,
#   18.4411,
#   63.4427,
#   44.8683,
#   -33.8679,
#   30.3333,
#   -2.7619,
#   24.1447,
#   -7.95,
#   -18.3733,
#   -3.3333,
#   11.0461,
#   4.4133,
#   43.3036,
#   22.1333,
#   49.1168,
#   -17.5333,
#   68.5646,
#   0.15,
#   32.8663,
#   50.949,
#   61.9875,
#   51.8892,
#   45.0503,
#   38.421,
#   -41.2866,
#   34.8791,
#   50.06,
#   39.8161,
#   -27.7951,
#   58.6978,
#   27.9769,
#   42.7762,
#   38.4167,
#   62.6667,
#   28.6585,
#   34.7575,
#   52.8667,
#   -20.9667,
#   9.4092,
#   -22.4667,
#   -45.75,
#   18.2164,
#   -28.55,
#   40.4272,
#   5.9485,
#   50.7214,
#   -34.6534,
#   13.0667,
#   25.9333,
#   66.9395,
#   27.4375,
#   46.3592,
#   59.6425,
#   3.3,
#   32.3502,
#   -8.7386,
#   14.9215,
#   42.3256],
#  'Lng': [-73.9662,
#   57.7575,
#   -133.0374,
#   168.8643,
#   -2.5,
#   -45.2371,
#   48.5268,
#   152.4333,
#   -73.414,
#   -56.1549,
#   -72.4167,
#   -28.7,
#   22.9573,
#   127.4,
#   153.6833,
#   -134.9692,
#   55.4781,
#   160.7034,
#   -68.3,
#   -147.8028,
#   10.7002,
#   106.6861,
#   -90.3518,
#   -98.8083,
#   -122.6762,
#   -171,
#   -159.775,
#   -175.2,
#   17.9442,
#   -57.6333,
#   135.9833,
#   -69.3632,
#   115.3333,
#   40.6453,
#   21.5482,
#   51.1442,
#   147.3294,
#   8.9167,
#   143.3,
#   125.4092,
#   26.891,
#   -68.5914,
#   -44.8683,
#   172.7902,
#   115.2494,
#   158.6667,
#   114.1577,
#   47.5312,
#   -51.1,
#   96.37,
#   -70.9167,
#   8.3181,
#   33.4479,
#   44.2833,
#   67.0786,
#   -124.1573,
#   -71.3436,
#   -66.8958,
#   -70.4,
#   -24.4956,
#   178.4167,
#   -149.2667,
#   -113.5841,
#   -109.9124,
#   138.95,
#   23.3716,
#   -113.0619,
#   -120.4579,
#   55.3333,
#   -156.7887,
#   135.7,
#   -79.2353,
#   -17.1,
#   108.0108,
#   -88.55,
#   80.5464,
#   19.2345,
#   -73.8203,
#   92.75,
#   30.7861,
#   5.2692,
#   100.3543,
#   168.3333,
#   147.9167,
#   -73.3579,
#   -159.319,
#   114.0833,
#   78.0056,
#   100.3354,
#   84.6,
#   -52.7314,
#   73.0833,
#   167.6833,
#   -126.8329,
#   -75.2829,
#   147.2712,
#   -51.7216,
#   -114.3525,
#   104.0286,
#   -77.8333,
#   -97.8558,
#   -52,
#   73.5667,
#   -173.3,
#   55.7679,
#   -94.9669,
#   -65.7125,
#   48.2436,
#   -54.9614,
#   128.8694,
#   20.0403,
#   25.5701,
#   161.3,
#   -91.6216,
#   6.6147,
#   27.9116,
#   47.4333,
#   135.8667,
#   -63.5986,
#   81.3833,
#   82.2167,
#   147.0587,
#   112.2447,
#   -131.6461,
#   109.7726,
#   -97.1436,
#   -17.7642,
#   14.2845,
#   54.1371,
#   -151.75,
#   -50.0119,
#   -52.95,
#   102.35,
#   122.8766,
#   -11.3333,
#   113.6333,
#   23.4167,
#   38.9073,
#   114.6,
#   -155.09,
#   140.8333,
#   169.8464,
#   -112.8686,
#   150.8552,
#   107.8106,
#   -42.0278,
#   66.4042,
#   67.0822,
#   82.8265,
#   -77.2708,
#   12.3689,
#   140.3,
#   -61.7485,
#   42.4509,
#   158.6483,
#   117.095,
#   4.2658,
#   -81.7826,
#   102.5,
#   -127.4199,
#   -122.4286,
#   -13.0499,
#   70.4667,
#   24.7314,
#   -81.2719,
#   49.05,
#   112.4,
#   -76.4356,
#   -93.218,
#   -47.8103,
#   58.5334,
#   102.4166,
#   155.6333,
#   170.3133,
#   -67.5833,
#   -53.1147,
#   130.9889,
#   15.6401,
#   -41.0511,
#   121.4443,
#   -103.6833,
#   53.087,
#   124.7333,
#   -122.7002,
#   15.1594,
#   72.642,
#   -56.4461,
#   -9.2667,
#   -100.45,
#   117.8871,
#   -139.0333,
#   4.3792,
#   -82.5271,
#   23.9167,
#   -67.5,
#   128.1814,
#   -64.6167,
#   141.9667,
#   -121.9166,
#   -135.33,
#   54.3667,
#   -59.5167,
#   18.4232,
#   144.3747,
#   139.5,
#   -122.8027,
#   57.5167,
#   153.4333,
#   -37.6368,
#   -75.1638,
#   -76.2167,
#   -60.2798,
#   -87.1764,
#   41.4465,
#   34.8389,
#   47.6536,
#   -57.5575,
#   -60.6906,
#   125.2833,
#   159.2333,
#   60.7756,
#   88.3972,
#   102.2655,
#   136.7667,
#   153.6167,
#   66.0215,
#   -152.4072,
#   -149.15,
#   44.24,
#   42.7506,
#   -73.65,
#   139.9,
#   -81.1144,
#   150.7333,
#   12.6934,
#   149.85,
#   137.5833,
#   -35.4608,
#   -116.9693,
#   96.5631,
#   -63.0578,
#   15.0988,
#   114.9675,
#   167.4164,
#   -118.0276,
#   -52.3158,
#   -72.225,
#   -52.0986,
#   -53.4616,
#   -97.5169,
#   -60.025,
#   150.7967,
#   167.4833,
#   106.8832,
#   -23.5087,
#   101.7959,
#   -92.4343,
#   11.9833,
#   -50.2056,
#   78.3667,
#   90.2201,
#   -71.1419,
#   -125.5528,
#   24.0833,
#   128.7333,
#   -35.2094,
#   -135.0107,
#   76.1333,
#   156.125,
#   146.4167,
#   50.2788,
#   86.1469,
#   27.4167,
#   -97.95,
#   -68.5145,
#   14.4742,
#   -42.8186,
#   91.9762,
#   -24.9804,
#   57.6608,
#   146.2667,
#   54.0175,
#   133.0436,
#   108.9667,
#   57.7625,
#   104.2841,
#   -115.7999,
#   30.9855,
#   80.8572,
#   1.0114,
#   30.8136,
#   20.9167,
#   -84.5333,
#   -76.2511,
#   10.6554,
#   -60.9833,
#   29.9553,
#   45.1914,
#   135.2892,
#   92.0667,
#   124.6491,
#   167.55,
#   -117.5857,
#   77.5833,
#   -35.9567,
#   -73.999,
#   -46.0333,
#   81.8167,
#   -156.47,
#   116.8463,
#   32.4469,
#   -86.8667,
#   14.5806,
#   -51.9853,
#   -48.7228,
#   35.5973,
#   1.3862,
#   -53.2648,
#   43.095,
#   -98.1014,
#   -84.3333,
#   -105.2,
#   120.3167,
#   11.549,
#   -72.0334,
#   117.9686,
#   -111.5833,
#   -15.2082,
#   124.2928,
#   87.9833,
#   122.6856,
#   69.9,
#   74.5667,
#   35.1988,
#   -77.4605,
#   -147.7164,
#   -17.0347,
#   8.7815,
#   22.2014,
#   54.0924,
#   -117.136,
#   78.4333,
#   50.263,
#   173.8583,
#   -102.3842,
#   -6.589,
#   -13.8627,
#   -91.9167,
#   -75.978,
#   122.7617,
#   15.1306,
#   -78.1522,
#   17.1583,
#   20.4767,
#   -35.7353,
#   18.7153,
#   -2.6321,
#   57.6142,
#   110.2864,
#   102.2797,
#   43.2844,
#   166.4572,
#   131.9608,
#   24.6028,
#   72.5167,
#   46.7102,
#   99.825,
#   84.55,
#   86.0833,
#   -42.12,
#   -71.3375,
#   -54.9683,
#   -71.1662,
#   -1.7554,
#   33.0799,
#   75.9797,
#   148.0167,
#   8.5934,
#   -49.3142,
#   59.5289,
#   140.7667,
#   -36.7744,
#   -104.7125,
#   16.9289,
#   -1.353,
#   134.6333,
#   -46.05,
#   10.7288,
#   9.2618,
#   118.0558,
#   108.85,
#   -6,
#   166.1,
#   103.6372,
#   132.75,
#   75.6892,
#   -71.1662,
#   -97.9298,
#   -54.1333,
#   80.2667,
#   116.2925,
#   122.7875,
#   -27.0667,
#   20.8,
#   139.8667,
#   179.3167,
#   -3.5872,
#   -63.0408,
#   -127.1743,
#   -37.1369,
#   105.2542,
#   57.7,
#   167.1667,
#   9.3787,
#   6.5208,
#   27.654,
#   89.8983,
#   47.3745,
#   150.4667,
#   152.8535,
#   -6.5377,
#   29.4742,
#   -80.0333,
#   159.95,
#   145.575,
#   -72.0662,
#   -7.7169,
#   -17.3389,
#   -110.6683,
#   -23.7142,
#   46.1167,
#   25.7209,
#   -27.9833,
#   -81.7165,
#   141.8833,
#   53.1512,
#   -35.2225,
#   32.3019,
#   20.0667,
#   116.9911,
#   29.0864,
#   77.5833,
#   -114.3129,
#   47.9875,
#   -8.6151,
#   145.9167,
#   -70.4833,
#   -58.6502,
#   86.5467,
#   75.6333,
#   170.5036,
#   -44.3767,
#   -169.9187,
#   96.5278,
#   -88.2321,
#   -8.1588,
#   -123.2078,
#   30.0833,
#   85.1833,
#   122.4157,
#   115.1333,
#   -63.5497,
#   -124.1637,
#   71.7858,
#   -78.55,
#   16.8167,
#   61.9714,
#   -77.6139,
#   24.1833,
#   -16.3333,
#   -108.4181,
#   93.45,
#   52.1167,
#   83.2667,
#   103.5347,
#   -86,
#   76.6625,
#   104.9744,
#   -15.75,
#   135.8833,
#   167.7167,
#   1.4078,
#   -20.2734,
#   13.8481,
#   151.2073,
#   10.85,
#   -42.2744,
#   67.4497,
#   110.2833,
#   -40.8306,
#   128.9167,
#   14.1401,
#   32.5678,
#   44.8964,
#   75.6,
#   -68.399,
#   146.0333,
#   14.9108,
#   29.2833,
#   59.2211,
#   43.7378,
#   5.1352,
#   0.9042,
#   136.6092,
#   -121.4238,
#   174.7756,
#   -76.9013,
#   43.2379,
#   109.9776,
#   -64.2615,
#   81.4825,
#   -114.0611,
#   -9.0603,
#   77.2406,
#   135.6,
#   -17.9182,
#   -112.4538,
#   -104.6177,
#   164.7,
#   45.064,
#   -68.9333,
#   170.5667,
#   42.5053,
#   16.4333,
#   71.7189,
#   80.5353,
#   136.6319,
#   -58.6198,
#   -59.5333,
#   -105.3667,
#   -53.6735,
#   115.4976,
#   6.9759,
#   -151.5483,
#   117.6333,
#   -85.1999,
#   24.9906,
#   -23.5087,
#   -83.331],
#  'Max Temp': [296.51,
#   293.27,
#   275.09,
#   282.86,
#   283.73,
#   272.32,
#   299.04,
#   303.11,
#   293.35,
#   269.91,
#   283.05,
#   288.2,
#   291.86,
#   300.46,
#   276.56,
#   297.8,
#   294.97,
#   301.64,
#   277.96,
#   287.36,
#   282.38,
#   289.71,
#   296.79,
#   293.08,
#   292.57,
#   274.28,
#   298.18,
#   301.24,
#   284.74,
#   286.05,
#   293.1,
#   267.15,
#   289.84,
#   301.01,
#   293.55,
#   288.5,
#   291.61,
#   283.42,
#   277.56,
#   295.53,
#   286.18,
#   263.6,
#   297.4,
#   300.83,
#   303.13,
#   275.48,
#   306.46,
#   290.19,
#   271.16,
#   281.19,
#   278.21,
#   285.2,
#   286.27,
#   292.74,
#   293.31,
#   290.61,
#   286,
#   296.96,
#   288.75,
#   295.98,
#   273.68,
#   300.13,
#   291.41,
#   303.04,
#   294.91,
#   283.78,
#   280.69,
#   290.51,
#   285.9,
#   273.16,
#   296.1,
#   294.1,
#   292.6,
#   282.83,
#   301.24,
#   271.39,
#   284.21,
#   283.83,
#   300.17,
#   281.09,
#   304.22,
#   300.18,
#   283.04,
#   272.23,
#   293.69,
#   301.14,
#   268.43,
#   285.53,
#   302.11,
#   302.45,
#   286.42,
#   301.82,
#   283.05,
#   293.48,
#   282.19,
#   303.78,
#   271.49,
#   286.24,
#   292.87,
#   291.26,
#   273.76,
#   295.68,
#   301.97,
#   278.52,
#   294.92,
#   299.13,
#   259.98,
#   306.35,
#   300.59,
#   271.52,
#   282.64,
#   282.65,
#   274.49,
#   292.08,
#   291.78,
#   287.6,
#   289.76,
#   293.44,
#   285.35,
#   302.98,
#   302.37,
#   291.42,
#   296.44,
#   282.05,
#   279.15,
#   296.25,
#   294.23,
#   290.05,
#   301.31,
#   300.79,
#   287.86,
#   298.62,
#   296.34,
#   300.4,
#   294.67,
#   299.19,
#   288.33,
#   287.67,
#   295.44,
#   296.07,
#   293.81,
#   285.89,
#   278.88,
#   293.36,
#   301.99,
#   296.16,
#   293.84,
#   303.05,
#   280.45,
#   299.59,
#   298.6,
#   295.99,
#   299.97,
#   290.44,
#   287.48,
#   302.63,
#   288.46,
#   298.71,
#   270.44,
#   285.32,
#   293.94,
#   300.9,
#   288.47,
#   281.42,
#   292.89,
#   291.27,
#   273.64,
#   297.6,
#   298.11,
#   291.15,
#   303.62,
#   304.05,
#   302.09,
#   273.01,
#   284.97,
#   282.67,
#   296.06,
#   268.06,
#   295.66,
#   306,
#   296.51,
#   291.05,
#   280.15,
#   292.56,
#   288.5,
#   301.14,
#   298.98,
#   280.04,
#   295.88,
#   301.35,
#   299.93,
#   303.74,
#   296.96,
#   293.42,
#   284.27,
#   300.23,
#   301.2,
#   290.94,
#   291.49,
#   282.09,
#   301.21,
#   299.98,
#   284.33,
#   286.68,
#   300.02,
#   293.56,
#   293.35,
#   297.2,
#   273.24,
#   297.07,
#   292.05,
#   284.1,
#   295.99,
#   282.09,
#   292.68,
#   289.59,
#   288.76,
#   284.84,
#   300.59,
#   279.48,
#   296.11,
#   273.37,
#   297.18,
#   302.49,
#   296.12,
#   298.27,
#   280.88,
#   303.16,
#   288.73,
#   298.3,
#   284.11,
#   271.89,
#   292.86,
#   298.03,
#   278.78,
#   293.25,
#   296.09,
#   296.65,
#   288.88,
#   302.23,
#   300.43,
#   285.23,
#   302.07,
#   299.71,
#   294.36,
#   296,
#   298.25,
#   289.79,
#   288.5,
#   300.2,
#   300.42,
#   302.73,
#   295.31,
#   274.22,
#   294.45,
#   301.27,
#   297.09,
#   293.4,
#   291.52,
#   281.35,
#   299.78,
#   298.42,
#   295.4,
#   277.83,
#   304.14,
#   296.51,
#   290.26,
#   296.37,
#   278.08,
#   278.43,
#   293.82,
#   289.8,
#   292.5,
#   300.15,
#   269,
#   290.35,
#   296.4,
#   304.22,
#   293.9,
#   293.36,
#   293.57,
#   297.36,
#   297.37,
#   300.27,
#   293.2,
#   289.54,
#   287.06,
#   289.66,
#   286.18,
#   305.27,
#   272.75,
#   303.77,
#   296.62,
#   290.16,
#   298.28,
#   299.82,
#   293.57,
#   300.01,
#   289.91,
#   280.24,
#   279.58,
#   300.15,
#   288.21,
#   306.6,
#   296.11,
#   296.06,
#   274.43,
#   300.49,
#   299.74,
#   300.48,
#   293.93,
#   297.14,
#   294.75,
#   290.42,
#   291.38,
#   300.75,
#   283.99,
#   286.85,
#   282.4,
#   282.36,
#   294.31,
#   298.83,
#   281.58,
#   294.12,
#   294.46,
#   291.53,
#   305.29,
#   275.79,
#   300.73,
#   276.48,
#   303.93,
#   293.1,
#   302.81,
#   290,
#   294.5,
#   288.34,
#   291.7,
#   298.23,
#   280.4,
#   301.2,
#   290.82,
#   301.29,
#   297.33,
#   289.45,
#   273.79,
#   277.66,
#   295.01,
#   302.79,
#   290.94,
#   280.68,
#   283.2,
#   291.28,
#   282.56,
#   283.18,
#   296.84,
#   278.05,
#   283.4,
#   293.41,
#   299.79,
#   283.06,
#   298.98,
#   298.15,
#   282.61,
#   279.7,
#   292.98,
#   289.19,
#   274.15,
#   301.64,
#   281.75,
#   291.94,
#   290.72,
#   297.72,
#   295.14,
#   298.68,
#   282.96,
#   293.28,
#   290.87,
#   283.1,
#   288.34,
#   306.1,
#   290.98,
#   295.96,
#   278.5,
#   285.64,
#   278.1,
#   279.06,
#   274.27,
#   302,
#   296.99,
#   302.94,
#   287.96,
#   282.03,
#   273.93,
#   299.3,
#   300.4,
#   289.09,
#   292.75,
#   295.55,
#   289.24,
#   300.41,
#   303.79,
#   301.76,
#   288.01,
#   293.6,
#   295.94,
#   273.62,
#   295.19,
#   296.76,
#   289.72,
#   297.68,
#   282.17,
#   293.29,
#   300.45,
#   282.64,
#   284.32,
#   286.52,
#   281.57,
#   277.93,
#   292.41,
#   297.21,
#   285.62,
#   292.88,
#   298,
#   302.53,
#   284.39,
#   276.12,
#   298.82,
#   273.69,
#   276.05,
#   276.75,
#   285.23,
#   276.35,
#   287.86,
#   295.32,
#   288,
#   291.03,
#   297.93,
#   280.37,
#   291.3,
#   301.03,
#   274.86,
#   278.88,
#   281.17,
#   294.14,
#   286.95,
#   287.01,
#   291.72,
#   279.37,
#   282.8,
#   293.11,
#   288.6,
#   296.75,
#   299.71,
#   302.24,
#   299.81,
#   280,
#   294.02,
#   292.56,
#   289.84,
#   304.87,
#   277.25,
#   301.09,
#   290.75,
#   290.31,
#   290.98,
#   293.09,
#   298.53,
#   290.68,
#   291.26,
#   290.83,
#   272.46,
#   286.98,
#   299.99,
#   300.33,
#   274.15,
#   298.28,
#   293.23,
#   301.76,
#   299.08,
#   296.69,
#   284.12,
#   306.64,
#   279.05,
#   290.09,
#   292.77,
#   294.87,
#   299.01,
#   302.51,
#   301.41,
#   293.43,
#   299.85,
#   304.27,
#   294.33,
#   294.7,
#   301.71,
#   286.56,
#   298.64,
#   281.2,
#   287.01,
#   292.47,
#   287.89,
#   281.04,
#   283.31,
#   287.32,
#   297.65,
#   289.16,
#   293.28,
#   288.24,
#   293.71,
#   288.03,
#   284.68,
#   289.26,
#   286.06,
#   295.64,
#   282.07,
#   292.01,
#   291.02,
#   275.57,
#   296.77,
#   295.59,
#   280.42,
#   288.04,
#   290.29,
#   286.18,
#   292.83,
#   300.63,
#   299.85,
#   287.09,
#   299.88,
#   300.87,
#   271.24,
#   294.2,
#   278.46,
#   282.09,
#   301.87,
#   296.72,
#   288.56,
#   294.45,
#   299.81],
#  'Humidity': [89,
#   62,
#   84,
#   61,
#   95,
#   97,
#   80,
#   70,
#   58,
#   96,
#   83,
#   66,
#   66,
#   38,
#   60,
#   58,
#   62,
#   74,
#   93,
#   58,
#   99,
#   45,
#   94,
#   63,
#   59,
#   99,
#   78,
#   83,
#   69,
#   98,
#   60,
#   74,
#   70,
#   30,
#   42,
#   93,
#   62,
#   53,
#   64,
#   54,
#   66,
#   84,
#   94,
#   77,
#   67,
#   89,
#   73,
#   70,
#   93,
#   54,
#   87,
#   82,
#   80,
#   66,
#   45,
#   68,
#   74,
#   96,
#   71,
#   73,
#   86,
#   74,
#   20,
#   57,
#   81,
#   73,
#   25,
#   69,
#   71,
#   86,
#   50,
#   63,
#   76,
#   42,
#   81,
#   85,
#   67,
#   88,
#   89,
#   88,
#   27,
#   74,
#   76,
#   86,
#   60,
#   83,
#   90,
#   38,
#   81,
#   69,
#   68,
#   72,
#   66,
#   21,
#   84,
#   62,
#   86,
#   35,
#   85,
#   84,
#   96,
#   99,
#   73,
#   66,
#   72,
#   88,
#   88,
#   6,
#   48,
#   84,
#   74,
#   70,
#   74,
#   87,
#   46,
#   58,
#   96,
#   31,
#   94,
#   38,
#   90,
#   58,
#   71,
#   87,
#   59,
#   87,
#   73,
#   71,
#   10,
#   71,
#   66,
#   89,
#   97,
#   71,
#   98,
#   31,
#   36,
#   91,
#   57,
#   94,
#   82,
#   56,
#   84,
#   64,
#   69,
#   90,
#   39,
#   74,
#   96,
#   88,
#   84,
#   87,
#   83,
#   40,
#   44,
#   67,
#   94,
#   65,
#   86,
#   71,
#   74,
#   22,
#   37,
#   73,
#   87,
#   87,
#   92,
#   96,
#   80,
#   68,
#   26,
#   59,
#   77,
#   94,
#   49,
#   80,
#   27,
#   68,
#   91,
#   53,
#   64,
#   65,
#   79,
#   35,
#   47,
#   74,
#   64,
#   89,
#   26,
#   74,
#   71,
#   51,
#   49,
#   95,
#   94,
#   86,
#   74,
#   46,
#   78,
#   93,
#   65,
#   73,
#   63,
#   92,
#   32,
#   29,
#   57,
#   63,
#   72,
#   41,
#   82,
#   86,
#   77,
#   94,
#   91,
#   74,
#   47,
#   97,
#   87,
#   59,
#   22,
#   98,
#   90,
#   61,
#   70,
#   9,
#   81,
#   73,
#   76,
#   83,
#   86,
#   95,
#   81,
#   68,
#   80,
#   44,
#   20,
#   81,
#   51,
#   62,
#   73,
#   93,
#   61,
#   68,
#   33,
#   99,
#   92,
#   93,
#   88,
#   82,
#   83,
#   69,
#   70,
#   87,
#   78,
#   78,
#   86,
#   99,
#   93,
#   91,
#   84,
#   75,
#   83,
#   82,
#   30,
#   78,
#   35,
#   42,
#   77,
#   53,
#   86,
#   24,
#   61,
#   80,
#   73,
#   77,
#   90,
#   67,
#   83,
#   76,
#   62,
#   16,
#   37,
#   81,
#   64,
#   83,
#   42,
#   89,
#   87,
#   25,
#   98,
#   20,
#   75,
#   88,
#   88,
#   75,
#   57,
#   70,
#   58,
#   30,
#   55,
#   69,
#   35,
#   27,
#   95,
#   48,
#   87,
#   77,
#   75,
#   19,
#   83,
#   68,
#   99,
#   100,
#   45,
#   54,
#   73,
#   77,
#   61,
#   85,
#   64,
#   73,
#   42,
#   99,
#   92,
#   97,
#   39,
#   59,
#   67,
#   97,
#   64,
#   52,
#   47,
#   92,
#   66,
#   61,
#   94,
#   92,
#   83,
#   78,
#   34,
#   28,
#   42,
#   71,
#   99,
#   86,
#   68,
#   73,
#   88,
#   51,
#   86,
#   86,
#   49,
#   93,
#   84,
#   90,
#   94,
#   76,
#   88,
#   40,
#   66,
#   99,
#   31,
#   64,
#   54,
#   83,
#   45,
#   41,
#   82,
#   74,
#   84,
#   58,
#   68,
#   87,
#   76,
#   27,
#   52,
#   94,
#   73,
#   35,
#   41,
#   82,
#   92,
#   94,
#   67,
#   40,
#   90,
#   60,
#   96,
#   39,
#   95,
#   79,
#   92,
#   85,
#   82,
#   50,
#   66,
#   81,
#   98,
#   71,
#   34,
#   70,
#   69,
#   61,
#   80,
#   89,
#   57,
#   94,
#   42,
#   79,
#   30,
#   61,
#   65,
#   90,
#   71,
#   61,
#   56,
#   37,
#   61,
#   88,
#   55,
#   94,
#   87,
#   73,
#   99,
#   100,
#   81,
#   78,
#   80,
#   64,
#   98,
#   97,
#   59,
#   73,
#   96,
#   65,
#   84,
#   90,
#   71,
#   51,
#   72,
#   35,
#   55,
#   69,
#   83,
#   72,
#   57,
#   92,
#   49,
#   93,
#   43,
#   92,
#   83,
#   63,
#   84,
#   92,
#   40,
#   85,
#   32,
#   62,
#   77,
#   61,
#   72,
#   40,
#   99,
#   68,
#   25,
#   87,
#   61,
#   72,
#   95,
#   12,
#   17,
#   73,
#   81,
#   92,
#   56,
#   76,
#   37,
#   32,
#   70,
#   23,
#   65,
#   63,
#   65,
#   41,
#   89,
#   73,
#   73,
#   88,
#   84,
#   41,
#   86,
#   54,
#   46,
#   96,
#   84,
#   82,
#   97,
#   27,
#   89,
#   89,
#   95,
#   70,
#   46,
#   73,
#   89,
#   88,
#   34,
#   46,
#   87,
#   67,
#   76,
#   20,
#   53,
#   68,
#   16,
#   96,
#   61,
#   65,
#   24,
#   50,
#   47,
#   76,
#   37,
#   84,
#   40,
#   97,
#   73,
#   17,
#   74,
#   98,
#   90,
#   72,
#   79,
#   58,
#   62,
#   78,
#   58],
#  'Cloudiness': [100,
#   79,
#   5,
#   20,
#   100,
#   98,
#   90,
#   84,
#   40,
#   100,
#   13,
#   7,
#   2,
#   87,
#   100,
#   2,
#   75,
#   100,
#   75,
#   75,
#   100,
#   100,
#   47,
#   98,
#   40,
#   100,
#   90,
#   75,
#   0,
#   100,
#   100,
#   23,
#   100,
#   52,
#   0,
#   100,
#   20,
#   0,
#   100,
#   64,
#   12,
#   100,
#   16,
#   100,
#   86,
#   100,
#   39,
#   100,
#   75,
#   22,
#   20,
#   38,
#   100,
#   0,
#   5,
#   75,
#   0,
#   100,
#   52,
#   2,
#   100,
#   10,
#   1,
#   20,
#   100,
#   0,
#   1,
#   90,
#   57,
#   90,
#   52,
#   1,
#   85,
#   55,
#   12,
#   99,
#   40,
#   43,
#   75,
#   99,
#   47,
#   100,
#   82,
#   71,
#   1,
#   20,
#   56,
#   0,
#   20,
#   100,
#   83,
#   46,
#   15,
#   9,
#   16,
#   9,
#   90,
#   0,
#   100,
#   90,
#   100,
#   100,
#   100,
#   45,
#   76,
#   90,
#   38,
#   16,
#   100,
#   100,
#   22,
#   1,
#   100,
#   31,
#   37,
#   6,
#   79,
#   69,
#   90,
#   2,
#   100,
#   4,
#   98,
#   100,
#   100,
#   90,
#   0,
#   0,
#   16,
#   9,
#   6,
#   99,
#   100,
#   95,
#   100,
#   67,
#   0,
#   60,
#   100,
#   90,
#   100,
#   11,
#   100,
#   1,
#   45,
#   85,
#   6,
#   40,
#   100,
#   100,
#   2,
#   100,
#   40,
#   3,
#   0,
#   93,
#   0,
#   75,
#   27,
#   100,
#   1,
#   12,
#   0,
#   1,
#   22,
#   3,
#   57,
#   100,
#   1,
#   0,
#   2,
#   24,
#   36,
#   63,
#   100,
#   95,
#   0,
#   75,
#   6,
#   13,
#   94,
#   43,
#   100,
#   100,
#   0,
#   87,
#   100,
#   15,
#   96,
#   100,
#   25,
#   72,
#   4,
#   45,
#   100,
#   40,
#   100,
#   0,
#   75,
#   90,
#   0,
#   34,
#   3,
#   75,
#   96,
#   23,
#   99,
#   75,
#   100,
#   1,
#   0,
#   100,
#   1,
#   97,
#   0,
#   100,
#   100,
#   90,
#   55,
#   27,
#   0,
#   100,
#   100,
#   90,
#   33,
#   0,
#   90,
#   8,
#   73,
#   6,
#   88,
#   100,
#   0,
#   29,
#   100,
#   0,
#   7,
#   4,
#   27,
#   82,
#   100,
#   100,
#   95,
#   94,
#   5,
#   100,
#   100,
#   100,
#   100,
#   4,
#   40,
#   55,
#   9,
#   75,
#   0,
#   100,
#   90,
#   100,
#   100,
#   88,
#   41,
#   100,
#   100,
#   36,
#   92,
#   0,
#   67,
#   0,
#   23,
#   100,
#   44,
#   0,
#   27,
#   4,
#   90,
#   0,
#   19,
#   4,
#   20,
#   39,
#   78,
#   94,
#   99,
#   96,
#   69,
#   99,
#   33,
#   7,
#   100,
#   82,
#   100,
#   16,
#   1,
#   1,
#   55,
#   100,
#   0,
#   90,
#   90,
#   49,
#   100,
#   78,
#   1,
#   97,
#   69,
#   75,
#   100,
#   100,
#   40,
#   0,
#   48,
#   75,
#   100,
#   100,
#   39,
#   6,
#   100,
#   52,
#   0,
#   100,
#   1,
#   1,
#   82,
#   99,
#   99,
#   100,
#   0,
#   100,
#   77,
#   100,
#   100,
#   2,
#   65,
#   49,
#   1,
#   90,
#   0,
#   100,
#   5,
#   20,
#   52,
#   5,
#   0,
#   100,
#   96,
#   99,
#   13,
#   1,
#   20,
#   95,
#   13,
#   18,
#   0,
#   0,
#   75,
#   90,
#   91,
#   28,
#   97,
#   42,
#   2,
#   55,
#   54,
#   72,
#   45,
#   51,
#   86,
#   80,
#   75,
#   8,
#   12,
#   100,
#   1,
#   58,
#   74,
#   100,
#   0,
#   100,
#   18,
#   0,
#   0,
#   0,
#   90,
#   100,
#   100,
#   22,
#   100,
#   91,
#   100,
#   52,
#   100,
#   100,
#   100,
#   100,
#   71,
#   0,
#   1,
#   20,
#   56,
#   100,
#   76,
#   93,
#   30,
#   56,
#   100,
#   72,
#   99,
#   100,
#   100,
#   6,
#   100,
#   83,
#   60,
#   90,
#   100,
#   1,
#   72,
#   44,
#   86,
#   25,
#   100,
#   84,
#   100,
#   100,
#   100,
#   13,
#   96,
#   100,
#   100,
#   2,
#   46,
#   90,
#   3,
#   97,
#   100,
#   45,
#   4,
#   100,
#   14,
#   33,
#   100,
#   15,
#   90,
#   1,
#   100,
#   2,
#   100,
#   100,
#   100,
#   81,
#   9,
#   38,
#   100,
#   99,
#   50,
#   100,
#   1,
#   5,
#   95,
#   9,
#   100,
#   36,
#   1,
#   34,
#   32,
#   93,
#   0,
#   49,
#   41,
#   75,
#   100,
#   84,
#   0,
#   75,
#   99,
#   100,
#   34,
#   32,
#   58,
#   70,
#   11,
#   90,
#   11,
#   0,
#   20,
#   0,
#   5,
#   97,
#   50,
#   53,
#   99,
#   100,
#   2,
#   44,
#   36,
#   100,
#   66,
#   93,
#   21,
#   0,
#   3,
#   97,
#   100,
#   100,
#   75,
#   96,
#   0,
#   4,
#   100,
#   92,
#   100,
#   0,
#   96,
#   100,
#   100,
#   0,
#   1,
#   100,
#   96,
#   99,
#   0,
#   5,
#   0,
#   0,
#   42,
#   71,
#   3,
#   100,
#   43,
#   100,
#   100,
#   100,
#   100,
#   75,
#   20,
#   1,
#   52,
#   0,
#   75],
#  'Wind Speed': [1.05,
#   7.65,
#   8.49,
#   1.23,
#   0.64,
#   1.66,
#   8.76,
#   2.28,
#   0,
#   2.79,
#   2.18,
#   7.74,
#   1.27,
#   5.22,
#   2.6,
#   2.8,
#   3.09,
#   1.88,
#   2.06,
#   0.45,
#   1.57,
#   7.06,
#   3.58,
#   2.93,
#   0.45,
#   0.98,
#   5.66,
#   6.69,
#   2.36,
#   1.45,
#   0.72,
#   3.58,
#   7.44,
#   0.39,
#   5.16,
#   4.62,
#   0.89,
#   1.72,
#   3.4,
#   1.54,
#   6.77,
#   1.26,
#   1.46,
#   9.89,
#   0.19,
#   4.43,
#   0.45,
#   5.9,
#   5.66,
#   1.45,
#   0.71,
#   1.03,
#   5.14,
#   5.28,
#   3.95,
#   1.79,
#   2.17,
#   1.04,
#   3.67,
#   2.57,
#   1.48,
#   4.14,
#   4.02,
#   4.12,
#   8.1,
#   2.97,
#   10.8,
#   6.69,
#   3.81,
#   9.26,
#   2.06,
#   0,
#   3.52,
#   1.23,
#   2.24,
#   1.94,
#   2.48,
#   1.88,
#   3.6,
#   4.13,
#   1.43,
#   0.17,
#   8.45,
#   1.57,
#   2.31,
#   1.34,
#   1.52,
#   1.16,
#   1.1,
#   1.77,
#   8.71,
#   3.33,
#   1.06,
#   4.31,
#   1.74,
#   1.83,
#   6.69,
#   4.47,
#   0.62,
#   4.04,
#   2.93,
#   1.1,
#   6.88,
#   5.64,
#   4.6,
#   0.89,
#   3.35,
#   3.31,
#   2.78,
#   3.3,
#   2.14,
#   5.18,
#   5.35,
#   2.35,
#   3.17,
#   6.32,
#   0.45,
#   4.26,
#   0,
#   0.32,
#   1.51,
#   0.89,
#   1.47,
#   3.35,
#   1.55,
#   3.13,
#   7.72,
#   3.12,
#   1.28,
#   5.25,
#   2.47,
#   5.47,
#   1.11,
#   1.87,
#   0.24,
#   2.57,
#   4.2,
#   4.59,
#   3.29,
#   3.09,
#   8.36,
#   2.71,
#   1.84,
#   1.34,
#   1.53,
#   4.75,
#   2.45,
#   6.17,
#   3.1,
#   1.61,
#   1.27,
#   10,
#   10.29,
#   1.34,
#   6.92,
#   0.97,
#   1.54,
#   6.69,
#   1.2,
#   4.47,
#   4.12,
#   3.06,
#   2.47,
#   3.61,
#   8.94,
#   1.56,
#   1.63,
#   0.86,
#   0.89,
#   0,
#   1.37,
#   0.82,
#   1.11,
#   1.92,
#   9.19,
#   3.96,
#   5.66,
#   3.6,
#   3.22,
#   2.91,
#   1.23,
#   7.06,
#   3.15,
#   0.99,
#   4.23,
#   2.14,
#   1.88,
#   4.48,
#   2.02,
#   0.56,
#   7.87,
#   6.22,
#   3.64,
#   0.68,
#   0.48,
#   3.44,
#   7.68,
#   6.74,
#   0.89,
#   5.14,
#   1.72,
#   8.99,
#   1.27,
#   4.31,
#   4.12,
#   1.62,
#   7.25,
#   6.07,
#   5.65,
#   2.68,
#   2.57,
#   3.89,
#   0,
#   3.12,
#   2.34,
#   6.21,
#   7.6,
#   1.34,
#   6.84,
#   2.21,
#   6.49,
#   6.15,
#   1.77,
#   6.69,
#   3.97,
#   2.43,
#   4.12,
#   4.2,
#   4.26,
#   4.76,
#   0.39,
#   1.59,
#   7.82,
#   6.73,
#   10.09,
#   2.98,
#   3.09,
#   4.99,
#   6.25,
#   0.87,
#   8.22,
#   3.58,
#   0.03,
#   4.78,
#   1.79,
#   1.23,
#   1.19,
#   11.31,
#   9.13,
#   3.9,
#   2.06,
#   3.48,
#   7.25,
#   4.08,
#   3.6,
#   0.88,
#   0.89,
#   1.07,
#   9.89,
#   5.68,
#   1.58,
#   9.11,
#   1.79,
#   2.56,
#   4.63,
#   3.8,
#   5.52,
#   1.76,
#   5.95,
#   2.8,
#   3.48,
#   2.43,
#   1.37,
#   1.68,
#   4.92,
#   2.06,
#   2.94,
#   1.7,
#   4.64,
#   1.34,
#   5.6,
#   2.08,
#   1.09,
#   0.41,
#   7.53,
#   0.4,
#   3.64,
#   1.98,
#   2.93,
#   3.01,
#   10.97,
#   3.84,
#   0.39,
#   2.57,
#   1.23,
#   8.53,
#   6.96,
#   8.65,
#   4.23,
#   1.75,
#   6.43,
#   7.54,
#   2.79,
#   0.89,
#   1.63,
#   0,
#   3.76,
#   3.22,
#   10.8,
#   5.67,
#   2.74,
#   0,
#   0.66,
#   1.43,
#   1.57,
#   4.3,
#   2.24,
#   3.13,
#   1.54,
#   6.02,
#   4.12,
#   3.09,
#   3.87,
#   0.31,
#   2.35,
#   2.53,
#   2.68,
#   6.82,
#   1.92,
#   8.33,
#   1.26,
#   3.18,
#   4.33,
#   1.5,
#   0,
#   5.14,
#   5.87,
#   7.23,
#   0.91,
#   1.54,
#   3.96,
#   1.35,
#   7.22,
#   9.45,
#   2.71,
#   5.95,
#   8.23,
#   2.92,
#   0,
#   3.72,
#   4.04,
#   4.19,
#   2.89,
#   5.46,
#   4.58,
#   3.79,
#   0.45,
#   1.34,
#   0.83,
#   1.27,
#   5.08,
#   4.58,
#   4.84,
#   2.15,
#   1.79,
#   2.14,
#   2.05,
#   1.65,
#   4.5,
#   1.31,
#   3.49,
#   1.68,
#   6.26,
#   2.83,
#   7.46,
#   3.56,
#   1.77,
#   2.96,
#   1.05,
#   3.37,
#   4.52,
#   7.56,
#   3.09,
#   1.74,
#   6.14,
#   3.63,
#   3.17,
#   4.09,
#   3.32,
#   4.17,
#   1.16,
#   2.68,
#   3.32,
#   0.62,
#   8.78,
#   3.04,
#   1.79,
#   1.34,
#   2.54,
#   3.97,
#   6.95,
#   1.98,
#   7.02,
#   1.37,
#   10.4,
#   1.19,
#   2.62,
#   0.61,
#   2.32,
#   7.45,
#   2.36,
#   7.69,
#   3.6,
#   3,
#   12.08,
#   0.89,
#   1.71,
#   3.73,
#   1.63,
#   4.92,
#   2.29,
#   2.22,
#   4,
#   1.46,
#   7.47,
#   1.03,
#   0.47,
#   2,
#   0.89,
#   6.85,
#   1.95,
#   5.07,
#   7.88,
#   4.35,
#   2.76,
#   7.08,
#   3.79,
#   6.49,
#   6.66,
#   5.51,
#   11.63,
#   1.79,
#   1.79,
#   3.64,
#   1.48,
#   1.46,
#   3.33,
#   4.12,
#   0.65,
#   1.55,
#   1.79,
#   1.22,
#   9.3,
#   0.71,
#   4.91,
#   1.51,
#   3.6,
#   1.37,
#   2.3,
#   4.33,
#   7.6,
#   6.71,
#   4.02,
#   1.57,
#   0.53,
#   1.06,
#   3.35,
#   4.12,
#   1.98,
#   4.12,
#   3.01,
#   4.63,
#   6.93,
#   3.62,
#   7.52,
#   0.25,
#   3.42,
#   0.87,
#   2.07,
#   2.18,
#   0.44,
#   1.95,
#   1.36,
#   2.06,
#   0.89,
#   9.47,
#   4.41,
#   7.61,
#   3.36,
#   0.73,
#   1.4,
#   0.89,
#   1.66,
#   1.12,
#   4.96,
#   4.09,
#   4.73,
#   5.27,
#   1.36,
#   5.13,
#   2.88,
#   4.39,
#   8.47,
#   3.96,
#   4.01,
#   8.23,
#   0.45,
#   3.12,
#   6.91,
#   9.28,
#   2.97,
#   9.61,
#   5.19,
#   3.42,
#   4.09,
#   8.57,
#   1.34,
#   1.47,
#   5.47,
#   4.63,
#   6.69,
#   1.82,
#   1.03,
#   3.45,
#   3.09,
#   4.58,
#   3.98,
#   4.48,
#   9.13,
#   2.91,
#   6.33,
#   0.96,
#   0.89,
#   4.63,
#   2.57,
#   2.19,
#   2.14,
#   3.6,
#   2.55]}

# %%
weather_df = pd.DataFrame(weather_dict)
weather_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Albany  42.6001  -73.9662    296.51        89         100
# 1  Bambous Virieux -20.3428   57.7575    293.27        62          79
# 2      Tuktoyaktuk  69.4541 -133.0374    275.09        84           5
# 3          Mataura -46.1927  168.8643    282.86        61          20
# 4         La Rioja  42.2500   -2.5000    283.73        95         100
#
#    Wind Speed
# 0        1.05
# 1        7.65
# 2        8.49
# 3        1.23
# 4        0.64

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(city_data_df['Lat'], city_data_df['Max Temp'])
plt.title(f'City Latitude vs. Max Temperature')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.grid(True)
plt.savefig('Max_temp.png')

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(city_data_df['Lat'], city_data_df['Humidity'])
plt.title(f'City Latitude vs. Humidity')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid(True)
plt.savefig('lat_humid.png')

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(city_data_df['Lat'], city_data_df['Cloudiness'])
plt.title(f'City Latitude vs. Cloudiness')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid(True)
plt.savefig('lat_clouds.png')

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(city_data_df['Lat'], city_data_df['Wind Speed'])
plt.title(f'City Latitude vs. Wind Speed')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.grid(True)
plt.savefig('lat_windspd.png')

# %% [markdown]
# ## Linear Regression

# %%
# Create a Scatter Plot for temperature vs latitude
x_values = city_data_df['Max Temp']
y_values = city_data_df['Lat']
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Max Temp (F)')
plt.show()

# %%
# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(city_data_df['Max Temp'],city_data_df['Lat'])

# Get regression values
regress_values = x_values * slope + intercept
print(regress_values)
# Out:
# 0      11.180358
# 1      16.243201
# 2      44.651378
# 3      32.509929
# 4      31.150462
#          ...
# 534     2.804789
# 535    10.852210
# 536    23.603075
# 537    14.399326
# 538     6.023758
# Name: Max Temp, Length: 539, dtype: float64

# %%
# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)
# Out:
# y = -1.56x +474.51

# %%
# Create Northern and Southern Hemisphere DataFrames
northeren_hemisphere = city_data_df[city_data_df["Lat"] >=0]
northern_cities_count =len(northeren_hemisphere)
print("There are {} cities in the northeren hemisphere out of {} cities total, representing {:.1%} of all cities in the data set."
       .format(northern_cities_count, city_left_count, (northern_cities_count/city_left_count)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-4d15185cc48e> in <module>
#       3 northern_cities_count =len(northeren_hemisphere)
#       4 print("There are {} cities in the northeren hemisphere out of {} cities total, representing {:.1%} of all cities in the data set."
# ----> 5        .format(northern_cities_count, city_left_count, (northern_cities_count/city_left_count)))
#
# NameError: name 'city_left_count' is not defined

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Create Plot
plt.scatter(x_values, y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Temperature')
plt.annotate(line_eq,(20,15),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.1770018798551769

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
