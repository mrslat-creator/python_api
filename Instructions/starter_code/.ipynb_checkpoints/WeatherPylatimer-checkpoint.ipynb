# %% [markdown]
# # WeatherPy
# Note
# Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from scipy import stats

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-7f974f159222> in <module>
#       1 # Dependencies and Setup
# ----> 2 import matplotlib.pyplot as plt
#       3 import pandas as pd
#       4 import numpy as np
#       5 import requests
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []
country_codes =[]

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.00, size=1500)
lat_lngs = zip(lats, lngs)
city = citipy

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 624

# %%
print(cities)
# Out:
# ['new norfolk', 'emmauss', 'hobart', 'havelock', 'codrington', 'punta arenas', 'asopos', 'samusu', 'ushuaia', 'tunduru', 'port alfred', 'thompson', 'butaritari', 'tiksi', 'havre-saint-pierre', 'ribeira grande', 'bredasdorp', 'ust-kamchatsk', 'aklavik', 'lapua', 'belushya guba', 'milazzo', 'cape town', 'sao joao do piaui', 'thessalon', 'nome', 'olinda', 'nizhneyansk', 'sao filipe', 'taolanaro', 'talnakh', 'los llanos de aridane', 'rikitea', 'puerto ayora', 'camana', 'carnarvon', 'khatanga', 'paracuru', 'loum', 'mathbaria', 'santiago del estero', 'bluff', 'bethel', 'fare', 'iqaluit', 'saint-francois', 'busselton', 'caravelas', 'ilsede', 'iwanai', 'saint-philippe', 'hithadhoo', 'am timan', 'mataura', 'mar del plata', 'yumen', 'illoqqortoormiut', 'barentsburg', 'tuatapere', 'yellowknife', 'cubulco', 'hermanus', 'kutoarjo', 'chokurdakh', 'marawi', 'caraquet', 'tuktoyaktuk', 'galiwinku', 'albany', 'jamestown', 'luderitz', 'vaini', 'calabozo', 'saint george', 'atuona', 'port blair', 'lucero', 'beringovskiy', 'upernavik', 'toora-khem', 'nikolskoye', 'lander', 'simpang', 'tamiahua', 'fort nelson', 'sakaiminato', 'aracati', 'poyarkovo', 'katsuura', 'kapaa', 'eureka', 'bambous virieux', 'iquitos', 'urdoma', 'barrow', 'arraial do cabo', 'lompoc', 'qaanaaq', 'sentyabrskiy', 'touba', 'fevralsk', 'port elizabeth', 'dandong', 'portsoy', 'andenes', 'kirakira', 'kaitangata', 'jinji', 'padang', 'ardakan', 'monrovia', 'cabo san lucas', 'enid', 'pevek', 'saleaula', 'tianpeng', 'tricase', 'henderson', 'calama', 'sao joao da barra', 'nanortalik', 'monzon', 'linxia', 'lebu', 'bara', 'auki', 'tukrah', 'tuscaloosa', 'tarata', 'tsihombe', 'semey', 'souillac', 'provideniya', 'castro', 'palana', 'mys shmidta', 'pitimbu', 'ancud', 'hambantota', 'vila velha', 'naze', 'westport', 'praia', 'yerbogachen', 'nguiu', 'flinders', 'lukang', 'hami', 'hay river', 'ngunguru', 'usinsk', 'mikuni', 'gunjur', 'wamba', 'dwarka', 'san joaquin', 'faanui', 'eha amufu', 'anito', 'otradnoye', 'georgetown', 'vila', 'esperance', 'anadyr', 'andilamena', 'songjianghe', 'taiyuan', 'neede', 'ahipara', 'soyo', 'naron', 'attawapiskat', 'truro', 'itarema', 'gat', 'labuhan', 'ambon', 'tasiilaq', 'byron bay', 'marcona', 'broome', 'farafangana', 'laranjeiras do sul', 'belle fourche', 'vitimskiy', 'sorland', 'klaksvik', 'santa isabel do rio negro', 'margate', 'sakakah', 'swan hill', 'hasaki', 'maumere', 'uyovu', 'morondava', 'chateaubelair', 'tautira', 'manadhoo', 'kot kapura', 'tabiauea', 'amderma', 'sitka', 'san pedro de ycuamandiyu', 'cloquet', 'sungaipenuh', 'rio verde de mato grosso', 'kruisfontein', 'garowe', 'longyearbyen', 'pangnirtung', 'iranshahr', 'geraldton', 'qasigiannguit', 'victoria', 'hilo', 'harper', 'arlit', 'suntar', 'deputatskiy', 'souris', 'porto novo', 'bandarbeyla', 'pedernales', 'valparaiso', 'slonim', 'laurens', 'tocopilla', 'nyurba', 'bengkulu', 'warrnambool', 'saint-georges', 'kavieng', 'tiruchchendur', 'basco', 'lavrentiya', 'mazamari', 'azrow', 'namibe', 'taywarah', 'monticello', 'east london', 'inhambane', 'selishche', 'ardmore', 'dingle', 'roald', 'aqtobe', 'ternate', 'espoo', 'kautokeino', 'longlac', 'rio grande', 'avarua', 'birjand', 'opuwo', 'przasnysz', 'mastic beach', 'fortuna', 'hokitika', 'rincon', 'alta', 'glendive', 'batagay-alyta', 'clearlake', 'bonthe', 'pacific grove', 'de-kastri', 'moerai', 'gobabis', 'bandar', 'mount isa', 'saint anthony', 'goderich', 'lebedyn', 'contamana', 'bilibino', 'ponta do sol', 'sangar', 'sosva', 'itoman', 'port hardy', 'vegreville', 'la canada', 'poso', 'voyvozh', 'labutta', 'panzhihua', 'north bend', 'naukot', 'severo-kurilsk', 'pisco', 'syamzha', 'touros', 'aromashevo', 'pangody', 'kavaratti', 'alofi', 'samalaeulu', 'heimberg', 'zhaotong', 'lolua', 'sharya', 'nalut', 'namatanai', 'vestmanna', 'thap than', 'petropavlovsk-kamchatskiy', 'novikovo', 'skibbereen', 'te anau', 'muisne', 'dogbo', 'samarai', 'vyritsa', 'grand gaube', 'srednekolymsk', 'moose factory', 'peniche', 'kamaishi', 'salalah', 'barinitas', 'artyom', 'giz ...

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?q="

# Data list of Cities
city_list = []
lat_list = []
lng_list = []
max_temp_list = []
humidity_list = []
cloudiness_list = []
windspeed_list = []
date = []
counter = 0
record_counter = 0
setcount = 1


for city in cities:
    counter += 1
    if (counter % 50 == 0):
        setcount += 1
        record_counter =0
        print(setcount)
        print(record_counter)
        print(counter)
    record_counter += 1
    print("processing record" + str(record_counter) +"of Set" + str(setcount) +"|" +city)
    try: 
        weather_response = requests.get(f"{url}{city}&appid={weather_api_key}").json()
        city_list.append(weather_response['name'])
        lat_list.append(weather_response['coord']['lat'])
        lng_list.append(weather_response['coord']['lon'])
        max_temp_list.append(weather_response['main']['temp_max'])
        humidity_list.append(weather_response['main']['humidity'])
        cloudiness_list.append(weather_response['clouds']['all'])
        windspeed_list.append(weather_response['wind']['speed'])
    except:
        print("City Not Found, Pass...:" + city)

        
print(len(weather_response))
# Out:
# processing record1of Set1|new norfolk
# processing record2of Set1|emmauss
# processing record3of Set1|hobart
# processing record4of Set1|havelock
# processing record5of Set1|codrington
# processing record6of Set1|punta arenas
# processing record7of Set1|asopos
# processing record8of Set1|samusu
# City Not Found, Pass...:samusu
# processing record9of Set1|ushuaia
# processing record10of Set1|tunduru
# City Not Found, Pass...:tunduru
# processing record11of Set1|port alfred
# processing record12of Set1|thompson
# processing record13of Set1|butaritari
# processing record14of Set1|tiksi
# processing record15of Set1|havre-saint-pierre
# processing record16of Set1|ribeira grande
# processing record17of Set1|bredasdorp
# processing record18of Set1|ust-kamchatsk
# City Not Found, Pass...:ust-kamchatsk
# processing record19of Set1|aklavik
# processing record20of Set1|lapua
# processing record21of Set1|belushya guba
# City Not Found, Pass...:belushya guba
# processing record22of Set1|milazzo
# processing record23of Set1|cape town
# processing record24of Set1|sao joao do piaui
# processing record25of Set1|thessalon
# processing record26of Set1|nome
# processing record27of Set1|olinda
# processing record28of Set1|nizhneyansk
# City Not Found, Pass...:nizhneyansk
# processing record29of Set1|sao filipe
# processing record30of Set1|taolanaro
# City Not Found, Pass...:taolanaro
# processing record31of Set1|talnakh
# processing record32of Set1|los llanos de aridane
# processing record33of Set1|rikitea
# processing record34of Set1|puerto ayora
# processing record35of Set1|camana
# processing record36of Set1|carnarvon
# processing record37of Set1|khatanga
# processing record38of Set1|paracuru
# processing record39of Set1|loum
# processing record40of Set1|mathbaria
# processing record41of Set1|santiago del estero
# processing record42of Set1|bluff
# processing record43of Set1|bethel
# processing record44of Set1|fare
# processing record45of Set1|iqaluit
# processing record46of Set1|saint-francois
# processing record47of Set1|busselton
# processing record48of Set1|caravelas
# processing record49of Set1|ilsede
# 2
# 0
# 50
# processing record1of Set2|iwanai
# processing record2of Set2|saint-philippe
# processing record3of Set2|hithadhoo
# processing record4of Set2|am timan
# processing record5of Set2|mataura
# processing record6of Set2|mar del plata
# processing record7of Set2|yumen
# processing record8of Set2|illoqqortoormiut
# City Not Found, Pass...:illoqqortoormiut
# processing record9of Set2|barentsburg
# City Not Found, Pass...:barentsburg
# processing record10of Set2|tuatapere
# processing record11of Set2|yellowknife
# processing record12of Set2|cubulco
# processing record13of Set2|hermanus
# processing record14of Set2|kutoarjo
# processing record15of Set2|chokurdakh
# processing record16of Set2|marawi
# processing record17of Set2|caraquet
# processing record18of Set2|tuktoyaktuk
# processing record19of Set2|galiwinku
# City Not Found, Pass...:galiwinku
# processing record20of Set2|albany
# processing record21of Set2|jamestown
# processing record22of Set2|luderitz
# processing record23of Set2|vaini
# processing record24of Set2|calabozo
# processing record25of Set2|saint george
# processing record26of Set2|atuona
# processing record27of Set2|port blair
# processing record28of Set2|lucero
# processing record29of Set2|beringovskiy
# processing record30of Set2|upernavik
# processing record31of Set2|toora-khem
# processing record32of Set2|nikolskoye
# processing record33of Set2|lander
# processing record34of Set2|simpang
# processing record35of Set2|tamiahua
# processing record36of Set2|fort nelson
# processing record37of Set2|sakaiminato
# processing record38of Set2|aracati
# processing record39of Set2|poyarkovo
# processing record40of Set2|katsuura
# processing record41of Set2|kapaa
# processing record42of Set2|eureka
# processing record43of Set2|bambous virieux
# processing record44of Set2|iquitos
# processing record45of Set2|urdoma
# processing record46of Set2|barrow
# processing record47of Set2|arraial do cabo
# processing record48of Set2|lompoc
# processing record49of Set2|qaanaaq
# processing record50of Set2|sentyabrskiy
# City Not Found, Pass...:sentyabrskiy
# 3
# 0
# 100
# processing record1of Set3|touba
# processing record2of Set3|fevralsk
# City Not Found, Pass...:fevralsk
# processing record3of Set3|port elizabeth
# processing record4of Set3|dandong
# processing record5of Set3|portsoy
# processing record6of Set3|andenes
# processing record7of Set3|kirakira
# processing record8of Set3|kaitangata
# processing record9of Set3|jinji
# processing record10of Set3|padang
# processing record11of Set3|ardakan
# processing record12of Set3|monrovia
# processing record13of Set3|cabo san lucas
# processing record14of Set3|enid
# processing record15of Set3|pevek
# processing record16of Set3|saleaula
# City Not Found, Pass...:saleaula
# processing record17of Set3|tianpeng
# processing record18of Set3|tricase
# processing record19of Set3|henderson
# processing record20of Set3|calama
# processing record21of Set3|sao joao da barra
# processing record22of Set3|nanortalik
# processing record23of Set3|monzon
# processing record24of Set3|linxia
# processing record25of Set3|lebu
# processing record26of Set3|bara
# processing record27of Set3|auki
# processing record28of Set3|tukrah
# processing record29of Set3|tuscaloosa
# processing record30of Set3|tarata
# processing record31of Set3|tsihombe
# City Not Found, Pass...:tsihombe
# processing record32of Set3|semey
# processing record33of Set3|souillac
# processing record34of Set3|provideniya
# processing record35of Set3|castro
# processing record36of Set3|palana
# processing record37of Set3|mys shmidta
# City Not Found, Pass...:mys shmidta
# processing record38of Set3|pitimbu
# processing record39of Set3|ancud
# processing record40of Set3|hambantota
# processing record41of Set3|vila velha
# processing record42of Set3|naze
# processing record43of Set3|westport
# processing record44of Set3|praia
# processing record45of Set3|yerbogachen
# processing record46of Set3|nguiu
# City Not Found, Pass...:nguiu
# processing record47of Set3|flinders
# processing record48of Set3|lukang
# processing record49of Set3|hami
# processing record50of Set3|hay river
# 4
# 0
# 150
# processing record1of Set4|ngunguru
# processing record2of Set4|usinsk
# processing record3of Set4|mikuni
# processing record4of Set4|gunjur
# processing record5of Set4|wamba
# processing record6of Set4|dwarka
# processing record7of Set4|san joaquin
# processing record8of Set4|faanui
# processing record9of Set4|eha amufu
# processing record10of Set4|anito
# processing record11of Set4|otradnoye
# processing record12of Set4|georgetown
# processing record13of Set4|vila
# processing record14of Set4|esperance
# processing record15of Set4|anadyr
# processing record16of Set4|andilamena
# processing record17of Set4|songjianghe
# processing record18of Set4|taiyuan
# processing record19of Set4|neede
# processing record20of Set4|ahipara
# processing record21of Set4|soyo
# processing record22of Set4|naron
# processing record23of Set4|attawapiskat
# City Not Found, Pass...:attawapiskat
# processing record24of Set4|truro
# processing record25of Set4|itarema
# processing record26of Set4|gat
# processing record27of Set4|labuhan
# processing record28of Set4|ambon
# processing record29of Set4|tasiilaq
# processing record30of Set4|byron bay
# processing record31of Set4|marcona
# City Not Found, Pass...:marcona
# processing record32of Set4|broome
# processing record33of Set4|farafangana
# processing record34of Set4|laranjeiras do sul
# processing record35of Set4|belle fourche
# processing record36of Set4|vitimskiy
# City Not Found, Pass...:vitimskiy
# processing record37of Set4|sorland
# processing record38of Set4|klaksvik
# processing record39of Set4|santa isabel do rio negro
# processing record40of Set4|margate
# processing record41of Set4|sakakah
# processing record42of Set4|swan hill
# processing record43of Set4|hasaki
# processing record44of Set4|maumere
# processing record45of Set4|uyovu
# processing record46of Set4|morondava
# processing record47of Set4|chateaubelair
# processing record48of Set4|tautira
# processing record49of Set4|manadhoo
# processing record50of Set4|kot kapura
# 5
# 0
# 200
# processing record1of Set5|tabiauea
# City Not Found, Pass...:tabiauea
# processing record2of Set5|amderma
# City Not Found, Pass...:amderma
# processing record3of Set5|sitka
# processing record4of Set5|san pedro de ycuamandiyu
# processing record5of Set5|cloquet
# processing record6of Set5|sungaipenuh
# processing record7of Set5|rio verde de mato grosso
# processing record8of Set5|kruisfontein
# processing record9of Set5|garowe
# processing record10of Set5|longyearbyen
# processing record11of Set5|pangnirtung
# processing record12of Set5|iranshahr
# processing record13of Set5|geraldton
# processing record14of Set5|qasigiannguit
# processing record15of Set5|victoria
# processing record16of Set5|hilo
# processing record17of Set5|harper
# processing record18of Set5|arlit
# processing record19of Set5|suntar
# processing record20of Set5|deputatskiy
# processing record21of Set5|souris
# processing record22of Set5|porto novo
# processing record23of Set5|bandarbeyla
# processing record24of Set5|pedernales
# processing record25of Set5|valparaiso
# processing record26of Set5|slonim
# processing record27of Set5|laurens
# processing record28of Set5|tocopilla
# processing record29of Set5|nyurba
# processing record30of Set5|bengkulu
# processing record31of Set5|warrnambool
# processing record32of Set5|saint-georges
# processing record33of Set5|kavieng
# processing record34of Set5|tiruchchendur
# processing record35of Set5|basco
# processing record36of Set5|lavrentiya
# processing record37of Set5|mazamari
# processing record38of Set5|azrow
# City Not Found, Pass...:azrow
# processing record39of Set5|namibe
# processing record40of Set5|taywarah
# processing record41of Set5|monticello
# processing record42of Set5|east london
# processing record43of Set5|inhambane
# processing record44of Set5|selishche
# processing record45of Set5|ardmore
# processing record46of Set5|dingle
# processing record47of Set5|roald
# processing record48of Set5|aqtobe
# processing record49of Set5|ternate
# processing record50of Set5|espoo
# 6
# 0
# 250
# processing record1of Set6|kautokeino
# processing record2of Set6|longlac
# City Not Found, Pass...:longlac
# processing record3of Set6|rio grande
# processing record4of Set6|avarua
# processing record5of Set6|birjand
# processing record6of Set6|opuwo
# processing record7of Set6|przasnysz
# processing record8of Set6|mastic beach
# processing record9of Set6|fortuna
# processing record10of Set6|hokitika
# processing record11of Set6|rincon
# processing record12of Set6|alta
# processing record13of Set6|glendive
# processing record14of Set6|batagay-alyta
# processing record15of Set6|clearlake
# processing record16of Set6|bonthe
# processing record17of Set6|pacific grove
# processing record18of Set6|de-kastri
# processing record19of Set6|moerai
# processing record20of Set6|gobabis
# processing record21of Set6|bandar
# processing record22of Set6|mount isa
# processing record23of Set6|saint anthony
# processing record24of Set6|goderich
# processing record25of Set6|lebedyn
# processing record26of Set6|contamana
# processing record27of Set6|bilibino
# processing record28of Set6|ponta do sol
# processing record29of Set6|sangar
# processing record30of Set6|sosva
# processing record31of Set6|itoman
# processing record32of Set6|port hardy
# processing record33of Set6|vegreville
# processing record34of Set6|la canada
# processing record35of Set6|poso
# processing record36of Set6|voyvozh
# processing record37of Set6|labutta
# City Not Found, Pass...:labutta
# processing record38of Set6|panzhihua
# processing record39of Set6|north bend
# processing record40of Set6|naukot
# processing record41of Set6|severo-kurilsk
# processing record42of Set6|pisco
# processing record43of Set6|syamzha
# processing record44of Set6|touros
# processing record45of Set6|aromashevo
# processing record46of Set6|pangody
# processing record47of Set6|kavaratti
# processing record48of Set6|alofi
# processing record49of Set6|samalaeulu
# City Not Found, Pass...:samalaeulu
# processing record50of Set6|heimberg
# 7
# 0
# 300
# processing record1of Set7|zhaotong
# processing record2of Set7|lolua
# City Not Found, Pass...:lolua
# processing record3of Set7|sharya
# processing record4of Set7|nalut
# processing record5of Set7|namatanai
# processing record6of Set7|vestmanna
# processing record7of Set7|thap than
# processing record8of Set7|petropavlovsk-kamchatskiy
# processing record9of Set7|novikovo
# processing record10of Set7|skibbereen
# processing record11of Set7|te anau
# processing record12of Set7|muisne
# processing record13of Set7|dogbo
# processing record14of Set7|samarai
# processing record15of Set7|vyritsa
# processing record16of Set7|grand gaube
# processing record17of Set7|srednekolymsk
# processing record18of Set7|moose factory
# processing record19of Set7|peniche
# processing record20of Set7|kamaishi
# processing record21of Set7|salalah
# processing record22of Set7|barinitas
# processing record23of Set7|artyom
# processing record24of Set7|gizo
# processing record25of Set7|fort-shevchenko
# processing record26of Set7|khani
# processing record27of Set7|chuy
# processing record28of Set7|axim
# processing record29of Set7|vao
# processing record30of Set7|doctor pedro p. pena
# City Not Found, Pass...:doctor pedro p. pena
# processing record31of Set7|formoso do araguaia
# City Not Found, Pass...:formoso do araguaia
# processing record32of Set7|zolotinka
# City Not Found, Pass...:zolotinka
# processing record33of Set7|gondanglegi
# processing record34of Set7|cherskiy
# processing record35of Set7|wuhan
# processing record36of Set7|amudat
# processing record37of Set7|zykovo
# processing record38of Set7|vinh
# processing record39of Set7|dikson
# processing record40of Set7|daru
# processing record41of Set7|borovskoy
# processing record42of Set7|skegness
# processing record43of Set7|tura
# processing record44of Set7|bilma
# processing record45of Set7|sinegorsk
# processing record46of Set7|saint-augustin
# processing record47of Set7|aden
# processing record48of Set7|mogadishu
# processing record49of Set7|bijie
# processing record50of Set7|sinnamary
# 8
# 0
# 350
# processing record1of Set8|lake cowichan
# processing record2of Set8|tessalit
# processing record3of Set8|vagur
# processing record4of Set8|belyy yar
# processing record5of Set8|belur
# processing record6of Set8|arona
# processing record7of Set8|kilcullen
# processing record8of Set8|skagastrond
# City Not Found, Pass...:skagastrond
# processing record9of Set8|liverpool
# processing record10of Set8|narsaq
# processing record11of Set8|rupert
# processing record12of Set8|kodiak
# processing record13of Set8|richards bay
# processing record14of Set8|jacareacanga
# processing record15of Set8|dunda
# processing record16of Set8|novaya zaimka
# processing record17of Set8|karaul
# City Not Found, Pass...:karaul
# processing record18of Set8|lufilufi
# processing record19of Set8|bombay
# processing record20of Set8|emerald
# processing record21of Set8|teguldet
# processing record22of Set8|baldeogarh
# processing record23of Set8|kuche
# City Not Found, Pass...:kuche
# processing record24of Set8|fort morgan
# processing record25of Set8|entre rios
# processing record26of Set8|ranong
# processing record27of Set8|kastamonu
# processing record28of Set8|lovec
# City Not Found, Pass...:lovec
# processing record29of Set8|soe
# processing record30of Set8|tahta
# processing record31of Set8|djang
# City Not Found, Pass...:djang
# processing record32of Set8|puerto gaitan
# processing record33of Set8|portachuelo
# processing record34of Set8|kaeo
# processing record35of Set8|fernley
# processing record36of Set8|lavara
# processing record37of Set8|nesna
# processing record38of Set8|laguna
# processing record39of Set8|lashio
# processing record40of Set8|dipkarpaz
# City Not Found, Pass...:dipkarpaz
# processing record41of Set8|kloulklubed
# processing record42of Set8|ouegoa
# processing record43of Set8|mahebourg
# processing record44of Set8|porbandar
# processing record45of Set8|rayevskaya
# processing record46of Set8|puerto escondido
# processing record47of Set8|beloha
# processing record48of Set8|poum
# processing record49of Set8|escanaba
# processing record50of Set8|chase
# 9
# 0
# 400
# processing record1of Set9|maceio
# processing record2of Set9|lasa
# processing record3of Set9|dunedin
# processing record4of Set9|umzimvubu
# City Not Found, Pass...:umzimvubu
# processing record5of Set9|maragogi
# processing record6of Set9|ponta delgada
# processing record7of Set9|azangaro
# processing record8of Set9|corner brook
# processing record9of Set9|qarchi gak
# processing record10of Set9|isangel
# processing record11of Set9|san patricio
# processing record12of Set9|tibati
# processing record13of Set9|sungairaya
# processing record14of Set9|reporoa
# processing record15of Set9|woodward
# processing record16of Set9|vacha
# processing record17of Set9|nata
# processing record18of Set9|ola
# processing record19of Set9|port macquarie
# processing record20of Set9|korla
# processing record21of Set9|ilam
# processing record22of Set9|gornyy
# processing record23of Set9|hobyo
# processing record24of Set9|constitucion
# processing record25of Set9|strzelin
# processing record26of Set9|cayenne
# processing record27of Set9|camacha
# processing record28of Set9|necochea
# processing record29of Set9|kahului
# processing record30of Set9|san luis
# processing record31of Set9|sulangan
# processing record32of Set9|sibolga
# processing record33of Set9|hovd
# processing record34of Set9|cidreira
# processing record35of Set9|zhovtneve
# processing record36of Set9|orlik
# processing record37of Set9|rapid city
# processing record38of Set9|rock springs
# processing record39of Set9|san cristobal
# processing record40of Set9|irbeyskoye
# processing record41of Set9|hofn
# processing record42of Set9|asyut
# processing record43of Set9|grindavik
# processing record44of Set9|lorengau
# processing record45of Set9|saskylakh
# processing record46of Set9|niquelandia
# processing record47of Set9|buchanan
# processing record48of Set9|flin flon
# processing record49of Set9|san juan del sur
# processing record50of Set9|kiruna
# 10
# 0
# 450
# processing record1of Set10|moussoro
# processing record2of Set10|sindang
# processing record3of Set10|sao jose da coroa grande
# processing record4of Set10|olafsvik
# processing record5of Set10|umm kaddadah
# processing record6of Set10|camopi
# processing record7of Set10|ecoporanga
# processing record8of Set10|dalvik
# processing record9of Set10|uruzgan
# processing record10of Set10|tecoanapa
# processing record11of Set10|tingi
# processing record12of Set10|port lincoln
# processing record13of Set10|grand river south east
# City Not Found, Pass...:grand river south east
# processing record14of Set10|saldanha
# processing record15of Set10|college
# processing record16of Set10|clyde river
# processing record17of Set10|norman wells
# processing record18of Set10|aquiraz
# processing record19of Set10|staryy nadym
# processing record20of Set10|marsh harbour
# processing record21of Set10|tanete
# processing record22of Set10|ankazoabo
# processing record23of Set10|aflu
# City Not Found, Pass...:aflu
# processing record24of Set10|rocha
# processing record25of Set10|batsfjord
# processing record26of Set10|wukari
# processing record27of Set10|clevelandia
# processing record28of Set10|paracale
# processing record29of Set10|tourlaville
# processing record30of Set10|zelenogorskiy
# processing record31of Set10|aswan
# processing record32of Set10|chatham
# processing record33of Set10|santa marta
# processing record34of Set10|severnyy
# processing record35of Set10|chutove
# processing record36of Set10|vardo
# processing record37of Set10|charlestown
# processing record38of Set10|reconquista
# processing record39of Set10|moron
# processing record40of Set10|sibu
# processing record41of Set10|lagoa
# processing record42of Set10|ilulissat
# processing record43of Set10|banda aceh
# processing record44of Set10|hoi an
# processing record45of Set10|lincoln
# processing record46of Set10|walvis bay
# processing record47of Set10|kutum
# processing record48of Set10|mago
# processing record49of Set10|vermillion
# processing record50of Set10|warqla
# City Not Found, Pass...:warqla
# 11
# 0
# 500
# processing record1of Set11|mount hagen
# processing record2of Set11|cabedelo
# processing record3of Set11|baie-saint-paul
# processing record4of Set11|guadalupe y calvo
# processing record5of Set11|piacabucu
# processing record6of Set11|komsomolskiy
# processing record7of Set11|charyshskoye
# processing record8of Set11|julana
# City Not Found, Pass...:julana
# processing record9of Set11|sembakung
# processing record10of Set11|sangamner
# processing record11of Set11|zemio
# processing record12of Set11|chibombo
# processing record13of Set11|solnechnyy
# processing record14of Set11|lethem
# processing record15of Set11|la ronge
# processing record16of Set11|porangatu
# processing record17of Set11|lanivtsi
# processing record18of Set11|mao
# processing record19of Set11|calca
# processing record20of Set11|hamilton
# processing record21of Set11|rodrigues alves
# processing record22of Set11|mujiayingzi
# processing record23of Set11|torbay
# processing record24of Set11|panaba
# processing record25of Set11|antofagasta
# processing record26of Set11|kununurra
# processing record27of Set11|mitsamiouli
# processing record28of Set11|gorontalo
# processing record29of Set11|seoul
# processing record30of Set11|dehri
# processing record31of Set11|benicarlo
# processing record32of Set11|pakxan
# processing record33of Set11|mombetsu
# processing record34of Set11|sisimiut
# processing record35of Set11|zyryanka
# processing record36of Set11|yirol
# City Not Found, Pass...:yirol
# processing record37of Set11|omboue
# processing record38of Set11|whitianga
# processing record39of Set11|xaxim
# processing record40of Set11|comodoro rivadavia
# processing record41of Set11|marquette
# processing record42of Set11|talcahuano
# processing record43of Set11|kennett
# processing record44of Set11|cortez
# processing record45of Set11|zhezkazgan
# processing record46of Set11|henties bay
# processing record47of Set11|qujing
# processing record48of Set11|senneterre
# processing record49of Set11|odesskoye
# processing record50of Set11|evanston
# 12
# 0
# 550
# processing record1of Set12|honiara
# processing record2of Set12|high rock
# processing record3of Set12|toliary
# City Not Found, Pass...:toliary
# processing record4of Set12|kamenskoye
# City Not Found, Pass...:kamenskoye
# processing record5of Set12|pajapan
# processing record6of Set12|pochutla
# processing record7of Set12|chapais
# processing record8of Set12|merauke
# processing record9of Set12|assiniboia
# processing record10of Set12|tilichiki
# processing record11of Set12|santo domingo
# processing record12of Set12|rungata
# City Not Found, Pass...:rungata
# processing record13of Set12|tawang
# processing record14of Set12|leningradskiy
# processing record15of Set12|greensburg
# processing record16of Set12|okhotsk
# processing record17of Set12|along
# processing record18of Set12|vaitupu
# City Not Found, Pass...:vaitupu
# processing record19of Set12|bulgan
# processing record20of Set12|sao miguel do araguaia
# processing record21of Set12|nieuw amsterdam
# processing record22of Set12|jambi
# processing record23of Set12|sinkat
# City Not Found, Pass...:sinkat
# processing record24of Set12|kaniama
# processing record25of Set12|borovoy
# processing record26of Set12|krasnoarmeysk
# processing record27of Set12|kalanchak
# processing record28of Set12|alamos
# processing record29of Set12|wolgast
# processing record30of Set12|road town
# processing record31of Set12|belomorsk
# processing record32of Set12|nanakuli
# processing record33of Set12|sainte-marie
# processing record34of Set12|bicester
# processing record35of Set12|pudozh
# processing record36of Set12|sambava
# processing record37of Set12|kayseri
# processing record38of Set12|burgos
# processing record39of Set12|canico
# processing record40of Set12|palmerston
# processing record41of Set12|ginda
# processing record42of Set12|kasongo-lunda
# processing record43of Set12|okha
# processing record44of Set12|awbari
# processing record45of Set12|manokwari
# processing record46of Set12|teya
# processing record47of Set12|khonuu
# City Not Found, Pass...:khonuu
# processing record48of Set12|syracuse
# processing record49of Set12|atar
# processing record50of Set12|ballina
# 13
# 0
# 600
# processing record1of Set13|ayorou
# processing record2of Set13|balkhash
# processing record3of Set13|verkhoyansk
# processing record4of Set13|totness
# processing record5of Set13|thinadhoo
# processing record6of Set13|biloela
# processing record7of Set13|pemba
# processing record8of Set13|salinas
# processing record9of Set13|lexington
# processing record10of Set13|lebyazhye
# processing record11of Set13|nishihara
# processing record12of Set13|tornio
# processing record13of Set13|nantucket
# processing record14of Set13|meridian
# processing record15of Set13|airai
# processing record16of Set13|vestmannaeyjar
# processing record17of Set13|san policarpo
# processing record18of Set13|mutsamudu
# City Not Found, Pass...:mutsamudu
# processing record19of Set13|porto-vecchio
# processing record20of Set13|haines junction
# processing record21of Set13|venado tuerto
# processing record22of Set13|ekibastuz
# processing record23of Set13|kangaatsiaq
# processing record24of Set13|gushikawa
# processing record25of Set13|adrar
# 13

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Creating a DataFrame
city_data_df = pd.DataFrame({"City":city_list,
                         "Lat":lat_list,
                         "Lng":lng_list,
                         "Max Temp":max_temp_list,
                         "Humidity":humidity_list,
                         "Cloudiness":cloudiness_list,
                         "Wind Speed":windspeed_list,
                            })

pd.DataFrame.to_csv(city_data_df, 'city_data.csv')

city_data_df.head()
# city_data_df.count()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed
# 0  New Norfolk -42.7826  147.0587    287.43        52          25        2.24
# 1       Emmaus  56.7805   36.1150    288.58        89          99        4.42
# 2       Hobart -42.8794  147.3294    287.62        49          40        0.89
# 3     Havelock  34.8791  -76.9013    293.12        78           1        0.00
# 4   Codrington -38.2667  141.9667    287.95        70          97        3.23

# %%
weather_dict = {"City":city_list,
                         "Lat":lat_list,
                         "Lng":lng_list,
                         "Max Temp":max_temp_list,
                         "Humidity":humidity_list,
                         "Cloudiness":cloudiness_list,
                         "Wind Speed":windspeed_list,
}
weather_dict
# Out:
# {'City': ['New Norfolk',
#   'Emmaus',
#   'Hobart',
#   'Havelock',
#   'Codrington',
#   'Punta Arenas',
#   'Asopós',
#   'Ushuaia',
#   'Port Alfred',
#   'Thompson',
#   'Butaritari',
#   'Tiksi',
#   'Havre-St-Pierre',
#   'Ribeira Grande',
#   'Bredasdorp',
#   'Aklavik',
#   'Lapua',
#   'Milazzo',
#   'Cape Town',
#   'São João do Piauí',
#   'Thessalon',
#   'Nome',
#   'Olinda',
#   'São Filipe',
#   'Talnakh',
#   'Los Llanos de Aridane',
#   'Rikitea',
#   'Puerto Ayora',
#   'Camaná',
#   'Carnarvon',
#   'Khatanga',
#   'Paracuru',
#   'Loum',
#   'Mathbaria',
#   'Santiago del Estero',
#   'Bluff',
#   'Bethel',
#   'Fare',
#   'Iqaluit',
#   'Saint-François',
#   'Busselton',
#   'Caravelas',
#   'Ilsede',
#   'Iwanai',
#   'Saint-Philippe',
#   'Hithadhoo',
#   'Am Timan',
#   'Mataura',
#   'Mar del Plata',
#   'Yumen',
#   'Tuatapere',
#   'Yellowknife',
#   'Cubulco',
#   'Hermanus',
#   'Kutoarjo',
#   'Chokurdakh',
#   'Marawi',
#   'Caraquet',
#   'Tuktoyaktuk',
#   'Albany',
#   'Jamestown',
#   'Lüderitz',
#   'Vaini',
#   'Calabozo',
#   'Saint George',
#   'Atuona',
#   'Port Blair',
#   'Lucero',
#   'Beringovskiy',
#   'Upernavik',
#   'Toora-Khem',
#   'Nikolskoye',
#   'Lander',
#   'Simpang',
#   'Tamiahua',
#   'Fort Nelson',
#   'Sakaiminato',
#   'Aracati',
#   'Poyarkovo',
#   'Katsuura',
#   'Kapaa',
#   'Eureka',
#   'Bambous Virieux',
#   'Iquitos',
#   'Urdoma',
#   'Barrow',
#   'Arraial do Cabo',
#   'Lompoc',
#   'Qaanaaq',
#   'Touba',
#   'Port Elizabeth',
#   'Dandong',
#   'Portsoy',
#   'Andenes',
#   'Kirakira',
#   'Kaitangata',
#   'Jinji',
#   'Padang',
#   'Ardakān',
#   'Monrovia',
#   'Cabo San Lucas',
#   'Enid',
#   'Pevek',
#   'Tianpeng',
#   'Tricase',
#   'Henderson',
#   'Calama',
#   'São João da Barra',
#   'Nanortalik',
#   'Monzón',
#   'Linxia Chengguanzhen',
#   'Lebu',
#   'Bara',
#   'Auki',
#   'Tūkrah',
#   'Tuscaloosa',
#   'Tarata',
#   'Semey',
#   'Souillac',
#   'Provideniya',
#   'Castro',
#   'Palana',
#   'Pitimbu',
#   'Ancud',
#   'Hambantota',
#   'Vila Velha',
#   'Naze',
#   'Westport',
#   'Praia',
#   'Yerbogachën',
#   'Flinders',
#   'Lukang',
#   'Kumul',
#   'Hay River',
#   'Ngunguru',
#   'Usinsk',
#   'Mikuni',
#   'Gunjur',
#   'Wamba',
#   'Dwārka',
#   'San Joaquin',
#   'Faanui',
#   'Eha Amufu',
#   'Anito',
#   'Otradnoye',
#   'George Town',
#   'Vila',
#   'Esperance',
#   'Anadyr',
#   'Andilamena',
#   'Songjianghe',
#   'Taiyuan',
#   'Neede',
#   'Ahipara',
#   'Soyo',
#   'Narón',
#   'Truro',
#   'Itarema',
#   'Kiryat Gat',
#   'Labuhan',
#   'Ambon City',
#   'Tasiilaq',
#   'Byron Bay',
#   'Broome',
#   'Farafangana',
#   'Laranjeiras do Sul',
#   'Belle Fourche',
#   'Sørland',
#   'Klaksvík',
#   'Santa Isabel Rio Negro',
#   'Margate',
#   'Sakakah',
#   'Swan Hill',
#   'Hasaki',
#   'Maumere',
#   'Uyovu',
#   'Morondava',
#   'Chateaubelair',
#   'Tautira',
#   'Manadhoo',
#   'Kot Kapūra',
#   'Sitka',
#   'San Pedro de Ycuamandiyú',
#   'Cloquet',
#   'Sungai Penuh',
#   'Rio Verde de Mato Grosso',
#   'Kruisfontein',
#   'Garoowe',
#   'Longyearbyen',
#   'Pangnirtung',
#   'Iranshahr',
#   'Geraldton',
#   'Qasigiannguit',
#   'Hong Kong',
#   'Hilo',
#   'Harper',
#   'Arlit',
#   'Suntar',
#   'Deputatsky',
#   'Souris',
#   'Porto-Novo',
#   'Bandarbeyla',
#   'Pedernales',
#   'Valparaíso',
#   'Slonim',
#   'Laurens',
#   'Tocopilla',
#   'Nyurba',
#   'Bengkulu',
#   'Warrnambool',
#   "St. George's",
#   'Kavieng',
#   'Tiruchchendur',
#   'Basco',
#   'Lavrentiya',
#   'Mazamari',
#   'Mossamedes',
#   'Taywarah',
#   'Monticello',
#   'East London',
#   'Inhambane',
#   'Selishche',
#   'Ardmore',
#   'Dingle',
#   'Roald',
#   'Aktobe',
#   'Ternate',
#   'Espoo',
#   'Kautokeino',
#   'Rio Grande',
#   'Avarua',
#   'Birjand',
#   'Opuwo',
#   'Przasnysz',
#   'Mastic Beach',
#   'Fortuna',
#   'Hokitika',
#   'Rincon',
#   'Alta',
#   'Glendive',
#   'Batagay-Alyta',
#   'Clearlake',
#   'Bonthe',
#   'Pacific Grove',
#   'De-Kastri',
#   'Moerai',
#   'Gobabis',
#   'Bandar',
#   'Mount Isa',
#   'Saint Anthony',
#   'Goderich',
#   'Lebedyn',
#   'Contamana',
#   'Bilibino',
#   'Ponta do Sol',
#   'Sangar',
#   "Sos'va",
#   'Itoman',
#   'Port Hardy',
#   'Vegreville',
#   'La Cañada',
#   'Poso',
#   'Voyvozh',
#   'Panzhihua',
#   'North Bend',
#   'Naukot',
#   "Severo-Kuril'sk",
#   'Pisco',
#   'Syamzha',
#   'Touros',
#   'Aromashevo',
#   'Pangody',
#   'Kavaratti',
#   'Alofi',
#   'Heimberg',
#   'Zhaotong',
#   "Shar'ya",
#   'Nālūt',
#   'Namatanai',
#   'Vestmanna',
#   'Thap Than',
#   'Petropavlovsk-Kamchatskiy',
#   'Novikovo',
#   'Skibbereen',
#   'Te Anau',
#   'Muisne',
#   'Dogbo',
#   'Samarai',
#   'Vyritsa',
#   'Grand Gaube',
#   'Srednekolymsk',
#   'Moose Factory',
#   'Peniche',
#   'Kamaishi',
#   'Salalah',
#   'Barinitas',
#   'Artyom',
#   'Gizo Government Station',
#   'Fort-Shevchenko',
#   'Khani',
#   'Chui',
#   'Esim',
#   'Vao',
#   'Gondanglegi',
#   'Cherskiy',
#   'Wuhan',
#   'Amudat',
#   'Zykovo',
#   'Vinh',
#   'Dikson',
#   'Daru',
#   'Borovskoy',
#   'Skegness',
#   'Tura',
#   'Bilma',
#   'Sinegorsk',
#   'Saint-Augustin',
#   'Aden',
#   'Mogadishu',
#   'Bijie',
#   'Sinnamary',
#   'Lake Cowichan',
#   'Tessalit',
#   'Vágur',
#   'Belyy Yar',
#   'Belūr',
#   'Arona',
#   'Kilcullen',
#   'Liverpool',
#   'Narsaq',
#   'Rupert',
#   'Saint Paul Harbor',
#   'Richards Bay',
#   'Jacareacanga',
#   'Dunda',
#   'Novozaimka',
#   'Lufilufi',
#   'Mumbai',
#   'Emerald',
#   "Tegul'det",
#   'Baldeogarh',
#   'Fort Morgan',
#   'Entre Rios',
#   'Ranong',
#   'Kastamonu Province',
#   'Soe',
#   'Ţahţā',
#   'Puerto Gaitán',
#   'Portachuelo',
#   'Kaeo',
#   'Fernley',
#   'Lávara',
#   'Nesna',
#   'Laguna',
#   'Lashio',
#   'Kloulklubed',
#   'Ouégoa',
#   'Mahébourg',
#   'Porbandar',
#   'Rayevskaya',
#   'Puerto Escondido',
#   'Beloha',
#   'Poum',
#   'Escanaba',
#   'Chase',
#   'Maceió',
#   'Laas',
#   'Dunedin',
#   'Maragogi',
#   'Ponta Delgada',
#   'Azángaro',
#   'Corner Brook',
#   'Qarchī Gak',
#   'Isangel',
#   'San Patricio',
#   'Tibati',
#   'Sungai Raya',
#   'Reporoa',
#   'Woodward',
#   'Vacha',
#   'Natá',
#   'Ola',
#   'Port Macquarie',
#   'Korla',
#   'Ilām',
#   'Gornyy',
#   'Hobyo',
#   'Constitución',
#   'Gmina Strzelin',
#   'Cayenne',
#   'Camacha',
#   'Necochea',
#   'Kahului',
#   'San Luis',
#   'Sulangan',
#   'Sibolga',
#   'Khovd',
#   'Cidreira',
#   'Blahodatne',
#   'Orlik',
#   'Rapid City',
#   'Rock Springs',
#   'San Cristobal',
#   'Irbeyskoye',
#   'Hofn',
#   'Assiut',
#   'Grindavik',
#   'Lorengau',
#   'Saskylakh',
#   'Niquelândia',
#   'Buchanan',
#   'Flin Flon',
#   'San Juan del Sur',
#   'Kiruna',
#   'Moussoro',
#   'Sindang',
#   'São José da Coroa Grande',
#   'Olafsvik',
#   'Umm Kaddadah',
#   'Camopi',
#   'Ecoporanga',
#   'Dalvik',
#   'Oruzgan',
#   'Barra de Tecoanapa',
#   'Tingi',
#   'Port Lincoln',
#   'Saldanha',
#   'College',
#   'Clyde River',
#   'Norman Wells',
#   'Aquiraz',
#   'Staryy Nadym',
#   'Marsh Harbour',
#   'Tanete',
#   'Ankazoabo',
#   'Rocha',
#   'Båtsfjord',
#   'Wukari',
#   'Clevelândia',
#   'Paracale',
#   'Tourlaville',
#   'Zelenogorskiy',
#   'Aswān',
#   'Chatham',
#   'Santa Marta',
#   'Severnyy',
#   'Chutove',
#   'Vardø',
#   'Charlestown',
#   'Reconquista',
#   'Morón',
#   'Sibu',
#   'Lagoa',
#   'Ilulissat',
#   'Banda Aceh',
#   'Hoi An',
#   'Lincoln',
#   'Walvis Bay',
#   'Kutum',
#   'Mago',
#   'Vermillion',
#   'Mount Hagen',
#   'Cabedelo',
#   'Baie-Saint-Paul',
#   'Guadalupe y Calvo',
#   'Piaçabuçu',
#   'Yangi Marg`ilon',
#   'Charyshskoye',
#   'Sembakung',
#   'Sangamner',
#   'Zemio',
#   'Chibombo',
#   'Solnechnyy',
#   'Lethem',
#   'La Ronge',
#   'Porangatu',
#   'Lanivtsi',
#   'Mahon',
#   'Calca',
#   'Hamilton',
#   'Rodrigues Alves',
#   'Mujiayingzi',
#   'Torbay',
#   'Panabá',
#   'Antofagasta',
#   'Kununurra',
#   'Mitsamiouli',
#   'Gorontalo',
#   'Seoul',
#   'Dehri',
#   'Benicarló',
#   'Pakxan',
#   'Mombetsu',
#   'Sisimiut',
#   'Zyryanka',
#   'Omboué',
#   'Whitianga',
#   'Xaxim',
#   'Comodoro Rivadavia',
#   'Marquette',
#   'Talcahuano',
#   'Kennett',
#   'Cortez',
#   'Zhezkazgan',
#   'Henties Bay',
#   'Qujing',
#   'Senneterre',
#   'Odesskoye',
#   'Evanston',
#   'Honiara',
#   'High Rock',
#   'Pajapan',
#   'Pochutla',
#   'Chapais',
#   'Merauke',
#   'Assiniboia',
#   'Tilichiki',
#   'Santo Domingo',
#   'Tawang Town',
#   'Leningradskiy',
#   'Greensburg',
#   'Okhotsk',
#   'Along',
#   'Bulgan',
#   'São Miguel do Araguaia',
#   'Nieuw Amsterdam',
#   'Jambi City',
#   'Kaniama',
#   'Borovoy',
#   'Krasnoarmeysk',
#   'Kalanchak',
#   'Álamos',
#   'Wolgast',
#   'Road Town',
#   'Belomorsk',
#   'Nānākuli',
#   'Sainte-Marie',
#   'Bicester',
#   'Pudozh',
#   'Sambava',
#   'Kayseri Province',
#   'Burgos',
#   'Caniço',
#   'Palmerston',
#   'Ginda',
#   'Kasongo-Lunda',
#   'Okha',
#   'Ubari',
#   'Manokwari',
#   'Teya',
#   'Syracuse',
#   'Atar',
#   'Ballina',
#   'Ayorou',
#   'Balkhash',
#   'Verkhoyansk',
#   'Totness',
#   'Thinadhoo',
#   'Biloela',
#   'Pemba',
#   'Salinas',
#   'Lexington',
#   "Lebyazh'ye",
#   'Nishihara',
#   'Tornio',
#   'Nantucket',
#   'Meridian',
#   'Airai',
#   'Vestmannaeyjar',
#   'San Policarpo',
#   'Porto-Vecchio',
#   86.0833,
#   45.6969,
#   33.2907,
#   -108.9333,
#   13.7667,
#   -64.6167,
#   34.7668,
#   -158.1547,
#   55.5496,
#   -1.1536,
#   36.5345,
#   50.1667,
#   35.4968,
#   -3.7079,
#   -16.85,
#   130.9833,
#   78.4932,
#   16.8167,
#   142.9478,
#   12.7805,
#   134.0833,
#   92.6267,
#   15.2792,
#   -13.0499,
#   153.5667,
#   0.9174,
#   74.9804,
#   133.385,
#   -56.3167,
#   72.9333,
#   150.5,
#   40.5178,
#   -121.6555,
#   -84.4777,
#   66.4947,
#   127.7558,
#   24.1466,
#   -70.0995,
#   -116.3915,
#   125.4092,
#   -20.2734,
#   125.5072,
#   9.2795,
#   -137.5108,
#   -61.9688,
#   75.3667,
#   -53.4641,
#   127.8686,
#   -10.0711],
#  'Max Temp': [287.43,
#   288.58,
#   287.62,
#   293.12,
#   287.95,
#   280.21,
#   290.69,
#   277.96,
#   296.59,
#   271.24,
#   300.67,
#   272.66,
#   278.35,
#   288.81,
#   287.77,
#   286.55,
#   282.21,
#   293.12,
#   289.2,
#   296.29,
#   287.57,
#   281.02,
#   297,
#   296.58,
#   266.1,
#   291.01,
#   296.13,
#   296.79,
#   291.78,
#   300.19,
#   270.89,
#   299.88,
#   295.2,
#   308.46,
#   291.93,
#   289.71,
#   291.09,
#   300.59,
#   267,
#   280.47,
#   293.17,
#   294.12,
#   281.38,
#   293.85,
#   295.92,
#   302.18,
#   302.32,
#   289.53,
#   284.89,
#   297.5,
#   289.72,
#   275.13,
#   294.73,
#   288.09,
#   302.68,
#   273.24,
#   300.18,
#   279.45,
#   275.15,
#   291.99,
#   293.95,
#   287.76,
#   299.24,
#   297.82,
#   302.48,
#   299.79,
#   303.37,
#   303.87,
#   275.52,
#   269.9,
#   278.42,
#   287.26,
#   290.48,
#   300.52,
#   296.41,
#   287.92,
#   297.14,
#   298.19,
#   292,
#   296.06,
#   300.14,
#   283.82,
#   296.05,
#   297.17,
#   293.88,
#   272.16,
#   294.15,
#   286,
#   269.9,
#   294.99,
#   287.31,
#   293.69,
#   281.12,
#   279.86,
#   300.06,
#   286.6,
#   303.57,
#   303.18,
#   298.36,
#   297.02,
#   298.99,
#   292.67,
#   274.15,
#   296.41,
#   286.1,
#   305.84,
#   280.42,
#   293.18,
#   275.39,
#   286.23,
#   290.99,
#   284.79,
#   301.91,
#   302.74,
#   294.29,
#   297.16,
#   285.41,
#   285.27,
#   296.13,
#   274.21,
#   283.22,
#   272.99,
#   296.48,
#   283.39,
#   303.34,
#   297.57,
#   299.66,
#   292.23,
#   295.45,
#   279.71,
#   293.81,
#   308.38,
#   301.49,
#   272.14,
#   291.57,
#   294.52,
#   292.1,
#   297.19,
#   297.78,
#   303.61,
#   291.64,
#   300.84,
#   297.89,
#   302.4,
#   287.35,
#   303.12,
#   282.78,
#   294.06,
#   276.43,
#   288.61,
#   299.86,
#   294.07,
#   281.93,
#   290.52,
#   298.84,
#   284.83,
#   285.13,
#   297.95,
#   295.59,
#   303.87,
#   304.23,
#   267.24,
#   296.12,
#   291.86,
#   293.14,
#   283.73,
#   293.51,
#   278.7,
#   275.66,
#   295.29,
#   282.42,
#   302.91,
#   288.6,
#   296.03,
#   302,
#   290.45,
#   296.72,
#   299.49,
#   301.16,
#   302.21,
#   302.27,
#   283.09,
#   293.82,
#   292.89,
#   298.76,
#   295.36,
#   289.15,
#   299.74,
#   269.06,
#   257.89,
#   303.34,
#   299.38,
#   275.29,
#   305.95,
#   299.97,
#   299.07,
#   303.59,
#   282.03,
#   272.31,
#   289.67,
#   301.05,
#   303,
#   299.14,
#   286.66,
#   281.67,
#   295.34,
#   291.58,
#   281.89,
#   302.24,
#   288.6,
#   299.97,
#   302.56,
#   303.31,
#   301.7,
#   274,
#   293.78,
#   296.71,
#   287.27,
#   293.27,
#   301.67,
#   286.14,
#   288.06,
#   295.38,
#   303.08,
#   280.46,
#   292.2,
#   301.79,
#   283.71,
#   276.88,
#   285.67,
#   300.18,
#   294.41,
#   287.13,
#   281.79,
#   290.26,
#   283.81,
#   285.69,
#   295.29,
#   279.74,
#   289.53,
#   274.6,
#   286.54,
#   299.17,
#   286.26,
#   282.5,
#   297.75,
#   285.26,
#   304.35,
#   300.02,
#   293.26,
#   295.33,
#   284.46,
#   295.38,
#   276.66,
#   295.5,
#   282.16,
#   292.81,
#   304.58,
#   283.25,
#   275.45,
#   296.03,
#   304.24,
#   294.59,
#   306.05,
#   284.18,
#   307.12,
#   279.85,
#   291.18,
#   291.64,
#   297.65,
#   287.81,
#   276.87,
#   301.93,
#   301.09,
#   281.4,
#   285.53,
#   292.78,
#   299.59,
#   302.8,
#   274.66,
#   306.76,
#   291.48,
#   285.12,
#   283.04,
#   285.06,
#   297.7,
#   297.52,
#   300.08,
#   284.88,
#   296.14,
#   278.89,
#   293.14,
#   288.86,
#   294.68,
#   302.2,
#   296.86,
#   294.23,
#   302.78,
#   292.26,
#   284.91,
#   282.95,
#   299.85,
#   296.08,
#   304.67,
#   280.98,
#   294.2,
#   292.19,
#   282.56,
#   309.3,
#   268.19,
#   300.45,
#   291.27,
#   280.31,
#   300.8,
#   301.79,
#   291.34,
#   282.3,
#   303.26,
#   299.42,
#   287.15,
#   298.78,
#   287.22,
#   304.73,
#   276.41,
#   284.09,
#   297.2,
#   293.14,
#   283.52,
#   282.12,
#   278.27,
#   285.12,
#   278.88,
#   292.03,
#   295.68,
#   287.28,
#   289.78,
#   302.03,
#   303.09,
#   298.9,
#   281.15,
#   302.37,
#   288.51,
#   292.58,
#   304.11,
#   284.54,
#   300.08,
#   298.33,
#   298.16,
#   296.09,
#   291.66,
#   289.12,
#   289.04,
#   280.14,
#   292.29,
#   305.94,
#   303.43,
#   298.56,
#   296.07,
#   303.14,
#   286.57,
#   301.29,
#   290.51,
#   297.56,
#   292.15,
#   283.64,
#   297.84,
#   279.56,
#   286.97,
#   296.98,
#   291.55,
#   276.66,
#   280.24,
#   304.65,
#   299.21,
#   294.17,
#   291.53,
#   303.25,
#   289.92,
#   291.44,
#   291.08,
#   299.02,
#   274.97,
#   295.31,
#   298.83,
#   294.7,
#   279.7,
#   300.05,
#   286.43,
#   282.13,
#   297.64,
#   293.57,
#   281.5,
#   300.16,
#   289.48,
#   301.69,
#   303.23,
#   291.76,
#   286.11,
#   281.06,
#   279.62,
#   292.75,
#   285.84,
#   297.25,
#   280.82,
#   274.57,
#   294.25,
#   276.41,
#   302.97,
#   271.01,
#   292.16,
#   297.13,
#   271.67,
#   300.38,
#   277.66,
#   302.91,
#   301.29,
#   297.34,
#   276.97,
#   299.83,
#   295.23,
#   290.87,
#   273.78,
#   296.1,
#   300.77,
#   285.32,
#   293.34,
#   287.18,
#   291.25,
#   260.28,
#   286.17,
#   299.92,
#   275.79,
#   297.1,
#   306.1,
#   288.9,
#   281.09,
#   278.27,
#   298.3,
#   284,
#   304.13,
#   284.63,
#   281.44,
#   300.92,
#   282.48,
#   302.58,
#   285.17,
#   284.83,
#   278.26,
#   296.45,
#   286.16,
#   288.13,
#   301.32,
#   288.12,
#   275.16,
#   303.45,
#   308.13,
#   293.19,
#   289.31,
#   295.87,
#   277.62,
#   293.04,
#   293.92,
#   296.52,
#   287.22,
#   282.4,
#   297.12,
#   294.55,
#   280.33,
#   303.11,
#   301.26,
#   292.36,
#   284.49,
#   283.46,
#   297.51,
#   271.29,
#   293.91,
#   281.71,
#   288.46,
#   282.16,
#   295.01,
#   294.99,
#   299.66,
#   278.3,
#   298.79,
#   288.75,
#   305.14,
#   299.57,
#   302.82,
#   295.91,
#   306.18,
#   288.65,
#   308.16,
#   289.16,
#   270.36,
#   278.3,
#   298.11,
#   291.49,
#   283.68,
#   283.07,
#   291.36,
#   284.97,
#   297.2,
#   295.57,
#   290.39,
#   289.18,
#   298.02,
#   294.27,
#   286.35,
#   294.25,
#   303.33,
#   297.16,
#   300.52,
#   300.83,
#   289.03,
#   301.57,
#   284.1,
#   273.02,
#   297.97,
#   286.51,
#   274.53,
#   293.43,
#   277.05,
#   295.46,
#   296.7,
#   294.8,
#   298.16,
#   300.95,
#   292.56,
#   281.75,
#   288.31,
#   287.03,
#   297.99,
#   281.4,
#   301.2,
#   291.7,
#   301.12,
#   296.24,
#   281.66,
#   291.55,
#   296.07,
#   283.16,
#   279.35,
#   295.5,
#   306.42,
#   287.6,
#   293.16,
#   274.57,
#   299.68,
#   298.96,
#   279.81,
#   291.42,
#   301.04,
#   295.17,
#   305.97,
#   290.49,
#   277.58,
#   298.26,
#   302.21,
#   296.8,
#   294.54,
#   286.49,
#   293.78,
#   290.46,
#   304.18,
#   281.16,
#   285.36,
#   286.33,
#   297.45,
#   277.22,
#   302.31,
#   285.89,
#   283.12,
#   287.53,
#   288.29,
#   272.33,
#   304.15,
#   303.98],
#  'Humidity': [52,
#   89,
#   49,
#   78,
#   70,
#   80,
#   47,
#   93,
#   38,
#   80,
#   79,
#   91,
#   100,
#   91,
#   87,
#   60,
#   91,
#   85,
#   93,
#   53,
#   95,
#   53,
#   80,
#   76,
#   79,
#   70,
#   59,
#   89,
#   82,
#   39,
#   90,
#   90,
#   98,
#   46,
#   73,
#   78,
#   62,
#   77,
#   68,
#   93,
#   55,
#   89,
#   93,
#   54,
#   81,
#   70,
#   50,
#   78,
#   59,
#   10,
#   73,
#   37,
#   85,
#   81,
#   68,
#   100,
#   71,
#   95,
#   75,
#   66,
#   57,
#   85,
#   83,
#   85,
#   10,
#   78,
#   68,
#   58,
#   85,
#   74,
#   95,
#   83,
#   39,
#   87,
#   72,
#   25,
#   53,
#   87,
#   57,
#   88,
#   68,
#   77,
#   74,
#   94,
#   53,
#   80,
#   74,
#   71,
#   76,
#   94,
#   94,
#   42,
#   88,
#   93,
#   87,
#   72,
#   71,
#   67,
#   8,
#   86,
#   68,
#   95,
#   89,
#   53,
#   73,
#   11,
#   24,
#   83,
#   80,
#   77,
#   37,
#   80,
#   52,
#   70,
#   52,
#   66,
#   60,
#   26,
#   76,
#   75,
#   52,
#   91,
#   81,
#   84,
#   71,
#   93,
#   81,
#   63,
#   78,
#   26,
#   43,
#   61,
#   11,
#   69,
#   70,
#   55,
#   76,
#   87,
#   76,
#   65,
#   54,
#   76,
#   90,
#   76,
#   83,
#   78,
#   60,
#   68,
#   95,
#   93,
#   20,
#   31,
#   93,
#   73,
#   88,
#   82,
#   87,
#   88,
#   75,
#   62,
#   73,
#   71,
#   64,
#   95,
#   75,
#   50,
#   86,
#   76,
#   74,
#   98,
#   82,
#   15,
#   43,
#   80,
#   70,
#   92,
#   58,
#   77,
#   76,
#   75,
#   48,
#   71,
#   54,
#   84,
#   67,
#   44,
#   53,
#   59,
#   80,
#   89,
#   12,
#   48,
#   60,
#   77,
#   75,
#   79,
#   12,
#   22,
#   82,
#   39,
#   86,
#   61,
#   76,
#   82,
#   92,
#   80,
#   71,
#   20,
#   69,
#   75,
#   78,
#   70,
#   62,
#   85,
#   95,
#   95,
#   45,
#   22,
#   95,
#   26,
#   100,
#   87,
#   81,
#   70,
#   100,
#   52,
#   75,
#   96,
#   97,
#   79,
#   74,
#   17,
#   38,
#   92,
#   57,
#   60,
#   79,
#   91,
#   81,
#   27,
#   62,
#   52,
#   85,
#   77,
#   91,
#   63,
#   49,
#   57,
#   32,
#   95,
#   40,
#   93,
#   97,
#   71,
#   60,
#   27,
#   44,
#   84,
#   71,
#   75,
#   27,
#   61,
#   43,
#   36,
#   74,
#   40,
#   82,
#   88,
#   78,
#   81,
#   46,
#   43,
#   77,
#   74,
#   91,
#   91,
#   66,
#   14,
#   68,
#   74,
#   44,
#   40,
#   90,
#   94,
#   70,
#   89,
#   94,
#   84,
#   82,
#   74,
#   69,
#   68,
#   77,
#   71,
#   79,
#   94,
#   70,
#   65,
#   68,
#   62,
#   87,
#   82,
#   76,
#   58,
#   53,
#   54,
#   83,
#   49,
#   46,
#   87,
#   87,
#   42,
#   80,
#   81,
#   10,
#   45,
#   72,
#   78,
#   85,
#   94,
#   87,
#   80,
#   23,
#   63,
#   44,
#   76,
#   64,
#   93,
#   74,
#   67,
#   63,
#   100,
#   75,
#   98,
#   90,
#   46,
#   78,
#   89,
#   41,
#   33,
#   56,
#   67,
#   97,
#   73,
#   62,
#   46,
#   33,
#   87,
#   72,
#   70,
#   29,
#   85,
#   80,
#   46,
#   42,
#   78,
#   68,
#   75,
#   79,
#   76,
#   75,
#   61,
#   74,
#   92,
#   78,
#   91,
#   94,
#   67,
#   89,
#   100,
#   60,
#   86,
#   11,
#   79,
#   95,
#   96,
#   64,
#   60,
#   87,
#   74,
#   86,
#   83,
#   54,
#   20,
#   82,
#   40,
#   76,
#   94,
#   92,
#   90,
#   82,
#   77,
#   67,
#   80,
#   74,
#   61,
#   29,
#   81,
#   91,
#   88,
#   58,
#   64,
#   98,
#   72,
#   68,
#   38,
#   76,
#   69,
#   86,
#   52,
#   87,
#   67,
#   78,
#   75,
#   9,
#   63,
#   87,
#   69,
#   48,
#   99,
#   97,
#   80,
#   13,
#   67,
#   81,
#   41,
#   90,
#   33,
#   72,
#   33,
#   89,
#   89,
#   65,
#   52,
#   66,
#   91,
#   97,
#   80,
#   46,
#   65,
#   70,
#   35,
#   22,
#   94,
#   74,
#   94,
#   96,
#   95,
#   47,
#   82,
#   82,
#   93,
#   85,
#   80,
#   66,
#   54,
#   94,
#   82,
#   38,
#   89,
#   91,
#   87,
#   80,
#   77,
#   52,
#   90,
#   46,
#   50,
#   95,
#   56,
#   95,
#   82,
#   77,
#   87,
#   54,
#   55,
#   89,
#   63,
#   89,
#   84,
#   92,
#   23,
#   82,
#   82,
#   75,
#   33,
#   66,
#   75,
#   49,
#   51,
#   60,
#   49,
#   72,
#   92,
#   85,
#   92,
#   82,
#   55,
#   93,
#   93,
#   100,
#   68,
#   18,
#   45,
#   86,
#   49,
#   79,
#   37,
#   78,
#   64,
#   69,
#   69,
#   72,
#   76,
#   80,
#   37,
#   100,
#   93,
#   97,
#   86,
#   85,
#   72,
#   100,
#   23,
#   52,
#   92,
#   86,
#   69,
#   33,
#   78,
#   80,
#   36,
#   94,
#   76,
#   71,
#   67,
#   64,
#   94,
#   78,
#   76,
#   57,
#   93,
#   68,
#   35,
#   97,
#   78,
#   97,
#   16,
#   86,
#   37,
#   75,
#   18,
#   60,
#   25,
#   36,
#   61,
#   91,
#   69,
#   43,
#   88,
#   62,
#   70,
#   41,
#   73,
#   92,
#   87,
#   63,
#   47,
#   81,
#   73,
#   68,
#   43,
#   81,
#   37,
#   96,
#   79,
#   18],
#  'Cloudiness': [25,
#   99,
#   40,
#   1,
#   97,
#   90,
#   6,
#   90,
#   39,
#   90,
#   86,
#   100,
#   40,
#   100,
#   100,
#   64,
#   100,
#   100,
#   75,
#   1,
#   100,
#   1,
#   40,
#   99,
#   20,
#   0,
#   66,
#   12,
#   77,
#   0,
#   91,
#   7,
#   100,
#   78,
#   81,
#   80,
#   1,
#   100,
#   75,
#   39,
#   14,
#   4,
#   51,
#   3,
#   97,
#   18,
#   57,
#   67,
#   0,
#   0,
#   20,
#   20,
#   56,
#   98,
#   72,
#   100,
#   46,
#   60,
#   20,
#   100,
#   1,
#   21,
#   75,
#   47,
#   1,
#   15,
#   100,
#   2,
#   86,
#   31,
#   100,
#   98,
#   1,
#   99,
#   99,
#   20,
#   75,
#   17,
#   91,
#   100,
#   75,
#   2,
#   83,
#   0,
#   10,
#   90,
#   51,
#   1,
#   29,
#   88,
#   45,
#   100,
#   100,
#   90,
#   99,
#   51,
#   100,
#   95,
#   0,
#   98,
#   1,
#   75,
#   84,
#   100,
#   61,
#   1,
#   0,
#   53,
#   6,
#   29,
#   85,
#   58,
#   58,
#   96,
#   0,
#   1,
#   100,
#   0,
#   99,
#   0,
#   0,
#   98,
#   0,
#   10,
#   40,
#   75,
#   50,
#   1,
#   0,
#   54,
#   67,
#   100,
#   39,
#   20,
#   100,
#   83,
#   100,
#   0,
#   44,
#   80,
#   1,
#   100,
#   98,
#   99,
#   98,
#   20,
#   67,
#   4,
#   20,
#   90,
#   100,
#   47,
#   0,
#   84,
#   57,
#   99,
#   75,
#   3,
#   0,
#   34,
#   40,
#   21,
#   24,
#   91,
#   86,
#   2,
#   40,
#   100,
#   99,
#   100,
#   99,
#   78,
#   100,
#   100,
#   71,
#   100,
#   0,
#   43,
#   88,
#   81,
#   0,
#   40,
#   21,
#   75,
#   59,
#   4,
#   47,
#   86,
#   90,
#   29,
#   0,
#   0,
#   93,
#   100,
#   90,
#   100,
#   0,
#   99,
#   89,
#   36,
#   75,
#   91,
#   17,
#   99,
#   100,
#   1,
#   16,
#   32,
#   90,
#   96,
#   20,
#   22,
#   95,
#   43,
#   60,
#   76,
#   0,
#   0,
#   75,
#   0,
#   20,
#   100,
#   1,
#   100,
#   90,
#   0,
#   90,
#   75,
#   100,
#   100,
#   75,
#   0,
#   0,
#   5,
#   1,
#   7,
#   99,
#   1,
#   75,
#   1,
#   100,
#   0,
#   97,
#   20,
#   100,
#   0,
#   3,
#   63,
#   66,
#   90,
#   100,
#   91,
#   78,
#   94,
#   5,
#   14,
#   100,
#   75,
#   40,
#   100,
#   20,
#   36,
#   69,
#   71,
#   1,
#   47,
#   70,
#   1,
#   5,
#   3,
#   81,
#   100,
#   100,
#   75,
#   75,
#   100,
#   9,
#   4,
#   76,
#   40,
#   100,
#   14,
#   60,
#   100,
#   28,
#   99,
#   31,
#   100,
#   100,
#   35,
#   95,
#   90,
#   64,
#   100,
#   40,
#   84,
#   69,
#   100,
#   51,
#   6,
#   100,
#   90,
#   39,
#   27,
#   88,
#   100,
#   100,
#   88,
#   100,
#   100,
#   94,
#   86,
#   95,
#   100,
#   0,
#   0,
#   100,
#   70,
#   100,
#   100,
#   100,
#   16,
#   40,
#   90,
#   0,
#   99,
#   0,
#   100,
#   100,
#   46,
#   75,
#   90,
#   100,
#   100,
#   72,
#   40,
#   22,
#   20,
#   40,
#   5,
#   30,
#   1,
#   18,
#   100,
#   3,
#   63,
#   0,
#   73,
#   73,
#   100,
#   0,
#   27,
#   100,
#   1,
#   81,
#   34,
#   37,
#   86,
#   40,
#   5,
#   3,
#   0,
#   3,
#   90,
#   21,
#   75,
#   45,
#   35,
#   29,
#   75,
#   64,
#   100,
#   96,
#   90,
#   81,
#   50,
#   99,
#   0,
#   90,
#   14,
#   11,
#   83,
#   63,
#   67,
#   95,
#   97,
#   86,
#   100,
#   63,
#   90,
#   20,
#   100,
#   20,
#   98,
#   100,
#   57,
#   85,
#   97,
#   42,
#   100,
#   75,
#   1,
#   63,
#   100,
#   93,
#   0,
#   75,
#   18,
#   97,
#   17,
#   87,
#   69,
#   2,
#   100,
#   4,
#   82,
#   22,
#   16,
#   58,
#   56,
#   0,
#   59,
#   0,
#   0,
#   98,
#   100,
#   100,
#   75,
#   1,
#   20,
#   4,
#   100,
#   100,
#   17,
#   0,
#   63,
#   100,
#   99,
#   16,
#   100,
#   0,
#   55,
#   0,
#   90,
#   23,
#   90,
#   86,
#   100,
#   30,
#   29,
#   100,
#   40,
#   100,
#   75,
#   95,
#   100,
#   90,
#   23,
#   0,
#   100,
#   99,
#   92,
#   0,
#   72,
#   0,
#   23,
#   94,
#   56,
#   100,
#   64,
#   78,
#   38,
#   100,
#   29,
#   90,
#   31,
#   91,
#   0,
#   36,
#   1,
#   7,
#   100,
#   40,
#   72,
#   7,
#   6,
#   70,
#   52,
#   0,
#   99,
#   72,
#   100,
#   20,
#   100,
#   82,
#   100,
#   91,
#   62,
#   0,
#   100,
#   75,
#   75,
#   90,
#   0,
#   4,
#   68,
#   90,
#   37,
#   90,
#   100,
#   100,
#   42,
#   3,
#   91,
#   70,
#   76,
#   100,
#   55,
#   100,
#   99,
#   1,
#   62,
#   100,
#   62,
#   20,
#   72,
#   85,
#   87,
#   0,
#   70,
#   13,
#   0,
#   6,
#   85,
#   74,
#   1,
#   75,
#   100,
#   78,
#   12,
#   0,
#   92,
#   20,
#   0,
#   100,
#   7,
#   100,
#   27,
#   100,
#   26,
#   99,
#   0,
#   10,
#   18,
#   0,
#   100,
#   69,
#   5,
#   52,
#   20,
#   1,
#   1,
#   26,
#   75,
#   100,
#   1,
#   90,
#   46,
#   99,
#   100,
#   20,
#   79,
#   100,
#   32,
#   100,
#   75,
#   71],
#  'Wind Speed': [2.24,
#   4.42,
#   0.89,
#   0,
#   3.23,
#   4.84,
#   2.17,
#   0,
#   5.83,
#   5.14,
#   5.46,
#   3.22,
#   1.03,
#   9.12,
#   3.4,
#   2.03,
#   2.57,
#   4.47,
#   1.79,
#   2.38,
#   3.33,
#   3.6,
#   1.12,
#   3.18,
#   0.57,
#   7.23,
#   7.71,
#   1.79,
#   3.97,
#   4.12,
#   2.22,
#   3.73,
#   0.69,
#   5.7,
#   2.78,
#   3.43,
#   0,
#   8.93,
#   3.6,
#   2.06,
#   1.97,
#   0.78,
#   0.45,
#   2.7,
#   9.42,
#   3.81,
#   2.3,
#   1.06,
#   0,
#   6.41,
#   2.2,
#   3.6,
#   0.72,
#   10.75,
#   2.6,
#   2.79,
#   1.92,
#   0.55,
#   7.72,
#   1.7,
#   2.06,
#   3.53,
#   4.63,
#   1.13,
#   0.89,
#   8.05,
#   4.12,
#   2.02,
#   5.48,
#   4.14,
#   1.62,
#   2.58,
#   2.06,
#   0.52,
#   6.89,
#   3.09,
#   6.69,
#   4.11,
#   4.42,
#   1.67,
#   1.34,
#   4.47,
#   11.42,
#   0,
#   2.55,
#   4.12,
#   1.74,
#   3.6,
#   3.42,
#   3.23,
#   1.54,
#   3.61,
#   4.47,
#   4.12,
#   2.72,
#   1.05,
#   1.88,
#   2.04,
#   0.61,
#   2.16,
#   5.14,
#   0.89,
#   2.87,
#   1.81,
#   6.28,
#   12.74,
#   7.72,
#   1.75,
#   3.65,
#   1.26,
#   1.2,
#   5.14,
#   4.77,
#   1.87,
#   2.1,
#   2.06,
#   1.41,
#   8,
#   11.41,
#   4,
#   1.19,
#   9.49,
#   1.69,
#   6.96,
#   7.49,
#   0.89,
#   7.22,
#   2.39,
#   2.57,
#   1.61,
#   1.34,
#   6.4,
#   2.28,
#   2.06,
#   2.3,
#   1.03,
#   0.7,
#   3.77,
#   1.05,
#   4.98,
#   11.83,
#   8.3,
#   2.95,
#   3.1,
#   2.74,
#   0.89,
#   1.38,
#   0.83,
#   6.71,
#   4.93,
#   2.08,
#   1.99,
#   2.1,
#   3.14,
#   2.19,
#   1.86,
#   7.83,
#   4.24,
#   1.46,
#   0.71,
#   2.83,
#   2.34,
#   2.97,
#   1.16,
#   3.79,
#   1.5,
#   2.58,
#   8.34,
#   5.97,
#   0.33,
#   3.29,
#   6.48,
#   1.21,
#   4.96,
#   0.61,
#   0.72,
#   6.86,
#   5.56,
#   9.73,
#   6.67,
#   1.88,
#   7.2,
#   2.66,
#   0,
#   1.32,
#   1.92,
#   3.53,
#   10.3,
#   4.12,
#   3.56,
#   2.06,
#   2.14,
#   11.61,
#   0.45,
#   5.14,
#   1.87,
#   3.27,
#   4.12,
#   1.96,
#   4.2,
#   3.16,
#   9.58,
#   1.95,
#   0.74,
#   4.82,
#   4.61,
#   2.49,
#   2.59,
#   1.66,
#   3.04,
#   10.29,
#   2.55,
#   6.1,
#   6.96,
#   1.14,
#   0.89,
#   4.14,
#   5.14,
#   4.87,
#   5.14,
#   0,
#   2.88,
#   0.89,
#   2.07,
#   0,
#   8,
#   1.73,
#   0.45,
#   5.55,
#   2.02,
#   7.72,
#   3.09,
#   1.76,
#   3.91,
#   2.06,
#   3.58,
#   1.55,
#   2.19,
#   1.03,
#   4.12,
#   4.14,
#   4.37,
#   1.69,
#   0.89,
#   1.89,
#   5.54,
#   4.85,
#   1.34,
#   5.66,
#   1.79,
#   2.06,
#   5.6,
#   0.56,
#   1.1,
#   1.89,
#   1.66,
#   3.41,
#   7.2,
#   5.66,
#   3.6,
#   2.99,
#   2.4,
#   3.2,
#   1.28,
#   5.66,
#   6.27,
#   1.26,
#   2.57,
#   3.66,
#   4.44,
#   2.67,
#   7.89,
#   5.07,
#   5.14,
#   0.45,
#   2.36,
#   4.42,
#   3.62,
#   2.35,
#   3.59,
#   1.83,
#   6.39,
#   3.68,
#   14.69,
#   3.31,
#   3.44,
#   1.87,
#   6.35,
#   1.97,
#   3.13,
#   5.23,
#   5.14,
#   7.09,
#   2.83,
#   1.03,
#   1.77,
#   12.22,
#   1.16,
#   9.13,
#   1.66,
#   1.87,
#   3.68,
#   7.71,
#   3.55,
#   1.82,
#   2.36,
#   1.1,
#   3.71,
#   1.36,
#   3.21,
#   8.32,
#   0.6,
#   3.41,
#   2.84,
#   5.8,
#   6.28,
#   2.58,
#   3.46,
#   8.22,
#   1.34,
#   4.81,
#   1.39,
#   4.61,
#   5.47,
#   5,
#   4.07,
#   2.24,
#   7.01,
#   1.79,
#   1.22,
#   5.91,
#   7.72,
#   5.29,
#   0.58,
#   0.95,
#   2.79,
#   8.27,
#   2.06,
#   4.63,
#   4.71,
#   8.16,
#   5.14,
#   1.12,
#   4.99,
#   1.41,
#   3.87,
#   5.82,
#   1.37,
#   3.43,
#   1,
#   5.36,
#   2.64,
#   3.08,
#   2.68,
#   1.97,
#   6.28,
#   2.85,
#   11.56,
#   4.63,
#   1.89,
#   3.06,
#   5.58,
#   6.76,
#   2.57,
#   1.59,
#   2.06,
#   3.27,
#   3.54,
#   1.62,
#   2.06,
#   1.09,
#   0.95,
#   8.46,
#   3.9,
#   3,
#   0.28,
#   0.36,
#   1.59,
#   1.85,
#   2.29,
#   2.45,
#   4.17,
#   2.2,
#   2.67,
#   1.78,
#   5.82,
#   10.61,
#   0.94,
#   2.31,
#   4.42,
#   2.06,
#   3.45,
#   10.8,
#   1.6,
#   1.18,
#   1.78,
#   7.72,
#   2.06,
#   4.36,
#   1.24,
#   1.65,
#   2.15,
#   1.52,
#   3.22,
#   1.52,
#   5.43,
#   0.81,
#   2.51,
#   4.12,
#   0.94,
#   0.51,
#   4.62,
#   3.3,
#   3.6,
#   4.1,
#   0.5,
#   1.14,
#   4.12,
#   2.58,
#   0.76,
#   0.11,
#   1.1,
#   2.43,
#   2.61,
#   1.36,
#   1.01,
#   7.93,
#   4.63,
#   3.09,
#   5.66,
#   3.96,
#   8.89,
#   11.72,
#   4.71,
#   2.88,
#   1.26,
#   4.02,
#   2.61,
#   1.64,
#   3.57,
#   3.6,
#   4.86,
#   1.71,
#   1.34,
#   1.79,
#   2,
#   5.06,
#   8.5,
#   1.34,
#   4.39,
#   3.34,
#   1.34,
#   7.3,
#   1.54,
#   3.41,
#   3.6,
#   2.57,
#   1.74,
#   1.61,
#   4.47,
#   4.94,
#   1.44,
#   2.96,
#   2.24,
#   1.13,
#   1.05,
#   2.06,
#   3.32,
#   0.71,
#   3.86,
#   1.16,
#   2.33,
#   2.55,
#   4,
#   5.14,
#   1.41,
#   4.97,
#   6.17,
#   1.44,
#   1.62,
#   0.36,
#   2.55,
#   4.12,
#   4.96,
#   2.79,
#   3.6,
#   2.56,
#   1.59,
#   4.14,
#   4.12,
#   1.8,
#   1.83,
#   5.14,
#   5.08,
#   8.38,
#   1.82,
#   1.36,
#   1.33,
#   0,
#   4.66,
#   2.06,
#   5.14,
#   4.12,
#   9,
#   2.52,
#   6.75,
#   2.19,
#   5.34,
#   0.45,
#   2.49,
#   12.43,
#   5,
#   2.65,
#   2.62,
#   6.57,
#   7.14,
#   0.87,
#   1.44,
#   1.87,
#   3.32,
#   1.58,
#   3.25,
#   0.13,
#   6.45,
#   1.33,
#   4.14,
#   1.07,
#   1.74,
#   5.18,
#   3.14,
#   1.71,
#   1.03,
#   3.96,
#   3.87,
#   5.45,
#   8.1,
#   2.57,
#   2.76,
#   3.37,
#   5.8,
#   0,
#   0,
#   5.73,
#   4.21,
#   0.8,
#   0.13,
#   5.36,
#   4.52,
#   2.34,
#   2.88,
#   1.56,
#   3.28,
#   4.12,
#   3.02,
#   10,
#   3.64,
#   5.54,
#   4.6,
#   6.66,
#   4.12,
#   5.66,
#   3.22,
#   1.68,
#   5.83,
#   5.28,
#   2.57,
#   1.34,
#   1.98,
#   0.91,
#   2.95,
#   1.99,
#   6.17,
#   3.13,
#   7.69,
#   7.44,
#   6.45,
#   2.86]}

# %%
weather_df = pd.DataFrame(weather_dict)
weather_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed
# 0  New Norfolk -42.7826  147.0587    287.43        52          25        2.24
# 1       Emmaus  56.7805   36.1150    288.58        89          99        4.42
# 2       Hobart -42.8794  147.3294    287.62        49          40        0.89
# 3     Havelock  34.8791  -76.9013    293.12        78           1        0.00
# 4   Codrington -38.2667  141.9667    287.95        70          97        3.23

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(city_data_df['Lat'], city_data_df['Max Temp'])
plt.title(f'City Latitude vs. Max Temperature')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.grid(True)
plt.savefig('Max_temp.png')

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(city_data_df['Lat'], city_data_df['Humidity'])
plt.title(f'City Latitude vs. Humidity')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid(True)
plt.savefig('lat_humid.png')

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(city_data_df['Lat'], city_data_df['Cloudiness'])
plt.title(f'City Latitude vs. Cloudiness')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid(True)
plt.savefig('lat_clouds.png')

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(city_data_df['Lat'], city_data_df['Wind Speed'])
plt.title(f'City Latitude vs. Wind Speed')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.grid(True)
plt.savefig('lat_windspd.png')

# %% [markdown]
# ## Linear Regression

# %%
# Create a Scatter Plot for temperature vs latitude
x_values = city_data_df['Max Temp']
y_values = city_data_df['Lat']
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Max Temp (F)')
plt.show()

# %%
# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(city_data_df['Max Temp'],city_data_df['Lat'])

# Get regression values
regress_values = x_values * slope + intercept
print(regress_values)
# Out:
# 0      27.402141
# 1      25.462377
# 2      27.081658
# 3      17.804527
# 4      26.525030
#          ...
# 572    27.233466
# 573    25.951535
# 574    52.872083
# 575    -0.800338
# 576    -0.513590
# Name: Max Temp, Length: 577, dtype: float64

# %%
# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)
# Out:
# y = -1.69x +512.23

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Create Plot
plt.scatter(x_values, y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Temperature')
plt.annotate(line_eq,(20,15),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.2279918171667773

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
