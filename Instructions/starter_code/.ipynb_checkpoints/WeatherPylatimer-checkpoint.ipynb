# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests, csv
import time
from scipy.stats import linregress
from datetime import datetime

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

print(weather_api_key)
# Out:
# 5509164b94b4b417973a3882e28bc8b4

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []
country_codes =[]

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.00, size=1500)
lat_lngs = zip(lats, lngs)
city = citipy

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 612

# %%
print(cities)
# Out:
# ['hermanus', 'punta arenas', 'mar del plata', 'kavieng', 'barrow', 'port alfred', 'lompoc', 'lebu', 'esperance', 'rikitea', 'mitsamiouli', 'busselton', 'kaitangata', 'east london', 'cabo san lucas', 'nago', 'muzhi', 'bababe', 'jieshi', 'qaanaaq', 'cape town', 'albany', 'hilo', 'chokurdakh', 'cherskiy', 'chuy', 'nouadhibou', 'puerto ayora', 'tsihombe', 'lavrentiya', 'karratha', 'kapaa', 'waddan', 'fortuna', 'namibe', 'coihaique', 'colesberg', 'cayenne', 'hithadhoo', 'mmabatho', 'oranjemund', 'aklavik', 'warner robins', 'provideniya', 'vanavara', 'ushuaia', 'salalah', 'baculin', 'pacific grove', 'georgetown', 'hofn', 'lakatoro', 'kodiak', 'flinders', 'batagay', 'beloha', 'fort nelson', 'mataura', 'itarema', 'brae', 'dingle', 'nikolskoye', 'penzance', 'husavik', 'jamestown', 'arraial do cabo', 'longyearbyen', 'dikson', 'new norfolk', 'pevek', 'vila velha', 'the valley', 'itaituba', 'grimshaw', 'grand river south east', 'grand centre', 'bud', 'dauphin', 'teguise', 'vaini', 'saint-philippe', 'avarua', 'mahebourg', 'sobolevo', 'ribeira grande', 'bredasdorp', 'wisconsin rapids', 'faanui', 'ilulissat', 'butaritari', 'bayan', 'lugo', 'upernavik', 'ancud', 'thompson', 'hanna', 'gamba', 'goderich', 'artyk', 'mendoza', 'sentyabrskiy', 'sioux lookout', 'walvis bay', 'ponta do sol', 'bluff', 'zihuatanejo', 'kushiro', 'saskylakh', 'torbay', 'amapa', 'shaikhpura', 'sandy springs', 'shelburne', 'warqla', 'ilam', 'besikduzu', 'taoudenni', 'suntar', 'tuatapere', 'balikpapan', 'ilembula', 'vannes', 'shillong', 'los llanos de aridane', 'hunza', 'illoqqortoormiut', 'oriximina', 'lira', 'taolanaro', 'anaconda', 'baghdad', 'anadyr', 'ilo', 'karamea', 'okha', 'chicama', 'homer', 'rawson', 'maragogi', 'tasiilaq', 'gat', 'avigliano', 'port hardy', 'yellowknife', 'maniitsoq', 'airai', 'atuona', 'norman wells', 'luderitz', 'presidencia roque saenz pena', 'vanimo', 'butterworth', 'saint-pierre', 'el cairo', 'lerwick', 'richards bay', 'poso', 'santa isabel', 'fairbanks', 'talawdi', 'kharan', 'kiama', 'galiwinku', 'narsaq', 'tiksi', 'castro', 'diffa', 'khatanga', 'vila do maio', 'barentsburg', 'surgut', 'geraldton', 'berlevag', 'mareeba', 'hobart', 'omboue', 'zaraza', 'carnarvon', 'solnechnyy', 'rocha', 'ust-maya', 'killam', 'pisco', 'poum', 'dubbo', 'poya', 'severo-kurilsk', 'oliveira dos brejinhos', 'cabedelo', 'te anau', 'vao', 'belushya guba', 'palabuhanratu', 'saquena', 'gazojak', 'mount isa', 'namatanai', 'laguna', 'mackay', 'dudinka', 'sao filipe', 'soyo', 'waingapu', 'aiken', 'leningradskiy', 'callaguip', 'ruwi', 'khonuu', 'corinto', 'tuktoyaktuk', 'bargal', 'sinnamary', 'coquimbo', 'san cristobal', 'olafsvik', 'asosa', 'yeppoon', 'zumpango', 'norsup', 'tura', 'havoysund', 'manta', 'ruteng', 'evensk', 'attawapiskat', 'aketi', 'tuskegee', 'saldanha', 'aguimes', 'shirgaon', 'gongzhuling', 'palmer', 'waipawa', 'ponta delgada', 'vaitupu', 'quatre cocos', 'padang', 'bardiyah', 'iqaluit', 'calvinia', 'mecca', 'livingstonia', 'svetla nad sazavou', 'umzimvubu', 'dunedin', 'samarai', 'dzaoudzi', 'saint-augustin', 'beringovskiy', 'santa isabel do rio negro', 'victoria', 'nortelandia', 'saleaula', 'lhuntshi', 'mirina', 'sucre', 'sao joao da barra', 'gizo', 'neuquen', 'tokur', 'ust-kamchatsk', 'faya', 'lagoa', 'fez', 'solovetskiy', 'najran', 'ambon', 'kovdor', 'rincon', 'nizhneyansk', 'payakumbuh', 'turochak', 'havre', 'jabinyanah', 'udachnyy', 'moose factory', 'grindavik', 'kudahuvadhoo', 'misratah', 'rognan', 'bengkulu', 'labuhan', 'acarau', 'port elizabeth', 'buala', 'guerrero negro', 'skjervoy', 'mbanza-ngungu', 'cap malheureux', 'doctor juan manuel frutos', 'male', 'wanning', 'samusu', 'banjar', 'ngukurr', 'bethel', 'souillac', 'barroualie', 'koulamoutou', 'paamiut', 'gao', 'nuuk', 'staryy nadym', 'tezu', 'clyde river', 'masvingo', 'herat', 'hobyo', 'san juan de uraba', 'saint george', 'saumur', 'terrell', 'beloye', 'petauke', 'vostok', 'baoshan', 'eydhafushi', 'beeville', 'lorengau', 'almaty', 'shimoda', 'sitka', 'katherine', 'aykhal', 'methoni', 'langsa', ...

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Open Weather Map using API Key

# url = "http://maps.openweathermap.org/maps/2.0/weather/TA2/{z}/{x}/{y}&appid=" + weather_api_key
# Starting URL for Weather Map API Call
#url = "http://api.openweathermap.org/data/2.5/weather?q="

# %%
# Create a partial query URL
# query = f"{url}{city}&appid={weather_api_key}"
# api.openweathermap.org/data/2.5/weather?q={city}&appid={weather_api_key}

# %%
# weather_response = requests.get(query)
# weather_json = weather_response.json()

# %%
# print(weather_json)

# %%
url = "http://api.openweathermap.org/data/2.5/weather?q="

# Data list of Cities
city_list = []
lat_list = []
lng_list = []
max_temp_list = []
humidity_list = []
cloudiness_list = []
windspeed_list = []
date = []
counter = 0
record_counter = 0
setcount = 1


for city in cities:
    counter += 1
    if (counter % 50 == 0):
        setcount += 1
        record_counter =0
        print(setcount)
        print(record_counter)
        print(counter)
    record_counter += 1
    print("processing record" + str(record_counter) +"of Set" + str(setcount) +"|" +city)
    try: 
        weather_response = requests.get(f"{url}{city}&appid={weather_api_key}").json()
        city_list.append(weather_response['name'])
        lat_list.append(weather_response['coord']['lat'])
        lng_list.append(weather_response['coord']['lon'])
        max_temp_list.append(weather_response['main']['temp_max'])
        humidity_list.append(weather_response['main']['humidity'])
        cloudiness_list.append(weather_response['clouds']['all'])
        windspeed_list.append(weather_response['wind']['speed'])
    except:
        print("City Not Found, Pass...:" + city)

        
print(len(weather_response))
# Out:
# processing record1of Set1|hermanus
# processing record2of Set1|punta arenas
# processing record3of Set1|mar del plata
# processing record4of Set1|kavieng
# processing record5of Set1|barrow
# processing record6of Set1|port alfred
# processing record7of Set1|lompoc
# processing record8of Set1|lebu
# processing record9of Set1|esperance
# processing record10of Set1|rikitea
# processing record11of Set1|mitsamiouli
# processing record12of Set1|busselton
# processing record13of Set1|kaitangata
# processing record14of Set1|east london
# processing record15of Set1|cabo san lucas
# processing record16of Set1|nago
# processing record17of Set1|muzhi
# processing record18of Set1|bababe
# City Not Found, Pass...:bababe
# processing record19of Set1|jieshi
# processing record20of Set1|qaanaaq
# processing record21of Set1|cape town
# processing record22of Set1|albany
# processing record23of Set1|hilo
# processing record24of Set1|chokurdakh
# processing record25of Set1|cherskiy
# processing record26of Set1|chuy
# processing record27of Set1|nouadhibou
# processing record28of Set1|puerto ayora
# processing record29of Set1|tsihombe
# City Not Found, Pass...:tsihombe
# processing record30of Set1|lavrentiya
# processing record31of Set1|karratha
# processing record32of Set1|kapaa
# processing record33of Set1|waddan
# processing record34of Set1|fortuna
# processing record35of Set1|namibe
# processing record36of Set1|coihaique
# processing record37of Set1|colesberg
# processing record38of Set1|cayenne
# processing record39of Set1|hithadhoo
# processing record40of Set1|mmabatho
# processing record41of Set1|oranjemund
# processing record42of Set1|aklavik
# processing record43of Set1|warner robins
# processing record44of Set1|provideniya
# processing record45of Set1|vanavara
# processing record46of Set1|ushuaia
# processing record47of Set1|salalah
# processing record48of Set1|baculin
# processing record49of Set1|pacific grove
# 2
# 0
# 50
# processing record1of Set2|georgetown
# processing record2of Set2|hofn
# processing record3of Set2|lakatoro
# processing record4of Set2|kodiak
# processing record5of Set2|flinders
# processing record6of Set2|batagay
# processing record7of Set2|beloha
# processing record8of Set2|fort nelson
# processing record9of Set2|mataura
# processing record10of Set2|itarema
# processing record11of Set2|brae
# processing record12of Set2|dingle
# processing record13of Set2|nikolskoye
# processing record14of Set2|penzance
# processing record15of Set2|husavik
# processing record16of Set2|jamestown
# processing record17of Set2|arraial do cabo
# processing record18of Set2|longyearbyen
# processing record19of Set2|dikson
# processing record20of Set2|new norfolk
# processing record21of Set2|pevek
# processing record22of Set2|vila velha
# processing record23of Set2|the valley
# processing record24of Set2|itaituba
# processing record25of Set2|grimshaw
# processing record26of Set2|grand river south east
# City Not Found, Pass...:grand river south east
# processing record27of Set2|grand centre
# City Not Found, Pass...:grand centre
# processing record28of Set2|bud
# processing record29of Set2|dauphin
# processing record30of Set2|teguise
# processing record31of Set2|vaini
# processing record32of Set2|saint-philippe
# processing record33of Set2|avarua
# processing record34of Set2|mahebourg
# processing record35of Set2|sobolevo
# processing record36of Set2|ribeira grande
# processing record37of Set2|bredasdorp
# processing record38of Set2|wisconsin rapids
# processing record39of Set2|faanui
# processing record40of Set2|ilulissat
# processing record41of Set2|butaritari
# processing record42of Set2|bayan
# processing record43of Set2|lugo
# processing record44of Set2|upernavik
# processing record45of Set2|ancud
# processing record46of Set2|thompson
# processing record47of Set2|hanna
# processing record48of Set2|gamba
# processing record49of Set2|goderich
# processing record50of Set2|artyk
# City Not Found, Pass...:artyk
# 3
# 0
# 100
# processing record1of Set3|mendoza
# processing record2of Set3|sentyabrskiy
# City Not Found, Pass...:sentyabrskiy
# processing record3of Set3|sioux lookout
# processing record4of Set3|walvis bay
# processing record5of Set3|ponta do sol
# processing record6of Set3|bluff
# processing record7of Set3|zihuatanejo
# processing record8of Set3|kushiro
# processing record9of Set3|saskylakh
# processing record10of Set3|torbay
# processing record11of Set3|amapa
# processing record12of Set3|shaikhpura
# processing record13of Set3|sandy springs
# processing record14of Set3|shelburne
# processing record15of Set3|warqla
# City Not Found, Pass...:warqla
# processing record16of Set3|ilam
# processing record17of Set3|besikduzu
# processing record18of Set3|taoudenni
# processing record19of Set3|suntar
# processing record20of Set3|tuatapere
# processing record21of Set3|balikpapan
# processing record22of Set3|ilembula
# processing record23of Set3|vannes
# processing record24of Set3|shillong
# processing record25of Set3|los llanos de aridane
# processing record26of Set3|hunza
# City Not Found, Pass...:hunza
# processing record27of Set3|illoqqortoormiut
# City Not Found, Pass...:illoqqortoormiut
# processing record28of Set3|oriximina
# processing record29of Set3|lira
# processing record30of Set3|taolanaro
# City Not Found, Pass...:taolanaro
# processing record31of Set3|anaconda
# processing record32of Set3|baghdad
# processing record33of Set3|anadyr
# processing record34of Set3|ilo
# processing record35of Set3|karamea
# City Not Found, Pass...:karamea
# processing record36of Set3|okha
# processing record37of Set3|chicama
# processing record38of Set3|homer
# processing record39of Set3|rawson
# processing record40of Set3|maragogi
# processing record41of Set3|tasiilaq
# processing record42of Set3|gat
# processing record43of Set3|avigliano
# processing record44of Set3|port hardy
# processing record45of Set3|yellowknife
# processing record46of Set3|maniitsoq
# processing record47of Set3|airai
# processing record48of Set3|atuona
# processing record49of Set3|norman wells
# processing record50of Set3|luderitz
# 4
# 0
# 150
# processing record1of Set4|presidencia roque saenz pena
# processing record2of Set4|vanimo
# processing record3of Set4|butterworth
# processing record4of Set4|saint-pierre
# processing record5of Set4|el cairo
# processing record6of Set4|lerwick
# processing record7of Set4|richards bay
# processing record8of Set4|poso
# processing record9of Set4|santa isabel
# processing record10of Set4|fairbanks
# processing record11of Set4|talawdi
# City Not Found, Pass...:talawdi
# processing record12of Set4|kharan
# processing record13of Set4|kiama
# processing record14of Set4|galiwinku
# City Not Found, Pass...:galiwinku
# processing record15of Set4|narsaq
# processing record16of Set4|tiksi
# processing record17of Set4|castro
# processing record18of Set4|diffa
# processing record19of Set4|khatanga
# processing record20of Set4|vila do maio
# processing record21of Set4|barentsburg
# City Not Found, Pass...:barentsburg
# processing record22of Set4|surgut
# processing record23of Set4|geraldton
# processing record24of Set4|berlevag
# processing record25of Set4|mareeba
# processing record26of Set4|hobart
# processing record27of Set4|omboue
# processing record28of Set4|zaraza
# processing record29of Set4|carnarvon
# processing record30of Set4|solnechnyy
# processing record31of Set4|rocha
# processing record32of Set4|ust-maya
# processing record33of Set4|killam
# processing record34of Set4|pisco
# processing record35of Set4|poum
# processing record36of Set4|dubbo
# processing record37of Set4|poya
# processing record38of Set4|severo-kurilsk
# processing record39of Set4|oliveira dos brejinhos
# processing record40of Set4|cabedelo
# processing record41of Set4|te anau
# processing record42of Set4|vao
# processing record43of Set4|belushya guba
# City Not Found, Pass...:belushya guba
# processing record44of Set4|palabuhanratu
# City Not Found, Pass...:palabuhanratu
# processing record45of Set4|saquena
# processing record46of Set4|gazojak
# processing record47of Set4|mount isa
# processing record48of Set4|namatanai
# processing record49of Set4|laguna
# processing record50of Set4|mackay
# 5
# 0
# 200
# processing record1of Set5|dudinka
# processing record2of Set5|sao filipe
# processing record3of Set5|soyo
# processing record4of Set5|waingapu
# processing record5of Set5|aiken
# processing record6of Set5|leningradskiy
# processing record7of Set5|callaguip
# processing record8of Set5|ruwi
# processing record9of Set5|khonuu
# City Not Found, Pass...:khonuu
# processing record10of Set5|corinto
# processing record11of Set5|tuktoyaktuk
# processing record12of Set5|bargal
# City Not Found, Pass...:bargal
# processing record13of Set5|sinnamary
# processing record14of Set5|coquimbo
# processing record15of Set5|san cristobal
# processing record16of Set5|olafsvik
# processing record17of Set5|asosa
# processing record18of Set5|yeppoon
# processing record19of Set5|zumpango
# processing record20of Set5|norsup
# processing record21of Set5|tura
# processing record22of Set5|havoysund
# processing record23of Set5|manta
# processing record24of Set5|ruteng
# processing record25of Set5|evensk
# processing record26of Set5|attawapiskat
# City Not Found, Pass...:attawapiskat
# processing record27of Set5|aketi
# processing record28of Set5|tuskegee
# processing record29of Set5|saldanha
# processing record30of Set5|aguimes
# processing record31of Set5|shirgaon
# processing record32of Set5|gongzhuling
# processing record33of Set5|palmer
# processing record34of Set5|waipawa
# processing record35of Set5|ponta delgada
# processing record36of Set5|vaitupu
# City Not Found, Pass...:vaitupu
# processing record37of Set5|quatre cocos
# processing record38of Set5|padang
# processing record39of Set5|bardiyah
# processing record40of Set5|iqaluit
# processing record41of Set5|calvinia
# processing record42of Set5|mecca
# processing record43of Set5|livingstonia
# processing record44of Set5|svetla nad sazavou
# processing record45of Set5|umzimvubu
# City Not Found, Pass...:umzimvubu
# processing record46of Set5|dunedin
# processing record47of Set5|samarai
# processing record48of Set5|dzaoudzi
# processing record49of Set5|saint-augustin
# processing record50of Set5|beringovskiy
# 6
# 0
# 250
# processing record1of Set6|santa isabel do rio negro
# processing record2of Set6|victoria
# processing record3of Set6|nortelandia
# processing record4of Set6|saleaula
# City Not Found, Pass...:saleaula
# processing record5of Set6|lhuntshi
# City Not Found, Pass...:lhuntshi
# processing record6of Set6|mirina
# City Not Found, Pass...:mirina
# processing record7of Set6|sucre
# processing record8of Set6|sao joao da barra
# processing record9of Set6|gizo
# processing record10of Set6|neuquen
# processing record11of Set6|tokur
# processing record12of Set6|ust-kamchatsk
# City Not Found, Pass...:ust-kamchatsk
# processing record13of Set6|faya
# processing record14of Set6|lagoa
# processing record15of Set6|fez
# processing record16of Set6|solovetskiy
# City Not Found, Pass...:solovetskiy
# processing record17of Set6|najran
# processing record18of Set6|ambon
# processing record19of Set6|kovdor
# processing record20of Set6|rincon
# processing record21of Set6|nizhneyansk
# City Not Found, Pass...:nizhneyansk
# processing record22of Set6|payakumbuh
# processing record23of Set6|turochak
# processing record24of Set6|havre
# processing record25of Set6|jabinyanah
# processing record26of Set6|udachnyy
# processing record27of Set6|moose factory
# processing record28of Set6|grindavik
# processing record29of Set6|kudahuvadhoo
# processing record30of Set6|misratah
# processing record31of Set6|rognan
# processing record32of Set6|bengkulu
# processing record33of Set6|labuhan
# processing record34of Set6|acarau
# processing record35of Set6|port elizabeth
# processing record36of Set6|buala
# processing record37of Set6|guerrero negro
# processing record38of Set6|skjervoy
# processing record39of Set6|mbanza-ngungu
# processing record40of Set6|cap malheureux
# processing record41of Set6|doctor juan manuel frutos
# processing record42of Set6|male
# processing record43of Set6|wanning
# processing record44of Set6|samusu
# City Not Found, Pass...:samusu
# processing record45of Set6|banjar
# processing record46of Set6|ngukurr
# City Not Found, Pass...:ngukurr
# processing record47of Set6|bethel
# processing record48of Set6|souillac
# processing record49of Set6|barroualie
# City Not Found, Pass...:barroualie
# processing record50of Set6|koulamoutou
# 7
# 0
# 300
# processing record1of Set7|paamiut
# processing record2of Set7|gao
# processing record3of Set7|nuuk
# processing record4of Set7|staryy nadym
# processing record5of Set7|tezu
# processing record6of Set7|clyde river
# processing record7of Set7|masvingo
# processing record8of Set7|herat
# processing record9of Set7|hobyo
# processing record10of Set7|san juan de uraba
# processing record11of Set7|saint george
# processing record12of Set7|saumur
# processing record13of Set7|terrell
# processing record14of Set7|beloye
# processing record15of Set7|petauke
# processing record16of Set7|vostok
# processing record17of Set7|baoshan
# processing record18of Set7|eydhafushi
# processing record19of Set7|beeville
# processing record20of Set7|lorengau
# processing record21of Set7|almaty
# processing record22of Set7|shimoda
# processing record23of Set7|sitka
# processing record24of Set7|katherine
# processing record25of Set7|aykhal
# processing record26of Set7|methoni
# processing record27of Set7|langsa
# processing record28of Set7|sawakin
# processing record29of Set7|anuradhapura
# processing record30of Set7|taltal
# processing record31of Set7|maymyo
# processing record32of Set7|nishihara
# processing record33of Set7|thoen
# processing record34of Set7|hasaki
# processing record35of Set7|barbacena
# processing record36of Set7|erie
# processing record37of Set7|asau
# processing record38of Set7|kita
# processing record39of Set7|tilichiki
# processing record40of Set7|energeticheskiy
# processing record41of Set7|esil
# processing record42of Set7|batagay-alyta
# processing record43of Set7|fairview
# processing record44of Set7|vestmanna
# processing record45of Set7|oshawa
# processing record46of Set7|senador pompeu
# processing record47of Set7|azare
# processing record48of Set7|kieta
# processing record49of Set7|yulara
# processing record50of Set7|luangwa
# 8
# 0
# 350
# processing record1of Set8|havre-saint-pierre
# processing record2of Set8|zhigansk
# processing record3of Set8|manggar
# processing record4of Set8|banda aceh
# processing record5of Set8|cuamba
# processing record6of Set8|gravdal
# processing record7of Set8|kaupanger
# processing record8of Set8|noumea
# processing record9of Set8|panaba
# processing record10of Set8|broken hill
# processing record11of Set8|manaus
# processing record12of Set8|kruisfontein
# processing record13of Set8|sangar
# processing record14of Set8|tanete
# processing record15of Set8|nampula
# processing record16of Set8|avera
# processing record17of Set8|oktyabrskiy
# processing record18of Set8|kirakira
# processing record19of Set8|ulaangom
# processing record20of Set8|dalbandin
# processing record21of Set8|verkhnyaya maksakovka
# processing record22of Set8|washington
# processing record23of Set8|calabar
# processing record24of Set8|kloulklubed
# processing record25of Set8|broome
# processing record26of Set8|lokosovo
# processing record27of Set8|noshiro
# processing record28of Set8|straseni
# processing record29of Set8|santa rosa
# processing record30of Set8|windsor
# processing record31of Set8|san patricio
# processing record32of Set8|kavaratti
# processing record33of Set8|cockburn town
# processing record34of Set8|carinhanha
# processing record35of Set8|tres picos
# processing record36of Set8|pucallpa
# processing record37of Set8|challapata
# processing record38of Set8|pinheiro
# processing record39of Set8|belem de sao francisco
# processing record40of Set8|el balyana
# City Not Found, Pass...:el balyana
# processing record41of Set8|cubuk
# processing record42of Set8|erenhot
# processing record43of Set8|pangnirtung
# processing record44of Set8|pokhara
# processing record45of Set8|caravelas
# processing record46of Set8|skelleftea
# processing record47of Set8|termoli
# processing record48of Set8|miri
# processing record49of Set8|wulanhaote
# City Not Found, Pass...:wulanhaote
# processing record50of Set8|margate
# 9
# 0
# 400
# processing record1of Set9|inongo
# processing record2of Set9|balezino
# processing record3of Set9|santo antonio do ica
# processing record4of Set9|ostrovnoy
# processing record5of Set9|tabiauea
# City Not Found, Pass...:tabiauea
# processing record6of Set9|krasne
# processing record7of Set9|sambava
# processing record8of Set9|meulaboh
# processing record9of Set9|gaoual
# processing record10of Set9|kambove
# processing record11of Set9|zhanaozen
# processing record12of Set9|vyazemskiy
# processing record13of Set9|novobelokatay
# processing record14of Set9|akdepe
# processing record15of Set9|russell
# processing record16of Set9|haibowan
# City Not Found, Pass...:haibowan
# processing record17of Set9|sompeta
# processing record18of Set9|svetlogorsk
# processing record19of Set9|nipawin
# processing record20of Set9|marawi
# processing record21of Set9|ronneby
# processing record22of Set9|vilhena
# processing record23of Set9|mapiri
# processing record24of Set9|siverek
# processing record25of Set9|clive
# processing record26of Set9|baruun-urt
# processing record27of Set9|majengo
# processing record28of Set9|jaipur hat
# City Not Found, Pass...:jaipur hat
# processing record29of Set9|ialibu
# processing record30of Set9|maloy
# processing record31of Set9|cordoba
# processing record32of Set9|marquette
# processing record33of Set9|ambikapur
# processing record34of Set9|bambous virieux
# processing record35of Set9|zhezkazgan
# processing record36of Set9|scalea
# processing record37of Set9|kathmandu
# processing record38of Set9|ovre ardal
# processing record39of Set9|cidreira
# processing record40of Set9|isangel
# processing record41of Set9|rio grande
# processing record42of Set9|lahij
# processing record43of Set9|shenjiamen
# processing record44of Set9|tual
# processing record45of Set9|acara
# processing record46of Set9|necochea
# processing record47of Set9|waterboro
# processing record48of Set9|marcona
# City Not Found, Pass...:marcona
# processing record49of Set9|saint-francois
# processing record50of Set9|guthrie
# 10
# 0
# 450
# processing record1of Set10|altagracia de orituco
# processing record2of Set10|bonavista
# processing record3of Set10|hanzhong
# processing record4of Set10|martapura
# processing record5of Set10|imbituba
# processing record6of Set10|whitehorse
# processing record7of Set10|asyut
# processing record8of Set10|port-gentil
# processing record9of Set10|tabat
# processing record10of Set10|pointe michel
# processing record11of Set10|kaisiadorys
# processing record12of Set10|eureka
# processing record13of Set10|baykit
# processing record14of Set10|altar
# processing record15of Set10|tingo maria
# processing record16of Set10|nome
# processing record17of Set10|keningau
# processing record18of Set10|kailua
# processing record19of Set10|bosaso
# processing record20of Set10|cururupu
# processing record21of Set10|picsi
# processing record22of Set10|tiarei
# processing record23of Set10|codrington
# processing record24of Set10|jacareacanga
# processing record25of Set10|lolua
# City Not Found, Pass...:lolua
# processing record26of Set10|vengerovo
# processing record27of Set10|bamnet narong
# processing record28of Set10|verkhnevilyuysk
# processing record29of Set10|amderma
# City Not Found, Pass...:amderma
# processing record30of Set10|kutum
# processing record31of Set10|ust-bolsheretsk
# City Not Found, Pass...:ust-bolsheretsk
# processing record32of Set10|visnes
# processing record33of Set10|hualmay
# processing record34of Set10|eirunepe
# processing record35of Set10|vila franca do campo
# processing record36of Set10|okhotsk
# processing record37of Set10|dickson
# processing record38of Set10|san quintin
# processing record39of Set10|muros
# processing record40of Set10|pakala
# processing record41of Set10|we
# City Not Found, Pass...:we
# processing record42of Set10|alofi
# processing record43of Set10|lodja
# processing record44of Set10|mgandu
# processing record45of Set10|ketchikan
# processing record46of Set10|pochutla
# processing record47of Set10|pemba
# processing record48of Set10|xiangdong
# City Not Found, Pass...:xiangdong
# processing record49of Set10|touros
# processing record50of Set10|qaqortoq
# 11
# 0
# 500
# processing record1of Set11|surt
# processing record2of Set11|krasnoselkup
# processing record3of Set11|san-pedro
# processing record4of Set11|mayor pablo lagerenza
# processing record5of Set11|vrangel
# processing record6of Set11|nanortalik
# processing record7of Set11|praia da vitoria
# processing record8of Set11|davila
# processing record9of Set11|khani
# processing record10of Set11|kjellerup
# processing record11of Set11|sarkand
# processing record12of Set11|bathsheba
# processing record13of Set11|churapcha
# processing record14of Set11|galle
# processing record15of Set11|jaumave
# processing record16of Set11|jizan
# processing record17of Set11|ngama
# processing record18of Set11|roald
# processing record19of Set11|teberda
# processing record20of Set11|sorvag
# City Not Found, Pass...:sorvag
# processing record21of Set11|ondorhaan
# City Not Found, Pass...:ondorhaan
# processing record22of Set11|hami
# processing record23of Set11|natal
# processing record24of Set11|ahipara
# processing record25of Set11|holme
# processing record26of Set11|bacolod
# processing record27of Set11|nyalikungu
# processing record28of Set11|bandarbeyla
# processing record29of Set11|agadir
# processing record30of Set11|ola
# processing record31of Set11|college
# processing record32of Set11|labrea
# processing record33of Set11|rundu
# processing record34of Set11|cananeia
# processing record35of Set11|aripuana
# processing record36of Set11|henties bay
# processing record37of Set11|rosetta
# processing record38of Set11|belaya gora
# processing record39of Set11|monze
# processing record40of Set11|mount gambier
# processing record41of Set11|obidos
# processing record42of Set11|volokonovka
# processing record43of Set11|hambantota
# processing record44of Set11|abrau-dyurso
# processing record45of Set11|chabua
# processing record46of Set11|sofia
# processing record47of Set11|savannakhet
# processing record48of Set11|jiwani
# processing record49of Set11|auki
# processing record50of Set11|atar
# 12
# 0
# 550
# processing record1of Set12|vestmannaeyjar
# processing record2of Set12|mapiripan
# processing record3of Set12|acapulco
# processing record4of Set12|hirara
# processing record5of Set12|lephepe
# City Not Found, Pass...:lephepe
# processing record6of Set12|harlingen
# processing record7of Set12|carauari
# processing record8of Set12|kahului
# processing record9of Set12|la ronge
# processing record10of Set12|ugoofaaru
# processing record11of Set12|truth or consequences
# processing record12of Set12|dongsheng
# processing record13of Set12|dzilam gonzalez
# processing record14of Set12|puksoozero
# processing record15of Set12|sao gabriel da cachoeira
# processing record16of Set12|yazman
# processing record17of Set12|bichura
# processing record18of Set12|vila
# processing record19of Set12|ulaanbaatar
# processing record20of Set12|sataua
# City Not Found, Pass...:sataua
# processing record21of Set12|shache
# processing record22of Set12|inhambane
# processing record23of Set12|manokwari
# processing record24of Set12|aguilas
# processing record25of Set12|mount vernon
# processing record26of Set12|zwedru
# processing record27of Set12|port lincoln
# processing record28of Set12|shingu
# processing record29of Set12|trairi
# processing record30of Set12|viransehir
# processing record31of Set12|tarudant
# City Not Found, Pass...:tarudant
# processing record32of Set12|prince rupert
# processing record33of Set12|xam nua
# processing record34of Set12|rosemont
# processing record35of Set12|coahuayana
# processing record36of Set12|tumannyy
# City Not Found, Pass...:tumannyy
# processing record37of Set12|nanyamba
# processing record38of Set12|sorong
# processing record39of Set12|missoula
# processing record40of Set12|kardailovo
# processing record41of Set12|ramos arizpe
# processing record42of Set12|tianpeng
# processing record43of Set12|kalmunai
# processing record44of Set12|ciudad guayana
# processing record45of Set12|joigny
# processing record46of Set12|rangapara
# processing record47of Set12|kuopio
# processing record48of Set12|fuyu
# processing record49of Set12|bairiki
# processing record50of Set12|moranbah
# 13
# 0
# 600
# processing record1of Set13|alice springs
# processing record2of Set13|constantine
# processing record3of Set13|motozintla
# processing record4of Set13|erzin
# processing record5of Set13|manzanillo
# processing record6of Set13|zhanakorgan
# processing record7of Set13|portland
# processing record8of Set13|saint-paul
# processing record9of Set13|calamar
# processing record10of Set13|medicine hat
# processing record11of Set13|haapu
# City Not Found, Pass...:haapu
# processing record12of Set13|pandan
# processing record13of Set13|knysna
# 13

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Creating a DataFrame
city_data_pd = pd.DataFrame({"City":city_list,
                         "Lat":lat_list,
                         "Lng":lng_list,
                         "Max Temp":max_temp_list,
                         "Humidity":humidity_list,
                         "Cloudiness":cloudiness_list,
                         "Wind Speed":windspeed_list,
                            })

pd.DataFrame.to_csv(city_data_pd, 'city_data.csv')

# city_data_pd.head()
city_data_pd.count()
# Out:
# City          564
# Lat           564
# Lng           564
# Max Temp      564
# Humidity      564
# Cloudiness    564
# Wind Speed    564
# dtype: int64

# %%
weather_dict = {"City":city_list,
                         "Lat":lat_list,
                         "Lng":lng_list,
                         "Max Temp":max_temp_list,
                         "Humidity":humidity_list,
                         "Cloudiness":cloudiness_list,
                         "Wind Speed":windspeed_list,
}

# %%
weather_df = pd.DataFrame(weather_dict)
weather_df.head()
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Hermanus -34.4187   19.2345    288.04        86         100
# 1   Punta Arenas -53.1500  -70.9167    279.88        79         100
# 2  Mar del Plata -38.0023  -57.5575    284.33        62           0
# 3        Kavieng  -2.5744  150.7967    302.97        68          17
# 4         Barrow  71.2906 -156.7887    272.16        86          90
#
#    Wind Speed
# 0        7.32
# 1        4.51
# 2        1.34
# 3        2.73
# 4        4.63

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(weather_df['Lat'], weather_df['Max Temp'], edgecolor="blue", linewidths=1, marker="0",
           alpha=0.8, label="Cities")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.title("City Latitude vs. Max Temperature (05/19/2021)")
plt.savefig("Max_temp.png")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\markers.py in set_marker(self, marker)
#     304             try:
# --> 305                 Path(marker)
#     306                 self._marker_function = self._set_vertices
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\path.py in __init__(self, vertices, codes, _interpolation_steps, closed, readonly)
#     131         vertices = _to_unmasked_float_array(vertices)
# --> 132         cbook._check_shape((None, 2), vertices=vertices)
#     133
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py in _check_shape(_shape, **kwargs)
#    2302
# -> 2303             raise ValueError(
#    2304                 f"{k!r} must be {len(target_shape)}D "
#
# ValueError: 'vertices' must be 2D with shape (M, 2). Your input has shape ().
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-3b255df6ae40> in <module>
# ----> 1 plt.scatter(weather_df['Lat'], weather_df['Max Temp'], edgecolor="blue", linewidths=1, marker="0",
#       2            alpha=0.8, label="Cities")
#       3 plt.xlabel("Latitude")
#       4 plt.ylabel("Max Temperature (F)")
#       5 plt.title("City Latitude vs. Max Temperature (05/19/2021)")
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2888         verts=cbook.deprecation._deprecated_parameter,
#    2889         edgecolors=None, *, plotnonfinite=False, data=None, **kwargs):
# -> 2890     __ret = gca().scatter(
#    2891         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2892         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# -> 1447             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448
#    1449         bound = new_sig.bind(ax, *args, **kwargs)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, **kwargs)
#    4471             marker_obj = marker
#    4472         else:
# -> 4473             marker_obj = mmarkers.MarkerStyle(marker)
#    4474
#    4475         path = marker_obj.get_path().transformed(
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\markers.py in __init__(self, marker, fillstyle)
#     226         self._marker_function = None
#     227         self.set_fillstyle(fillstyle)
# --> 228         self.set_marker(marker)
#     229
#     230     def _recache(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\markers.py in set_marker(self, marker)
#     306                 self._marker_function = self._set_vertices
#     307             except ValueError as err:
# --> 308                 raise ValueError('Unrecognized marker style {!r}'
#     309                                  .format(marker)) from err
#     310
#
# ValueError: Unrecognized marker style '0'

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(weather_df['Lat'], weather_df['Humidity'], edgecolor="blue", linewidths=1, marker="0",
           alpha=0.8, label="Cities")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("City Latitude vs. Humidity (05/19/2021)")
plt.savefig("Humidity.png")

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
