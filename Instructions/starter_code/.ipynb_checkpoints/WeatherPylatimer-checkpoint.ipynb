# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []
country_codes =[]

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.00, size=1500)
lat_lngs = zip(lats, lngs)
city = citipy

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 627

# %%
print(cities)
# Out:
# ['busselton', 'kapaa', 'vaini', 'bakchar', 'new norfolk', 'ponta do sol', 'truth or consequences', 'aljezur', 'palabuhanratu', 'besikduzu', 'taolanaro', 'nikolskoye', 'kaitangata', 'pundaguitan', 'columbus', 'punta arenas', 'puerto ayora', 'rikitea', 'mataura', 'mount gambier', 'meulaboh', 'mar del plata', 'arraial do cabo', 'oliveira dos brejinhos', 'albany', 'tuktoyaktuk', 'nava', 'hobart', 'felipe carrillo puerto', 'williamsport', 'butaritari', 'praia', 'viedma', 'provideniya', 'glendive', 'ushuaia', 'petatlan', 'bijapur', 'cape town', 'castro', 'hithadhoo', 'turukhansk', 'verkhnyaya inta', 'namtsy', 'flinders', 'bethel', 'illoqqortoormiut', 'carnarvon', 'tabiauea', 'matamoros', 'alexandria', 'lagoa', 'codrington', 'moree', 'sao filipe', 'sur', 'tutoia', 'qeshm', 'cidreira', 'dikson', 'saint-philippe', 'pemangkat', 'east london', 'dawlatabad', 'tasiilaq', 'mzimba', 'pervomayskoye', 'wajima', 'ixtapa', 'taloda', 'la ronge', 'porbandar', 'hilo', 'leningradskiy', 'georgetown', 'san rafael', 'barbar', 'jamestown', 'calbuco', 'sentyabrskiy', 'saint george', 'maua', 'safaga', 'torbay', 'port blair', 'rapid city', 'kamenka', 'airai', 'shahpur', 'tura', 'ochakiv', 'marcona', 'saskylakh', 'yurgamysh', 'souillac', 'touros', 'mys shmidta', 'aklavik', 'luderitz', 'komsomolskiy', 'saint anthony', 'samusu', 'sheffield', 'yellowknife', 'lucea', 'charlestown', 'sechura', 'qaanaaq', 'sarkand', 'maloshuyka', 'djambala', 'hvide sande', 'hermanus', 'seminole', 'upernavik', 'dikaia', 'avarua', 'nova serrana', 'atuona', 'bokspits', 'severo-kurilsk', 'zhuhai', 'longyearbyen', 'kidal', 'bambous virieux', 'dunedin', 'sampit', 'xadani', 'vila franca do campo', 'amberieu-en-bugey', 'yar-sale', 'pestravka', 'hobe sound', 'guerrero negro', 'omsukchan', 'merauke', 'thakurganj', 'tooele', 'zhezkazgan', 'asfi', 'durango', 'ketchikan', 'tvoroyri', 'faanui', 'awbari', 'kabo', 'bengkulu', 'krasnoselkup', 'etaples', 'show low', 'chuy', 'vardo', 'port hedland', 'lorengau', 'barentsburg', 'caracoli', 'bluff', 'pamanukan', 'beyneu', 'san lorenzo', 'bacolod', 'san nicolas', 'isangel', 'yarkovo', 'labuhan', 'bilsanda', 'pune', 'mweka', 'thunder bay', 'chimoio', 'bria', 'orapa', 'kiboga', 'laguna', 'esqueda', 'sao gabriel da cachoeira', 'hanstholm', 'mayumba', 'cherskiy', 'tuatapere', 'kenai', 'saint-louis', 'tawkar', 'barrow', 'san patricio', 'kodiak', 'salalah', 'tumannyy', 'constitucion', 'margate', 'corowa', 'pacific grove', 'tashir', 'yaan', 'voineasa', 'puno', 'edd', 'girona', 'srednekolymsk', 'kargasok', 'huangnihe', 'rio gallegos', 'betsiamites', 'fairbanks', 'moose factory', 'port alfred', 'port pirie', 'kawana waters', 'kleck', 'miranda', 'naze', 'portales', 'leogane', 'puerto carreno', 'lebu', 'port lincoln', 'saleaula', 'grand river south east', 'warqla', 'marathon', 'cavan', 'san cristobal', 'chokurdakh', 'lewistown', 'voi', 'sibolga', 'adrar', 'murgab', 'luanda', 'nuuk', 'najran', 'rochester', 'toba tek singh', 'camana', 'buala', 'neustrelitz', 'attawapiskat', 'arkhangelskoye', 'nargana', 'grindavik', 'ghansor', 'conceicao da barra', 'maarianhamina', 'port elizabeth', 'hofn', 'gao', 'nanortalik', 'mamu kanjan', 'port augusta', 'urdzhar', 'bredasdorp', 'borba', 'carupano', 'dubai', 'nizhneyansk', 'la libertad', 'piacabucu', 'puerto del rosario', 'caravelas', 'mago', 'roebourne', 'villa carlos paz', 'mount isa', 'laela', 'buchanan', 'oktyabrskiy', 'tiksi', 'sembe', 'esperance', 'college', 'thompson', 'bilsi', 'traverse city', 'trofors', 'vanavara', 'fuerte', 'shahr-e babak', 'kavieng', 'ustye', 'gamba', 'davila', 'chicama', 'talnakh', 'oron', 'karaul', 'la rioja', 'norman wells', 'tiznit', 'strathmore', 'hasaki', 'cayenne', 'lavrentiya', 'sobolevo', 'maningrida', 'tsihombe', 'porto novo', 'sorland', 'ugoofaaru', 'mushie', 'yulara', 'ha giang', 'pinar del rio', 'oparino', 'grand gaube', 'mangai', 'ust-tarka', 'stromness', 'nichinan', 'valparaiso', 'ribeira grande', 'hernani', 'funadhoo', 'ust-omchug', 'suntar', 'kalianget', 'puerto colombia', 'izhma', 'p ...

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?q="

# Data list of Cities
city_list = []
lat_list = []
lng_list = []
max_temp_list = []
humidity_list = []
cloudiness_list = []
windspeed_list = []
date = []
counter = 0
record_counter = 0
setcount = 1


for city in cities:
    counter += 1
    if (counter % 50 == 0):
        setcount += 1
        record_counter =0
        print(setcount)
        print(record_counter)
        print(counter)
    record_counter += 1
    print("processing record" + str(record_counter) +"of Set" + str(setcount) +"|" +city)
    try: 
        weather_response = requests.get(f"{url}{city}&appid={weather_api_key}").json()
        city_list.append(weather_response['name'])
        lat_list.append(weather_response['coord']['lat'])
        lng_list.append(weather_response['coord']['lon'])
        max_temp_list.append(weather_response['main']['temp_max'])
        humidity_list.append(weather_response['main']['humidity'])
        cloudiness_list.append(weather_response['clouds']['all'])
        windspeed_list.append(weather_response['wind']['speed'])
    except:
        print("City Not Found, Pass...:" + city)

        
print(len(weather_response))
# Out:
# processing record1of Set1|busselton
# processing record2of Set1|kapaa
# processing record3of Set1|vaini
# processing record4of Set1|bakchar
# processing record5of Set1|new norfolk
# processing record6of Set1|ponta do sol
# processing record7of Set1|truth or consequences
# processing record8of Set1|aljezur
# processing record9of Set1|palabuhanratu
# City Not Found, Pass...:palabuhanratu
# processing record10of Set1|besikduzu
# processing record11of Set1|taolanaro
# City Not Found, Pass...:taolanaro
# processing record12of Set1|nikolskoye
# processing record13of Set1|kaitangata
# processing record14of Set1|pundaguitan
# processing record15of Set1|columbus
# processing record16of Set1|punta arenas
# processing record17of Set1|puerto ayora
# processing record18of Set1|rikitea
# processing record19of Set1|mataura
# processing record20of Set1|mount gambier
# processing record21of Set1|meulaboh
# processing record22of Set1|mar del plata
# processing record23of Set1|arraial do cabo
# processing record24of Set1|oliveira dos brejinhos
# processing record25of Set1|albany
# processing record26of Set1|tuktoyaktuk
# processing record27of Set1|nava
# processing record28of Set1|hobart
# processing record29of Set1|felipe carrillo puerto
# processing record30of Set1|williamsport
# processing record31of Set1|butaritari
# processing record32of Set1|praia
# processing record33of Set1|viedma
# processing record34of Set1|provideniya
# processing record35of Set1|glendive
# processing record36of Set1|ushuaia
# processing record37of Set1|petatlan
# processing record38of Set1|bijapur
# processing record39of Set1|cape town
# processing record40of Set1|castro
# processing record41of Set1|hithadhoo
# processing record42of Set1|turukhansk
# processing record43of Set1|verkhnyaya inta
# processing record44of Set1|namtsy
# processing record45of Set1|flinders
# processing record46of Set1|bethel
# processing record47of Set1|illoqqortoormiut
# City Not Found, Pass...:illoqqortoormiut
# processing record48of Set1|carnarvon
# processing record49of Set1|tabiauea
# City Not Found, Pass...:tabiauea
# 2
# 0
# 50
# processing record1of Set2|matamoros
# processing record2of Set2|alexandria
# processing record3of Set2|lagoa
# processing record4of Set2|codrington
# processing record5of Set2|moree
# processing record6of Set2|sao filipe
# processing record7of Set2|sur
# processing record8of Set2|tutoia
# processing record9of Set2|qeshm
# processing record10of Set2|cidreira
# processing record11of Set2|dikson
# processing record12of Set2|saint-philippe
# processing record13of Set2|pemangkat
# processing record14of Set2|east london
# processing record15of Set2|dawlatabad
# processing record16of Set2|tasiilaq
# processing record17of Set2|mzimba
# processing record18of Set2|pervomayskoye
# processing record19of Set2|wajima
# processing record20of Set2|ixtapa
# processing record21of Set2|taloda
# processing record22of Set2|la ronge
# processing record23of Set2|porbandar
# processing record24of Set2|hilo
# processing record25of Set2|leningradskiy
# processing record26of Set2|georgetown
# processing record27of Set2|san rafael
# processing record28of Set2|barbar
# City Not Found, Pass...:barbar
# processing record29of Set2|jamestown
# processing record30of Set2|calbuco
# processing record31of Set2|sentyabrskiy
# City Not Found, Pass...:sentyabrskiy
# processing record32of Set2|saint george
# processing record33of Set2|maua
# processing record34of Set2|safaga
# processing record35of Set2|torbay
# processing record36of Set2|port blair
# processing record37of Set2|rapid city
# processing record38of Set2|kamenka
# processing record39of Set2|airai
# processing record40of Set2|shahpur
# processing record41of Set2|tura
# processing record42of Set2|ochakiv
# processing record43of Set2|marcona
# City Not Found, Pass...:marcona
# processing record44of Set2|saskylakh
# processing record45of Set2|yurgamysh
# processing record46of Set2|souillac
# processing record47of Set2|touros
# processing record48of Set2|mys shmidta
# City Not Found, Pass...:mys shmidta
# processing record49of Set2|aklavik
# processing record50of Set2|luderitz
# 3
# 0
# 100
# processing record1of Set3|komsomolskiy
# processing record2of Set3|saint anthony
# processing record3of Set3|samusu
# City Not Found, Pass...:samusu
# processing record4of Set3|sheffield
# processing record5of Set3|yellowknife
# processing record6of Set3|lucea
# processing record7of Set3|charlestown
# processing record8of Set3|sechura
# processing record9of Set3|qaanaaq
# processing record10of Set3|sarkand
# processing record11of Set3|maloshuyka
# City Not Found, Pass...:maloshuyka
# processing record12of Set3|djambala
# processing record13of Set3|hvide sande
# processing record14of Set3|hermanus
# processing record15of Set3|seminole
# processing record16of Set3|upernavik
# processing record17of Set3|dikaia
# City Not Found, Pass...:dikaia
# processing record18of Set3|avarua
# processing record19of Set3|nova serrana
# processing record20of Set3|atuona
# processing record21of Set3|bokspits
# City Not Found, Pass...:bokspits
# processing record22of Set3|severo-kurilsk
# processing record23of Set3|zhuhai
# processing record24of Set3|longyearbyen
# processing record25of Set3|kidal
# processing record26of Set3|bambous virieux
# processing record27of Set3|dunedin
# processing record28of Set3|sampit
# processing record29of Set3|xadani
# City Not Found, Pass...:xadani
# processing record30of Set3|vila franca do campo
# processing record31of Set3|amberieu-en-bugey
# processing record32of Set3|yar-sale
# processing record33of Set3|pestravka
# processing record34of Set3|hobe sound
# processing record35of Set3|guerrero negro
# processing record36of Set3|omsukchan
# processing record37of Set3|merauke
# processing record38of Set3|thakurganj
# processing record39of Set3|tooele
# processing record40of Set3|zhezkazgan
# processing record41of Set3|asfi
# processing record42of Set3|durango
# processing record43of Set3|ketchikan
# processing record44of Set3|tvoroyri
# processing record45of Set3|faanui
# processing record46of Set3|awbari
# processing record47of Set3|kabo
# processing record48of Set3|bengkulu
# processing record49of Set3|krasnoselkup
# processing record50of Set3|etaples
# 4
# 0
# 150
# processing record1of Set4|show low
# processing record2of Set4|chuy
# processing record3of Set4|vardo
# processing record4of Set4|port hedland
# processing record5of Set4|lorengau
# processing record6of Set4|barentsburg
# City Not Found, Pass...:barentsburg
# processing record7of Set4|caracoli
# processing record8of Set4|bluff
# processing record9of Set4|pamanukan
# processing record10of Set4|beyneu
# processing record11of Set4|san lorenzo
# processing record12of Set4|bacolod
# processing record13of Set4|san nicolas
# processing record14of Set4|isangel
# processing record15of Set4|yarkovo
# processing record16of Set4|labuhan
# processing record17of Set4|bilsanda
# processing record18of Set4|pune
# processing record19of Set4|mweka
# processing record20of Set4|thunder bay
# processing record21of Set4|chimoio
# processing record22of Set4|bria
# processing record23of Set4|orapa
# processing record24of Set4|kiboga
# processing record25of Set4|laguna
# processing record26of Set4|esqueda
# processing record27of Set4|sao gabriel da cachoeira
# processing record28of Set4|hanstholm
# processing record29of Set4|mayumba
# processing record30of Set4|cherskiy
# processing record31of Set4|tuatapere
# processing record32of Set4|kenai
# processing record33of Set4|saint-louis
# processing record34of Set4|tawkar
# City Not Found, Pass...:tawkar
# processing record35of Set4|barrow
# processing record36of Set4|san patricio
# processing record37of Set4|kodiak
# processing record38of Set4|salalah
# processing record39of Set4|tumannyy
# City Not Found, Pass...:tumannyy
# processing record40of Set4|constitucion
# processing record41of Set4|margate
# processing record42of Set4|corowa
# processing record43of Set4|pacific grove
# processing record44of Set4|tashir
# processing record45of Set4|yaan
# processing record46of Set4|voineasa
# processing record47of Set4|puno
# processing record48of Set4|edd
# processing record49of Set4|girona
# processing record50of Set4|srednekolymsk
# 5
# 0
# 200
# processing record1of Set5|kargasok
# processing record2of Set5|huangnihe
# processing record3of Set5|rio gallegos
# processing record4of Set5|betsiamites
# processing record5of Set5|fairbanks
# processing record6of Set5|moose factory
# processing record7of Set5|port alfred
# processing record8of Set5|port pirie
# processing record9of Set5|kawana waters
# City Not Found, Pass...:kawana waters
# processing record10of Set5|kleck
# City Not Found, Pass...:kleck
# processing record11of Set5|miranda
# processing record12of Set5|naze
# processing record13of Set5|portales
# processing record14of Set5|leogane
# processing record15of Set5|puerto carreno
# processing record16of Set5|lebu
# processing record17of Set5|port lincoln
# processing record18of Set5|saleaula
# City Not Found, Pass...:saleaula
# processing record19of Set5|grand river south east
# City Not Found, Pass...:grand river south east
# processing record20of Set5|warqla
# City Not Found, Pass...:warqla
# processing record21of Set5|marathon
# processing record22of Set5|cavan
# processing record23of Set5|san cristobal
# processing record24of Set5|chokurdakh
# processing record25of Set5|lewistown
# processing record26of Set5|voi
# processing record27of Set5|sibolga
# processing record28of Set5|adrar
# processing record29of Set5|murgab
# processing record30of Set5|luanda
# processing record31of Set5|nuuk
# processing record32of Set5|najran
# processing record33of Set5|rochester
# processing record34of Set5|toba tek singh
# processing record35of Set5|camana
# processing record36of Set5|buala
# processing record37of Set5|neustrelitz
# processing record38of Set5|attawapiskat
# City Not Found, Pass...:attawapiskat
# processing record39of Set5|arkhangelskoye
# processing record40of Set5|nargana
# processing record41of Set5|grindavik
# processing record42of Set5|ghansor
# processing record43of Set5|conceicao da barra
# processing record44of Set5|maarianhamina
# processing record45of Set5|port elizabeth
# processing record46of Set5|hofn
# processing record47of Set5|gao
# processing record48of Set5|nanortalik
# processing record49of Set5|mamu kanjan
# processing record50of Set5|port augusta
# 6
# 0
# 250
# processing record1of Set6|urdzhar
# City Not Found, Pass...:urdzhar
# processing record2of Set6|bredasdorp
# processing record3of Set6|borba
# processing record4of Set6|carupano
# processing record5of Set6|dubai
# processing record6of Set6|nizhneyansk
# City Not Found, Pass...:nizhneyansk
# processing record7of Set6|la libertad
# processing record8of Set6|piacabucu
# processing record9of Set6|puerto del rosario
# processing record10of Set6|caravelas
# processing record11of Set6|mago
# processing record12of Set6|roebourne
# processing record13of Set6|villa carlos paz
# processing record14of Set6|mount isa
# processing record15of Set6|laela
# processing record16of Set6|buchanan
# processing record17of Set6|oktyabrskiy
# processing record18of Set6|tiksi
# processing record19of Set6|sembe
# processing record20of Set6|esperance
# processing record21of Set6|college
# processing record22of Set6|thompson
# processing record23of Set6|bilsi
# processing record24of Set6|traverse city
# processing record25of Set6|trofors
# processing record26of Set6|vanavara
# processing record27of Set6|fuerte
# processing record28of Set6|shahr-e babak
# processing record29of Set6|kavieng
# processing record30of Set6|ustye
# processing record31of Set6|gamba
# processing record32of Set6|davila
# processing record33of Set6|chicama
# processing record34of Set6|talnakh
# processing record35of Set6|oron
# processing record36of Set6|karaul
# City Not Found, Pass...:karaul
# processing record37of Set6|la rioja
# processing record38of Set6|norman wells
# processing record39of Set6|tiznit
# processing record40of Set6|strathmore
# processing record41of Set6|hasaki
# processing record42of Set6|cayenne
# processing record43of Set6|lavrentiya
# processing record44of Set6|sobolevo
# processing record45of Set6|maningrida
# processing record46of Set6|tsihombe
# City Not Found, Pass...:tsihombe
# processing record47of Set6|porto novo
# processing record48of Set6|sorland
# processing record49of Set6|ugoofaaru
# processing record50of Set6|mushie
# 7
# 0
# 300
# processing record1of Set7|yulara
# processing record2of Set7|ha giang
# processing record3of Set7|pinar del rio
# processing record4of Set7|oparino
# processing record5of Set7|grand gaube
# processing record6of Set7|mangai
# processing record7of Set7|ust-tarka
# processing record8of Set7|stromness
# processing record9of Set7|nichinan
# processing record10of Set7|valparaiso
# processing record11of Set7|ribeira grande
# processing record12of Set7|hernani
# processing record13of Set7|funadhoo
# processing record14of Set7|ust-omchug
# processing record15of Set7|suntar
# processing record16of Set7|kalianget
# processing record17of Set7|puerto colombia
# processing record18of Set7|izhma
# processing record19of Set7|port shepstone
# processing record20of Set7|saint-georges
# processing record21of Set7|eureka
# processing record22of Set7|tsentralnyy
# City Not Found, Pass...:tsentralnyy
# processing record23of Set7|necochea
# processing record24of Set7|tobetsu
# processing record25of Set7|lompoc
# processing record26of Set7|colac
# processing record27of Set7|beloha
# processing record28of Set7|khatanga
# processing record29of Set7|zhigansk
# processing record30of Set7|botro
# processing record31of Set7|fiche
# processing record32of Set7|vila velha
# processing record33of Set7|bubaque
# processing record34of Set7|kaohsiung
# processing record35of Set7|vernon
# processing record36of Set7|sao joao da barra
# processing record37of Set7|alibag
# processing record38of Set7|alappuzha
# processing record39of Set7|naifaru
# processing record40of Set7|mitsamiouli
# processing record41of Set7|mahebourg
# processing record42of Set7|shubarkuduk
# processing record43of Set7|shizunai
# processing record44of Set7|cockburn town
# processing record45of Set7|ventspils
# processing record46of Set7|adet
# processing record47of Set7|namibe
# processing record48of Set7|padang
# processing record49of Set7|usa river
# processing record50of Set7|husavik
# 8
# 0
# 350
# processing record1of Set8|arlit
# processing record2of Set8|dhidhdhoo
# processing record3of Set8|robertsport
# processing record4of Set8|broken hill
# processing record5of Set8|kahului
# processing record6of Set8|bukama
# processing record7of Set8|fortuna
# processing record8of Set8|mehamn
# processing record9of Set8|kieta
# processing record10of Set8|kloulklubed
# processing record11of Set8|morondava
# processing record12of Set8|kaputa
# processing record13of Set8|avera
# processing record14of Set8|karakendzha
# City Not Found, Pass...:karakendzha
# processing record15of Set8|montague
# processing record16of Set8|sitka
# processing record17of Set8|paradwip
# City Not Found, Pass...:paradwip
# processing record18of Set8|hambantota
# processing record19of Set8|grand-santi
# processing record20of Set8|ilulissat
# processing record21of Set8|mogadishu
# processing record22of Set8|sakakah
# processing record23of Set8|hay river
# processing record24of Set8|nalut
# processing record25of Set8|benguela
# processing record26of Set8|juneau
# processing record27of Set8|itoman
# processing record28of Set8|klaksvik
# processing record29of Set8|rosetta
# processing record30of Set8|shetpe
# processing record31of Set8|carikar
# City Not Found, Pass...:carikar
# processing record32of Set8|barranca
# processing record33of Set8|la palma
# processing record34of Set8|lolua
# City Not Found, Pass...:lolua
# processing record35of Set8|ahipara
# processing record36of Set8|kirakira
# processing record37of Set8|wulanhaote
# City Not Found, Pass...:wulanhaote
# processing record38of Set8|nguiu
# City Not Found, Pass...:nguiu
# processing record39of Set8|christchurch
# processing record40of Set8|kushiro
# processing record41of Set8|lalmohan
# processing record42of Set8|alma
# processing record43of Set8|geraldton
# processing record44of Set8|victoria
# processing record45of Set8|kachikau
# City Not Found, Pass...:kachikau
# processing record46of Set8|itanhem
# processing record47of Set8|chalette-sur-loing
# processing record48of Set8|seka
# processing record49of Set8|capreol
# processing record50of Set8|ola
# 9
# 0
# 400
# processing record1of Set9|chapais
# processing record2of Set9|cururupu
# processing record3of Set9|hervey bay
# processing record4of Set9|palana
# processing record5of Set9|san ramon de la nueva oran
# processing record6of Set9|osoyoos
# processing record7of Set9|belmonte
# processing record8of Set9|barashevo
# processing record9of Set9|brae
# processing record10of Set9|caala
# processing record11of Set9|hof
# processing record12of Set9|itarema
# processing record13of Set9|kragero
# processing record14of Set9|trapani
# processing record15of Set9|narsaq
# processing record16of Set9|nador
# processing record17of Set9|korla
# processing record18of Set9|mayo
# processing record19of Set9|muhos
# processing record20of Set9|rongcheng
# processing record21of Set9|kuche
# City Not Found, Pass...:kuche
# processing record22of Set9|yuli
# processing record23of Set9|neyshabur
# processing record24of Set9|wajid
# processing record25of Set9|mapiri
# processing record26of Set9|cadillac
# processing record27of Set9|berlevag
# processing record28of Set9|parrita
# processing record29of Set9|balikpapan
# processing record30of Set9|karpinsk
# processing record31of Set9|russell
# processing record32of Set9|whitianga
# processing record33of Set9|tabialan
# City Not Found, Pass...:tabialan
# processing record34of Set9|hualmay
# processing record35of Set9|safwah
# City Not Found, Pass...:safwah
# processing record36of Set9|vaitupu
# City Not Found, Pass...:vaitupu
# processing record37of Set9|asosa
# processing record38of Set9|varhaug
# processing record39of Set9|stornoway
# processing record40of Set9|portland
# processing record41of Set9|hamilton
# processing record42of Set9|tateyama
# processing record43of Set9|malakal
# processing record44of Set9|krutinka
# processing record45of Set9|port-gentil
# processing record46of Set9|springbok
# processing record47of Set9|de-kastri
# processing record48of Set9|puerto suarez
# processing record49of Set9|nyimba
# processing record50of Set9|okhotsk
# 10
# 0
# 450
# processing record1of Set10|sangar
# processing record2of Set10|draguignan
# processing record3of Set10|ushibuka
# processing record4of Set10|darhan
# processing record5of Set10|katsuura
# processing record6of Set10|sidmouth
# processing record7of Set10|solnechnyy
# processing record8of Set10|karkaralinsk
# City Not Found, Pass...:karkaralinsk
# processing record9of Set10|saint-augustin
# processing record10of Set10|fenyi
# processing record11of Set10|hai phong
# City Not Found, Pass...:hai phong
# processing record12of Set10|arkhipovka
# processing record13of Set10|saint-francois
# processing record14of Set10|lake cowichan
# processing record15of Set10|amderma
# City Not Found, Pass...:amderma
# processing record16of Set10|iberia
# processing record17of Set10|lalgudi
# processing record18of Set10|soverato
# processing record19of Set10|black river
# processing record20of Set10|kruisfontein
# processing record21of Set10|sohag
# processing record22of Set10|hauknes
# processing record23of Set10|chernyshevskiy
# processing record24of Set10|whyalla
# processing record25of Set10|roald
# processing record26of Set10|ossora
# processing record27of Set10|rehti
# processing record28of Set10|landerneau
# processing record29of Set10|jimenez
# processing record30of Set10|ruatoria
# City Not Found, Pass...:ruatoria
# processing record31of Set10|wamba
# processing record32of Set10|heihe
# processing record33of Set10|manono
# processing record34of Set10|shache
# processing record35of Set10|wanning
# processing record36of Set10|haines junction
# processing record37of Set10|pevek
# processing record38of Set10|poum
# processing record39of Set10|palmerston
# processing record40of Set10|beringovskiy
# processing record41of Set10|dingle
# processing record42of Set10|zhanakorgan
# processing record43of Set10|bondowoso
# processing record44of Set10|kuah
# processing record45of Set10|alofi
# processing record46of Set10|maumere
# processing record47of Set10|wad rawah
# processing record48of Set10|san fernando
# processing record49of Set10|daru
# processing record50of Set10|alyangula
# 11
# 0
# 500
# processing record1of Set11|naron
# processing record2of Set11|coquimbo
# processing record3of Set11|ayan
# processing record4of Set11|burnie
# processing record5of Set11|qesarya
# processing record6of Set11|tahe
# processing record7of Set11|lata
# processing record8of Set11|sabang
# processing record9of Set11|lewisporte
# processing record10of Set11|puerto leguizamo
# processing record11of Set11|jiddah
# City Not Found, Pass...:jiddah
# processing record12of Set11|faya
# processing record13of Set11|sinnamary
# processing record14of Set11|xai-xai
# processing record15of Set11|fukue
# processing record16of Set11|west bay
# processing record17of Set11|florianopolis
# processing record18of Set11|udachnyy
# processing record19of Set11|abrau-dyurso
# processing record20of Set11|kokkola
# processing record21of Set11|bukachacha
# processing record22of Set11|svetlyy
# processing record23of Set11|debno
# processing record24of Set11|petropavlovsk-kamchatskiy
# processing record25of Set11|wagar
# processing record26of Set11|vao
# processing record27of Set11|koutiala
# processing record28of Set11|kushmurun
# processing record29of Set11|luena
# processing record30of Set11|wote
# processing record31of Set11|bull savanna
# processing record32of Set11|ramnagar
# processing record33of Set11|south shields
# processing record34of Set11|druskininkai
# processing record35of Set11|prachuap khiri khan
# processing record36of Set11|am timan
# processing record37of Set11|los llanos de aridane
# processing record38of Set11|kumbo
# processing record39of Set11|tete
# processing record40of Set11|jalu
# processing record41of Set11|lake grove
# processing record42of Set11|jaisalmer
# processing record43of Set11|waipawa
# processing record44of Set11|nkhotakota
# processing record45of Set11|cuamba
# processing record46of Set11|lakes entrance
# processing record47of Set11|iqaluit
# processing record48of Set11|dickinson
# processing record49of Set11|nikita
# processing record50of Set11|alta floresta
# 12
# 0
# 550
# processing record1of Set12|middle island
# processing record2of Set12|uwayl
# City Not Found, Pass...:uwayl
# processing record3of Set12|changde
# processing record4of Set12|vilhena
# processing record5of Set12|kilindoni
# processing record6of Set12|bathsheba
# processing record7of Set12|jiayuguan
# processing record8of Set12|richards bay
# processing record9of Set12|tautira
# processing record10of Set12|ambagarh chauki
# processing record11of Set12|hami
# processing record12of Set12|pisco
# processing record13of Set12|mondovi
# processing record14of Set12|anadyr
# processing record15of Set12|buariki
# City Not Found, Pass...:buariki
# processing record16of Set12|arkansas city
# processing record17of Set12|emerald
# processing record18of Set12|ipixuna
# processing record19of Set12|boissevain
# processing record20of Set12|mao
# processing record21of Set12|rovaniemi
# processing record22of Set12|monrovia
# processing record23of Set12|qui nhon
# processing record24of Set12|kedrovyy
# processing record25of Set12|minab
# processing record26of Set12|tornio
# processing record27of Set12|crixas
# processing record28of Set12|salinopolis
# processing record29of Set12|zaysan
# processing record30of Set12|shimoda
# processing record31of Set12|hobyo
# processing record32of Set12|bondo
# processing record33of Set12|barzas
# processing record34of Set12|mahibadhoo
# processing record35of Set12|ukmerge
# processing record36of Set12|mashhad
# processing record37of Set12|yeppoon
# processing record38of Set12|qibili
# City Not Found, Pass...:qibili
# processing record39of Set12|taoudenni
# processing record40of Set12|praia da vitoria
# processing record41of Set12|honiara
# processing record42of Set12|santa rosa
# processing record43of Set12|siddipet
# processing record44of Set12|asau
# processing record45of Set12|colquiri
# processing record46of Set12|tessalit
# processing record47of Set12|vega de alatorre
# processing record48of Set12|mahajanga
# processing record49of Set12|araouane
# processing record50of Set12|kongsberg
# 13
# 0
# 600
# processing record1of Set13|magadi
# processing record2of Set13|mananjary
# processing record3of Set13|buqayq
# City Not Found, Pass...:buqayq
# processing record4of Set13|jambalo
# processing record5of Set13|vostok
# processing record6of Set13|mihai viteazu
# processing record7of Set13|san quintin
# processing record8of Set13|antalaha
# processing record9of Set13|challans
# processing record10of Set13|broome
# processing record11of Set13|shingu
# processing record12of Set13|kharan
# processing record13of Set13|sao paulo de olivenca
# processing record14of Set13|cam ranh
# processing record15of Set13|andujar
# processing record16of Set13|chagda
# City Not Found, Pass...:chagda
# processing record17of Set13|lasa
# processing record18of Set13|khudumelapye
# processing record19of Set13|cilegon
# processing record20of Set13|phibun mangsahan
# processing record21of Set13|cumanayagua
# processing record22of Set13|mto wa mbu
# processing record23of Set13|deder
# processing record24of Set13|harlingen
# processing record25of Set13|castelo do piaui
# processing record26of Set13|palembang
# processing record27of Set13|rosenberg
# processing record28of Set13|bonthe
# 13

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Creating a DataFrame
city_data_df = pd.DataFrame({"City":city_list,
                         "Lat":lat_list,
                         "Lng":lng_list,
                         "Max Temp":max_temp_list,
                         "Humidity":humidity_list,
                         "Cloudiness":cloudiness_list,
                         "Wind Speed":windspeed_list,
                            })

pd.DataFrame.to_csv(city_data_df, 'city_data.csv')

city_data_df.head()
# city_data_df.count()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed
# 0    Busselton -33.6500  115.3333    290.83        62          16        2.16
# 1        Kapaa  22.0752 -159.3190    299.33        70          75        2.24
# 2        Vaini -21.2000 -175.2000    300.24        78          75        3.60
# 3      Bakchar  57.0186   82.0711    277.25        43           4        4.94
# 4  New Norfolk -42.7826  147.0587    286.88        54          34        4.81

# %%
weather_dict = {"City":city_list,
                         "Lat":lat_list,
                         "Lng":lng_list,
                         "Max Temp":max_temp_list,
                         "Humidity":humidity_list,
                         "Cloudiness":cloudiness_list,
                         "Wind Speed":windspeed_list,
}
weather_dict
# Out:
# {'City': ['Busselton',
#   'Kapaa',
#   'Vaini',
#   'Bakchar',
#   'New Norfolk',
#   'Ponta do Sol',
#   'Truth or Consequences',
#   'Aljezur',
#   'Beşikdüzü',
#   'Nikolskoye',
#   'Kaitangata',
#   'Pundaguitan',
#   'Columbus',
#   'Punta Arenas',
#   'Puerto Ayora',
#   'Rikitea',
#   'Mataura',
#   'Mount Gambier',
#   'Meulaboh',
#   'Mar del Plata',
#   'Arraial do Cabo',
#   'Oliveira dos Brejinhos',
#   'Albany',
#   'Tuktoyaktuk',
#   'Nava',
#   'Hobart',
#   'Felipe Carrillo Puerto',
#   'Williamsport',
#   'Butaritari',
#   'Praia',
#   'Viedma',
#   'Provideniya',
#   'Glendive',
#   'Ushuaia',
#   'Petatlán',
#   'Bijapur',
#   'Cape Town',
#   'Castro',
#   'Hithadhoo',
#   'Turukhansk',
#   'Verkhnyaya Inta',
#   'Namtsy',
#   'Flinders',
#   'Bethel',
#   'Carnarvon',
#   'Matamoros',
#   'Alexandria',
#   'Lagoa',
#   'Codrington',
#   'Moree',
#   'São Filipe',
#   'Sur',
#   'Tutóia',
#   'Qeshm',
#   'Cidreira',
#   'Dikson',
#   'Saint-Philippe',
#   'Pemangkat',
#   'East London',
#   'Dawlatabad',
#   'Tasiilaq',
#   'Mzimba',
#   'Pervomayskoye',
#   'Wajima',
#   'Ixtapa',
#   'Taloda',
#   'La Ronge',
#   'Porbandar',
#   'Hilo',
#   'Leningradskiy',
#   'George Town',
#   'San Rafael',
#   'Jamestown',
#   'Calbuco',
#   'Saint George',
#   'Mauá',
#   'Safaga',
#   'Torbay',
#   'Port Blair',
#   'Rapid City',
#   'Kamenka',
#   'Airai',
#   'Shāhpur',
#   'Tura',
#   'Ochakiv',
#   'Saskylakh',
#   'Yurgamysh',
#   'Souillac',
#   'Touros',
#   'Aklavik',
#   'Lüderitz',
#   'Yangi Marg`ilon',
#   'Saint Anthony',
#   'Sheffield',
#   'Yellowknife',
#   'Lucea',
#   'Charlestown',
#   'Sechura',
#   'Qaanaaq',
#   'Sarkand',
#   'Djambala',
#   'Hvide Sande',
#   'Hermanus',
#   'Seminole',
#   'Upernavik',
#   'Avarua',
#   'Nova Serrana',
#   'Atuona',
#   "Severo-Kuril'sk",
#   'Zhuhai',
#   'Longyearbyen',
#   'Kidal',
#   'Bambous Virieux',
#   'Dunedin',
#   'Sampit',
#   'Vila Franca do Campo',
#   'Ambérieu-en-Bugey',
#   'Yar-Sale',
#   'Pestravka',
#   'Hobe Sound',
#   'Guerrero Negro',
#   'Omsukchan',
#   'Merauke',
#   'Thākurganj',
#   'Tooele',
#   'Zhezkazgan',
#   'Safi',
#   'Durango',
#   'Ketchikan',
#   'Tvøroyri',
#   'Faanui',
#   'Ubari',
#   'Kabo',
#   'Bengkulu',
#   "Krasnosel'kup",
#   'Étaples',
#   'Show Low',
#   'Chui',
#   'Vardø',
#   'Port Hedland',
#   'Lorengau',
#   'Caracolí',
#   'Bluff',
#   'Pamanukan',
#   'Beyneu',
#   'San Lorenzo',
#   'Bacolod City',
#   'San Nicolas',
#   'Isangel',
#   'Yarkovo',
#   'Labuhan',
#   'Bilsanda',
#   'Pune',
#   'Mweka',
#   'Thunder Bay',
#   'Chimoio',
#   'Bria',
#   'Orapa',
#   'Kiboga',
#   'Laguna',
#   'Esqueda',
#   'São Gabriel da Cachoeira',
#   'Hanstholm',
#   'Mayumba',
#   'Cherskiy',
#   'Tuatapere',
#   'Kenai',
#   'Saint-Louis',
#   'Barrow',
#   'San Patricio',
#   'Saint Paul Harbor',
#   'Salalah',
#   'Constitución',
#   'Margate',
#   'Corowa',
#   'Pacific Grove',
#   'Tashir',
#   'Yaan',
#   'Voineasa',
#   'Puno',
#   'Edd',
#   'Girona',
#   'Srednekolymsk',
#   'Kargasok',
#   'Huangnihe',
#   'Río Gallegos',
#   'Betsiamites',
#   'Fairbanks',
#   'Moose Factory',
#   'Port Alfred',
#   'Port Pirie',
#   'Miranda',
#   'Naze',
#   'Portales',
#   'Léogâne',
#   'Puerto Carreño',
#   'Lebu',
#   'Port Lincoln',
#   'Marathon',
#   'Cavan',
#   'San Cristobal',
#   'Chokurdakh',
#   'Lewistown',
#   'Voi',
#   'Sibolga',
#   'Adrar',
#   'Murgab',
#   'Luanda',
#   'Nuuk',
#   'Najrān',
#   'Rochester',
#   'Toba Tek Singh',
#   'Camaná',
#   'Buala',
#   'Neustrelitz',
#   'Arkhangel’skoye',
#   'Narganá',
#   'Grindavik',
#   'Ghansor',
#   'Conceição da Barra',
#   'Mariehamn',
#   'Port Elizabeth',
#   'Hofn',
#   'Gao',
#   'Nanortalik',
#   'Mamu Kanjan',
#   'Port Augusta',
#   'Bredasdorp',
#   'Borba',
#   'Carupano',
#   'Dubai',
#   'La Libertad',
#   'Piaçabuçu',
#   'Puerto del Rosario',
#   'Caravelas',
#   'Mago',
#   'Roebourne',
#   'Villa Carlos Paz',
#   'Mount Isa',
#   'Laela',
#   'Buchanan',
#   "Oktyabr'skiy",
#   'Tiksi',
#   'Sémbé',
#   'Esperance',
#   'College',
#   'Thompson',
#   'Bilsi',
#   'Traverse City',
#   'Trofors',
#   'Vanavara',
#   'Fuerte',
#   'Shahr-e Bābak',
#   'Kavieng',
#   "Ust'ye",
#   'Gamba',
#   'Davila',
#   'Chicama',
#   'Talnakh',
#   'Oron',
#   'La Rioja',
#   'Norman Wells',
#   'Tiznit Province',
#   'Strathmore',
#   'Hasaki',
#   'Cayenne',
#   'Lavrentiya',
#   'Sobolevo',
#   'Maningrida',
#   'Porto-Novo',
#   'Sørland',
#   'Ugoofaaru',
#   'Mushie',
#   'Yulara',
#   'Ha Giang',
#   'Pinar del Río',
#   'Oparino',
#   'Grand Gaube',
#   'Mangai',
#   "Ust'-Tarka",
#   'Stromness',
#   'Nichinan',
#   'Valparaíso',
#   'Ribeira Grande',
#   'Hernani',
#   'Funadhoo',
#   "Ust'-Omchug",
#   'Suntar',
#   'Kalianget',
#   'Puerto Colombia',
#   'Izhma',
#   'Port Shepstone',
#   "St. George's",
#   'Eureka',
#   'Necochea',
#   'Tōbetsu',
#   'Lompoc',
#   'Colac',
#   'Beloha',
#   'Khatanga',
#   'Zhigansk',
#   'Botro',
#   'Fichē',
#   'Vila Velha',
#   'Bubaque',
#   'Kaohsiung City',
#   'Vernon',
#   'São João da Barra',
#   'Alibag',
#   'Alappuzha',
#   'Naifaru',
#   'Mitsamiouli',
#   'Mahébourg',
#   'Shubarkuduk',
#   'Shizunai-furukawachō',
#   'Cockburn Town',
#   'Ventspils',
#   'Adet',
#   'Mossamedes',
#   'Padang',
#   'Usa River',
#   'Husavik',
#   'Arlit',
#   'Dhidhdhoo',
#   'Robertsport',
#   'Broken Hill',
#   'Kahului',
#   'Bukama',
#   'Fortuna',
#   'Mehamn',
#   'Kieta',
#   'Kloulklubed',
#   'Morondava',
#   'Kaputa',
#   'Avera',
#   'Montague',
#   'Sitka',
#   'Hambantota',
#   'Grand-Santi',
#   'Ilulissat',
#   'Mogadishu',
#   'Sakakah',
#   'Hay River',
#   'Nālūt',
#   'Benguela',
#   'Juneau',
#   'Itoman',
#   'Klaksvík',
#   'Rosetta',
#   'Shetpe',
#   'Barranca',
#   'La Palma',
#   'Ahipara',
#   'Kirakira',
#   'Christchurch',
#   'Kushiro',
#   'Lālmohan',
#   'Alma',
#   'Geraldton',
#   'Hong Kong',
#   'Itanhém',
#   'Châlette-sur-Loing',
#   'Seka',
#   'Capreol',
#   'Ola',
#   'Chapais',
#   'Cururupu',
#   'Hervey Bay',
#   'Palana',
#   'Orán',
#   'Osoyoos',
#   'Belmonte',
#   'Barashevo',
#   'Brae',
#   'Caála',
#   'Hof',
#   'Itarema',
#   'Kragerø',
#   'Province of Trapani',
#   'Narsaq',
#   'Nador',
#   'Korla',
#   'Mayo',
#   'Muhos',
#   'Rongcheng',
#   'Yuli',
#   'Neyshabur',
#   'Wajid',
#   'Mapiri',
#   'Cadillac',
#   'Berlevåg',
#   'Parrita',
#   'Balikpapan',
#   'Karpinsk',
#   'Russell',
#   'Whitianga',
#   'Hualmay',
#   'Āsosa',
#   'Varhaug',
#   'Stornoway',
#   'Portland',
#   'Hamilton',
#   'Tateyama',
#   'Malakal',
#   'Krutinka',
#   'Port-Gentil',
#   'Springbok',
#   'De-Kastri',
#   'Puerto Suárez',
#   'Nyimba',
#   'Okhotsk',
#   'Sangar',
#   'Draguignan',
#   'Ushibukamachi',
#   'Darhan',
#   'Katsuura',
#   'Sidmouth',
#   'Solnechnyy',
#   'Saint-Augustin',
#   'Fenyi',
#   'Arkhipovka',
#   'Saint-François',
#   'Lake Cowichan',
#   'Iberia',
#   'Lalgudi',
#   'Soverato Marina',
#   'Black River',
#   'Kruisfontein',
#   'Sohag',
#   'Hauknes',
#   'Chernyshevskiy',
#   'Whyalla',
#   'Roald',
#   'Ossora',
#   'Rehti',
#   'Landerneau',
#   'Jiménez',
#   'Wamba',
#   'Heihe',
#   'Manono',
#   'Shache',
#   'Wanning',
#   'Haines Junction',
#   'Pevek',
#   'Poum',
#   'Palmerston',
#   'Beringovskiy',
#   'Dingle',
#   'Zhanakorgan',
#   'Bondowoso',
#   'Kuah',
#   'Alofi',
#   'Maumere',
#   'Wad Rāwah',
#   'San Fernando',
#   'Daru',
#   'Alyangula',
#   'Narón',
#   'Coquimbo',
#   'Ayan',
#   'Burnie',
#   'Caesarea',
#   'Tahe',
#   'Lata',
#   'Sabang',
#   'Lewisporte',
#   'Caucayá',
#   'Faya',
#   'Sinnamary',
#   'Xai-Xai',
#   'Fukuechō',
#   'West Bay',
#   'Florianópolis',
#   'Udachny',
#   'Abrau-Dyurso',
#   'Kokkola',
#   'Bukachacha',
#   'Tsimmerbude',
#   'Dębno',
#   'Petropavlovsk-Kamchatskiy',
#   'Wagar',
#   'Vao',
#   'Koutiala',
#   'Kushmurun',
#   'Luena',
#   'Wote',
#   'Bull Savanna',
#   'Ramnagar',
#   'South Shields',
#   'Druskininkai',
#   'Prachuap Khiri Khan',
#   'Am Timan',
#   'Los Llanos de Aridane',
#   'Kumbo',
#   'Tete',
#   'Jalu',
#   'Lake Grove',
#   'Jaisalmer',
#   'Waipawa',
#   'Nkhotakota',
#   'Cuamba',
#   'Lakes Entrance',
#   'Iqaluit',
#   'Dickinson',
#   'Nikita',
#   'Alta Floresta',
#   'Middle Island',
#   'Changde',
#   'Vilhena',
#   'Kilindoni',
#   'Bathsheba',
#   'Jiayuguan City',
#   'Richards Bay',
#   'Tautira',
#   'Ambāgarh Chauki',
#   'Kumul',
#   'Pisco',
#   'Mondovì',
#   'Anadyr',
#   'Arkansas City',
#   'Emerald',
#   'Ipixuna',
#   'Boissevain',
#   'Mahon',
#   'Rovaniemi',
#   'Monrovia',
#   'Qui Nhon',
#   'Kedrovyy',
#   'Mīnāb',
#   'Tornio',
#   'Crixás',
#   'Salinópolis',
#   'Zaysan',
#   'Shimoda',
#   'Hobyo',
#   'Bondo',
#   'Barzas',
#   'Mahibadhoo',
#   'Ukmerge',
#   'Mashhad',
#   'Yeppoon',
#   'Taoudenni',
#   'Praia da Vitória',
#   'Honiara',
#   'Santa Rosa',
#   'Siddipet',
#   'Asău',
#   'Colquiri',
#   'Tessalit',
#   'Vega de Alatorre',
#   'Mahajanga',
#   'Araouane',
#   'Kongsberg',
#   'Māgadi',
#   'Mananjary',
#   'Jambaló',
#   'Vostok',
#   'Mihai Viteazu',
#   'San Quintín',
#   'Antalaha',
#   'Challans',
#   'Broome',
#   'Shingū',
#   'Kharan',
#   'São Paulo de Olivença',
#   'Cam Ranh',
#   'Andújar',
#   'Laas',
#   'Khudumelapye',
#   'Cilegon',
#   'Phibun Mangsahan',
#   'Cumanayagua',
#   'Mto wa Mbu',
#   'Deder',
#   'Harlingen',
#   'Castelo do Piauí',
#   'Palembang',
#   'Ružomberok',
#   'Bonthe'],
#  'Lat': [-33.65,
#   22.0752,
#   -21.2,
#   57.0186,
#   -42.7826,
#   32.6667,
#   33.1284,
#   37.3191,
#   41.052,
#   59.7035,
#   -46.2817,
#   6.3711,
#   39.9612,
#   -53.15,
#   -0.7393,
#   -23.1203,
#   -46.1927,
#   -37.8333,
#   4.1363,
#   -38.0023,
#   -22.9661,
#   -12.3169,
#   42.6001,
#   69.4541,
#   28.4167,
#   -42.8794,
#   19.5833,
#   41.2412,
#   3.0707,
#   14.9215,
#   -40.8135,
#   64.3833,
#   47.1053,
#   -54.8,
#   17.5167,
#   16.8333,
#   -33.9258,
#   -24.7911,
#   -0.6,
#   65.8167,
#   65.9811,
#   62.7161,
#   -34.5833,
#   41.3712,
#   -24.8667,
#   25.5333,
#   31.2156,
#   39.05,
#   -38.2667,
#   -29.4667,
#   14.8961,
#   22.5667,
#   -2.7619,
#   26.9581,
#   -30.1811,
#   73.5069,
#   -21.3585,
#   1.1667,
#   -33.0153,
#   36.4141,
#   65.6145,
#   -11.9,
#   43.919,
#   37.4,
#   20.7,
#   21.5667,
#   55.1001,
#   21.6422,
#   19.7297,
#   69.3833,
#   5.4112,
#   -34.6177,
#   42.097,
#   -41.768,
#   37.1041,
#   -23.6678,
#   26.7292,
#   47.6666,
#   11.6667,
#   44.0805,
#   51.3223,
#   -8.9266,
#   16.7,
#   25.5198,
#   46.6128,
#   71.9167,
#   55.3714,
#   -20.5167,
#   -5.1989,
#   68.2191,
#   -26.6481,
#   40.4272,
#   45.0205,
#   53.383,
#   62.456,
#   18.451,
#   -32.95,
#   -5.5569,
#   77.484,
#   45.41,
#   -2.5447,
#   56.0045,
#   -34.4187,
#   28.7086,
#   72.7868,
#   -21.2078,
#   -19.8761,
#   -9.8,
#   50.6789,
#   22.2769,
#   78.2186,
#   18.4411,
#   -20.3428,
#   -45.8742,
#   -2.5333,
#   37.7167,
#   45.9589,
#   66.8333,
#   52.405,
#   27.0595,
#   27.9769,
#   62.5333,
#   -8.4667,
#   26.45,
#   40.5308,
#   47.8043,
#   32.2994,
#   24.8333,
#   55.3422,
#   61.5556,
#   -16.4833,
#   26.5921,
#   7.6994,
#   -3.8004,
#   65.7,
#   50.5219,
#   34.2542,
#   -33.6971,
#   70.3705,
#   -20.3167,
#   -2.0226,
#   6.4119,
#   -46.6,
#   -6.2842,
#   45.3167,
#   -25.3333,
#   10.6667,
#   18.1725,
#   -19.55,
#   57.4028,
#   -6.8844,
#   28.25,
#   18.5196,
#   -4.85,
#   48.4001,
#   -19.1164,
#   6.5423,
#   -21.2833,
#   0.9161,
#   38.421,
#   30.7167,
#   -0.1303,
#   57.1167,
#   -3.432,
#   68.75,
#   -46.1333,
#   60.5544,
#   16.3333,
#   71.2906,
#   28.017,
#   57.79,
#   17.0151,
#   -35.3333,
#   51.3813,
#   -36.0333,
#   36.6177,
#   41.1207,
#   7.3833,
#   44.2833,
#   -15.8333,
#   13.9297,
#   41.9831,
#   67.45,
#   59.0556,
#   43.5583,
#   -51.6226,
#   48.9413,
#   64.8378,
#   51.2585,
#   -33.5906,
#   -33.1833,
#   3.2499,
#   28.3667,
#   34.1862,
#   18.5108,
#   6.189,
#   -37.6167,
#   -34.7333,
#   44.9,
#   53.9908,
#   7.7669,
#   70.6333,
#   40.5992,
#   -3.3945,
#   1.7427,
#   20.5022,
#   37.4966,
#   -8.8368,
#   64.1835,
#   17.4924,
#   43.1548,
#   30.9743,
#   -16.6228,
#   -8.145,
#   53.3667,
#   55.8549,
#   9.4428,
#   63.8424,
#   22.65,
#   -18.5933,
#   60.0973,
#   -33.918,
#   64.2539,
#   16.6362,
#   60.1432,
#   30.8333,
#   -32.5,
#   -34.5322,
#   -4.3878,
#   10.6678,
#   25.2582,
#   -2.2333,
#   -10.4056,
#   28.5004,
#   -17.7125,
#   53.2514,
#   -20.7833,
#   -31.4241,
#   -20.7333,
#   -8.5667,
#   5.8808,
#   54.4815,
#   71.6872,
#   1.6481,
#   -33.8667,
#   64.8569,
#   55.7435,
#   28.1333,
#   44.7631,
#   65.5333,
#   60.34,
#   17.5381,
#   30.1165,
#   -2.5744,
#   59.6304,
#   -2.65,
#   18.4726,
#   -7.8447,
#   69.4865,
#   4.8256,
#   42.25,
#   65.282,
#   29.5833,
#   51.0501,
#   35.7333,
#   4.9333,
#   65.5833,
#   54.4299,
#   -12.0667,
#   6.4965,
#   67.667,
#   5.6667,
#   -3.0167,
#   -25.2406,
#   22.8333,
#   22.4175,
#   59.8518,
#   -20.0064,
#   -4.05,
#   55.5672,
#   58.965,
#   31.6,
#   -33.0393,
#   38.5167,
#   43.2662,
#   6.15,
#   61.15,
#   62.1444,
#   -7.05,
#   10.9878,
#   65.0083,
#   -30.7414,
#   12.0564,
#   40.8021,
#   -38.5473,
#   43.2169,
#   34.6391,
#   -38.3333,
#   -25.1667,
#   71.9667,
#   66.7697,
#   7.8525,
#   9.8,
#   -20.3297,
#   11.2833,
#   22.6163,
#   50.2581,
#   -21.6403,
#   18.6411,
#   9.49,
#   5.4444,
#   -11.3847,
#   -20.4081,
#   49.1447,
#   42.3339,
#   21.4612,
#   57.3894,
#   11.2644,
#   -15.1961,
#   -0.9492,
#   -3.3667,
#   66.0449,
#   18.7369,
#   6.8833,
#   6.7533,
#   -31.95,
#   20.8947,
#   -9.2,
#   40.5982,
#   71.0357,
#   -6.2167,
#   7.0419,
#   -20.2833,
#   -8.4689,
#   33.194,
#   42.5356,
#   57.0531,
#   6.1241,
#   4.25,
#   69.2167,
#   2.0371,
#   29.9697,
#   60.8156,
#   30.3333,
#   -12.5763,
#   58.3019,
#   26.1247,
#   62.2266,
#   31.4044,
#   44.1667,
#   -10.75,
#   33.8464,
#   -35.1667,
#   -10.4544,
#   -43.5333,
#   42.975,
#   22.3384,
#   48.5501,
#   -28.7667,
#   22.2855,
#   -17.1664,
#   48.0134,
#   17.9285,
#   46.706,
#   59.5833,
#   49.7834,
#   -1.8283,
#   -25.2986,
#   59.1167,
#   -23.1322,
#   49.0331,
#   -15.8631,
#   54.5325,
#   60.3964,
#   -12.8525,
#   50.3167,
#   -2.9248,
#   58.8693,
#   37.8333,
#   60.9167,
#   35.174,
#   41.7597,
#   38.8876,
#   64.808,
#   30.634,
#   9.6989,
#   36.2133,
#   3.8093,
#   -15.25,
#   44.2519,
#   70.8578,
#   9.5201,
#   -1.2675,
#   59.7654,
#   32.3502,
#   -36.8333,
#   -11.0964,
#   10.0667,
#   58.6147,
#   58.2093,
#   45.5234,
#   39.1834,
#   34.9833,
#   9.5334,
#   56.0055,
#   -0.7193,
#   -29.6643,
#   51.4667,
#   -18.95,
#   -14.5566,
#   59.3833,
#   63.9242,
#   43.5333,
#   32.1906,
#   49.4867,
#   35.1333,
#   50.6909,
#   50.7214,
#   51.226,
#   27.8112,
#   56.6629,
#   46.4154,
#   48.825,
#   29.9502,
#   10.8667,
#   38.685,
#   18.0264,
#   -34.0033,
#   26.557,
#   66.2833,
#   63.0128,
#   -33.0333,
#   62.5833,
#   59.2353,
#   22.7333,
#   48.4525,
#   28.3333,
#   8.9333,
#   50.2441,
#   -7.3,
#   38.4167,
#   18.8003,
#   60.7522,
#   69.7008,
#   -20.2333,
#   -12.486,
#   63.05,
#   10.9995,
#   43.9098,
#   -7.9135,
#   6.3265,
#   -19.0595,
#   -8.6199,
#   15.1603,
#   15.0286,
#   -9.0763,
#   -13.8483,
#   43.5167,
#   -29.9533,
#   56.45,
#   -41.0667,
#   32.5189,
#   52.3333,
#   40.1629,
#   5.8933,
#   49.2499,
#   -0.1934,
#   18.3851,
#   5.3833,
#   -25.0519,
#   32.6881,
#   19.3667,
#   -27.6146,
#   66.4167,
#   44.69,
#   63.8385,
#   52.9833,
#   54.675,
#   52.739,
#   53.0452,
#   16.1525,
#   -22.6667,
#   12.3917,
#   52.4503,
#   -11.7833,
#   -1.7808,
#   17.8868,
#   29.4,
#   54.9986,
#   54.0167,
#   12.2167,
#   11.0297,
#   28.6585,
#   6.2,
#   -16.1564,
#   29.0331,
#   40.8529,
#   26.9147,
#   -41.4122,
#   -12.9274,
#   -14.8031,
#   -37.8811,
#   63.7506,
#   29.4608,
#   44.5333,
#   -9.8756,
#   40.8843,
#   29.0464,
#   -12.7406,
#   -7.9139,
#   13.2167,
#   39.8167,
#   -28.783,
#   -17.7333,
#   20.7833,
#   42.8,
#   -13.7,
#   44.396,
#   64.75,
#   37.062,
#   -23.5333,
#   -1.7625,
#   49.2306,
#   39.8885,
#   66.5,
#   6.3005,
#   13.7667,
#   56.1667,
#   27.1467,
#   65.8481,
#   -14.5489,
#   -0.6136,
#   47.4667,
#   34.6667,
#   5.3505,
#   3.8146,
#   55.7167,
#   3.7833,
#   55.25,
#   36.297,
#   -23.1333,
#   22.6783,
#   38.7333,
#   -9.4333,
#   14.3122,
#   18.1,
#   46.4333,
#   -17.4167,
#   20.1986,
#   20.0333,
#   -15.7167,
#   18.9048,
#   59.6652,
#   12.9667,
#   -21.2167,
#   2.7923,
#   46.4856,
#   46.5333,
#   30.4833,
#   -14.9003,
#   46.8436,
#   42.2506,
#   33.7333,
#   28.5833,
#   -3.3783,
#   11.9214,
#   38.0392,
#   46.6166,
#   -23.8833,
#   -6.0174,
#   15.2447,
#   22.1494,
#   -3.35,
#   9.3167,
#   26.1906,
#   -5.3222,
#   -2.9167,
#   49.0748,
#   7.5264],
#  'Lng': [115.3333,
#   -159.319,
#   -175.2,
#   82.0711,
#   147.0587,
#   -17.1,
#   -107.2528,
#   -8.8033,
#   39.2284,
#   30.7861,
#   169.8464,
#   126.1689,
#   -82.9988,
#   -70.9167,
#   -90.3518,
#   -134.9692,
#   168.8643,
#   140.7667,
#   96.1285,
#   -57.5575,
#   -42.0278,
#   -42.8961,
#   -73.9662,
#   -133.0374,
#   -100.7667,
#   147.3294,
#   -88.05,
#   -77.0011,
#   172.7902,
#   -23.5087,
#   -62.9967,
#   -173.3,
#   -104.7125,
#   -68.3,
#   -101.2667,
#   75.7,
#   18.4232,
#   -50.0119,
#   73.0833,
#   87.9833,
#   60.3094,
#   129.6658,
#   150.8552,
#   -73.414,
#   113.6333,
#   -103.25,
#   29.9553,
#   -27.9833,
#   141.9667,
#   149.85,
#   -24.4956,
#   59.5289,
#   -42.2744,
#   56.2719,
#   -50.2056,
#   80.5464,
#   55.7679,
#   108.9667,
#   27.9116,
#   64.9053,
#   -37.6368,
#   33.6,
#   46.7102,
#   136.9,
#   -105.2,
#   74.2167,
#   -105.2842,
#   69.6093,
#   -155.09,
#   178.4167,
#   100.3354,
#   -68.3301,
#   -79.2353,
#   -73.1273,
#   -113.5841,
#   -46.4614,
#   33.9365,
#   -52.7314,
#   92.75,
#   -103.231,
#   42.7678,
#   125.4092,
#   76.8333,
#   90.2201,
#   31.5498,
#   114.0833,
#   64.4656,
#   57.5167,
#   -35.4608,
#   -135.0107,
#   15.1594,
#   71.7189,
#   -93.218,
#   -1.4659,
#   -114.3525,
#   -78.1736,
#   151.6667,
#   -80.8222,
#   -69.3632,
#   79.9186,
#   14.7533,
#   8.1294,
#   19.2345,
#   -81.2081,
#   -56.1549,
#   -159.775,
#   -44.9836,
#   -139.0333,
#   156.125,
#   113.5678,
#   15.6401,
#   1.4078,
#   57.7575,
#   170.5036,
#   112.95,
#   -25.4333,
#   5.3432,
#   70.8333,
#   49.9583,
#   -80.1364,
#   -114.0611,
#   155.8,
#   140.3333,
#   88.1333,
#   -112.2983,
#   67.7144,
#   -9.2372,
#   -104.8333,
#   -131.6461,
#   -6.8111,
#   -151.75,
#   12.7805,
#   18.629,
#   102.2655,
#   82.4667,
#   1.6332,
#   -110.0298,
#   -53.4616,
#   31.1107,
#   118.5667,
#   147.2712,
#   -74.7606,
#   168.3333,
#   107.8106,
#   55.2,
#   -57.5333,
#   122.95,
#   120.5953,
#   169.2667,
#   67.0786,
#   112.2051,
#   79.95,
#   73.8553,
#   21.5667,
#   -89.3168,
#   33.4833,
#   21.9863,
#   25.3667,
#   31.7742,
#   -121.4238,
#   -109.5833,
#   -67.0892,
#   8.6167,
#   10.6554,
#   161.3,
#   167.6833,
#   -151.2583,
#   -15,
#   -156.7887,
#   -97.5169,
#   -152.4072,
#   54.0924,
#   -72.4167,
#   1.3862,
#   146.3833,
#   -121.9166,
#   44.2846,
#   8.5667,
#   24.1333,
#   -70.0333,
#   41.6925,
#   2.8249,
#   153.6833,
#   80.8572,
#   128.0239,
#   -69.2181,
#   -68.646,
#   -147.7164,
#   -80.6094,
#   26.891,
#   138.0167,
#   -76.2281,
#   129.4833,
#   -103.3344,
#   -72.6339,
#   -67.4859,
#   -73.65,
#   135.8667,
#   -89.7668,
#   -7.3606,
#   -72.225,
#   147.9167,
#   -77.5714,
#   38.563,
#   98.7792,
#   -10.0711,
#   61.9714,
#   13.2343,
#   -51.7216,
#   44.1277,
#   -77.6156,
#   72.4827,
#   -72.7111,
#   159.5921,
#   13.0833,
#   35.3287,
#   -78.5906,
#   -22.4338,
#   79.95,
#   -39.7322,
#   19.9348,
#   25.5701,
#   -15.2082,
#   1.637,
#   -45.2371,
#   72.8,
#   137.7667,
#   20.0403,
#   -59.5939,
#   -63.2585,
#   55.3047,
#   -80.9,
#   -36.4344,
#   -13.8627,
#   -39.2481,
#   140.1822,
#   117.1333,
#   -64.4978,
#   139.5,
#   32.05,
#   -10.0467,
#   53.471,
#   128.8694,
#   14.5806,
#   121.9,
#   -147.8028,
#   -97.8558,
#   78.9167,
#   -85.6206,
#   13.4063,
#   102.2797,
#   120.3644,
#   55.1186,
#   150.7967,
#   39.736,
#   10,
#   120.5763,
#   -79.1469,
#   88.3972,
#   8.2343,
#   -2.5,
#   -126.8329,
#   -9.5,
#   -113.3852,
#   140.8333,
#   -52.3333,
#   -171,
#   31.8996,
#   134.2667,
#   2.6036,
#   12.6934,
#   73,
#   16.9,
#   130.9889,
#   104.9833,
#   -83.6981,
#   48.2783,
#   57.6608,
#   19.5333,
#   75.705,
#   -3.296,
#   131.3667,
#   -71.6273,
#   -28.7,
#   -1.9762,
#   73.2667,
#   149.6333,
#   117.6319,
#   113.9333,
#   -74.9547,
#   53.9113,
#   30.455,
#   -61.7485,
#   -124.1637,
#   -58.7368,
#   141.5169,
#   -120.4579,
#   143.5833,
#   45.05,
#   102.5,
#   123.3711,
#   -5.3106,
#   38.7333,
#   -40.2925,
#   -15.8333,
#   120.3133,
#   -119.2691,
#   -41.0511,
#   72.8792,
#   76.3264,
#   73.3657,
#   43.2844,
#   57.7,
#   56.4872,
#   142.3669,
#   -71.1419,
#   21.5606,
#   37.4888,
#   12.1522,
#   100.3543,
#   36.85,
#   -17.3389,
#   7.3853,
#   73.1,
#   -11.3686,
#   141.4333,
#   -156.47,
#   25.85,
#   -124.1573,
#   27.8492,
#   155.6333,
#   134.2556,
#   44.2833,
#   29.6619,
#   -82.5271,
#   -72.5351,
#   -135.33,
#   81.1185,
#   -54.3833,
#   -51.1,
#   45.3438,
#   40.2064,
#   -115.7999,
#   10.85,
#   13.4055,
#   -134.4197,
#   127.6694,
#   -6.589,
#   30.4164,
#   52.1167,
#   -77.7667,
#   -118.0467,
#   173.1667,
#   161.9205,
#   172.6333,
#   144.3747,
#   90.7419,
#   -71.6491,
#   114.6,
#   114.1577,
#   -40.33,
#   2.7359,
#   103.9552,
#   -80.9225,
#   151.2833,
#   -74.8492,
#   -44.8683,
#   152.8535,
#   159.9667,
#   -64.326,
#   -119.4524,
#   -38.8828,
#   42.8792,
#   -1.353,
#   15.5606,
#   11.9167,
#   -39.9167,
#   9.4149,
#   12.6667,
#   -46.05,
#   -2.9287,
#   86.1469,
#   -76.5119,
#   25.9931,
#   117.8517,
#   10.2744,
#   58.7958,
#   43.2471,
#   -68.1667,
#   -85.4012,
#   29.0864,
#   -84.3225,
#   116.8289,
#   60.0085,
#   -85.1999,
#   175.7,
#   -77.6139,
#   34.5333,
#   5.6457,
#   -6.3865,
#   -122.6762,
#   -84.5333,
#   139.8667,
#   31.6605,
#   71.5113,
#   8.7815,
#   17.8865,
#   140.7833,
#   -57.8,
#   30.8149,
#   143.3,
#   127.4739,
#   6.4667,
#   130.0228,
#   105.9228,
#   140.3,
#   -3.2397,
#   136.6319,
#   -58.6502,
#   114.6681,
#   41.2543,
#   3.9054,
#   -124.0546,
#   -91.7507,
#   78.8333,
#   16.5499,
#   -77.8487,
#   24.7314,
#   31.6948,
#   14.0667,
#   112.4714,
#   137.5833,
#   6.1333,
#   163.0719,
#   77.4333,
#   -4.2525,
#   -105.4,
#   8.6,
#   127.4902,
#   27.4167,
#   77.2406,
#   110.3967,
#   -137.5108,
#   170.3133,
#   164.0167,
#   130.9833,
#   179.3167,
#   122.6711,
#   67.2495,
#   113.8214,
#   99.8432,
#   -169.9187,
#   122.2111,
#   33.1397,
#   120.6898,
#   143.2092,
#   136.4192,
#   -8.1528,
#   -71.3436,
#   138.1667,
#   145.9167,
#   34.9046,
#   124.7333,
#   -8.3327,
#   95.3214,
#   -55.0482,
#   -74.7819,
#   42.4509,
#   -52.95,
#   33.6442,
#   128.8419,
#   -81.4167,
#   -48.5012,
#   112.4,
#   37.59,
#   23.1307,
#   116.9167,
#   20.1347,
#   14.698,
#   158.6483,
#   36.2032,
#   167.4833,
#   -5.4642,
#   64.6311,
#   19.9167,
#   37.6288,
#   -77.5902,
#   79.1167,
#   -1.4323,
#   23.9667,
#   99.75,
#   20.2827,
#   -17.9182,
#   10.6667,
#   33.5867,
#   21.5482,
#   -73.1151,
#   70.9181,
#   175.5153,
#   34.2961,
#   36.5372,
#   147.981,
#   -68.5145,
#   -95.0513,
#   34.2333,
#   -56.0861,
#   -72.9373,
#   111.6783,
#   -60.1458,
#   39.6668,
#   -59.5167,
#   98.3,
#   32.0377,
#   -149.15,
#   80.7167,
#   93.45,
#   -76.2167,
#   7.8176,
#   177.4833,
#   -97.0384,
#   148.1667,
#   -48.8043,
#   -100.0559,
#   4.2658,
#   25.7167,
#   -10.7969,
#   109.2333,
#   91.8167,
#   57.0801,
#   24.1466,
#   -49.9692,
#   -47.3561,
#   84.8667,
#   138.95,
#   48.5268,
#   23.6866,
#   86.3167,
#   72.9667,
#   24.75,
#   59.6062,
#   150.7333,
#   -3.9836,
#   -27.0667,
#   159.95,
#   121.1114,
#   78.85,
#   26.4,
#   -67.1333,
#   1.0114,
#   -96.6333,
#   46.3167,
#   -3.5265,
#   9.6465,
#   77.2333,
#   48.3333,
#   -76.3226,
#   135.8833,
#   23.75,
#   -115.95,
#   50.2788,
#   -1.8749,
#   -75.833,
#   135.9833,
#   65.4167,
#   -68.8725,
#   109.1591,
#   -4.0508,
#   10.7002,
#   24.75,
#   106.0538,
#   105.2291,
#   -80.2022,
#   35.85,
#   41.45,
#   -97.6961,
#   -41.5525,
#   104.7458,
#   19.3075,
#   -12.505],
#  'Max Temp': [290.83,
#   299.33,
#   300.24,
#   277.25,
#   286.88,
#   296.5,
#   299.77,
#   288.82,
#   288.09,
#   287.26,
#   289.78,
#   300.96,
#   296.17,
#   280.21,
#   296.79,
#   296.02,
#   288.97,
#   288.1,
#   300.08,
#   284.33,
#   294.77,
#   295.87,
#   293.96,
#   273.55,
#   293.08,
#   287.07,
#   298.9,
#   294.24,
#   301.05,
#   295.45,
#   285.2,
#   274.21,
#   292.86,
#   277.96,
#   298.92,
#   297.44,
#   289.2,
#   283.94,
#   302.12,
#   273.21,
#   289.97,
#   282.21,
#   292.69,
#   293.23,
#   296.19,
#   301.21,
#   295.1,
#   288.26,
#   288.07,
#   292.47,
#   296.85,
#   305.83,
#   298.84,
#   302.18,
#   286.77,
#   266.19,
#   294.92,
#   298.6,
#   297.56,
#   299.44,
#   267.24,
#   285.83,
#   290.5,
#   291.38,
#   297.72,
#   300.79,
#   273.37,
#   302.05,
#   299,
#   274.62,
#   301.42,
#   287.25,
#   293.95,
#   284.71,
#   305.41,
#   288.91,
#   300.55,
#   278.31,
#   302.54,
#   296.42,
#   283.63,
#   296.31,
#   300.14,
#   298.95,
#   284.23,
#   271.06,
#   287.66,
#   295.02,
#   297.65,
#   285.54,
#   287.97,
#   291.55,
#   294.25,
#   281.23,
#   274.44,
#   299.18,
#   295.89,
#   294.05,
#   271.27,
#   285.5,
#   294.08,
#   281.59,
#   289.15,
#   297.62,
#   269.93,
#   301.18,
#   289.19,
#   299.9,
#   279.58,
#   305.77,
#   268.06,
#   306.12,
#   294.94,
#   288.6,
#   298.18,
#   291.38,
#   282.14,
#   274.1,
#   290.42,
#   299.14,
#   290.03,
#   272.67,
#   302.07,
#   302.82,
#   299.51,
#   286.89,
#   292.28,
#   293.12,
#   285.37,
#   275.81,
#   300.78,
#   300.9,
#   297.06,
#   299.54,
#   269.68,
#   282.82,
#   295.99,
#   282.77,
#   277.76,
#   302.18,
#   303.06,
#   295.04,
#   289.15,
#   301.39,
#   296.9,
#   295.67,
#   302.77,
#   305.06,
#   298.36,
#   286.21,
#   301.69,
#   296.08,
#   296.96,
#   293.83,
#   293.14,
#   285.59,
#   294.05,
#   285.69,
#   289.38,
#   297.29,
#   299.13,
#   295.98,
#   281.9,
#   298.66,
#   280.94,
#   289.16,
#   283.16,
#   301.93,
#   272.16,
#   295.2,
#   278.88,
#   302.2,
#   286.68,
#   283.83,
#   287.2,
#   290.37,
#   278.23,
#   298.91,
#   285.48,
#   278.25,
#   304.22,
#   288.95,
#   279.9,
#   276.8,
#   299.53,
#   281.57,
#   282.87,
#   292.65,
#   293.14,
#   295.96,
#   295.2,
#   294.22,
#   298.33,
#   293.68,
#   297.26,
#   297.59,
#   284.88,
#   292.75,
#   292.89,
#   283.39,
#   297.25,
#   273.09,
#   294.7,
#   294.31,
#   301.48,
#   304.22,
#   299.19,
#   298.15,
#   275.49,
#   297.44,
#   293.34,
#   301.07,
#   291.45,
#   301.88,
#   279.77,
#   286.79,
#   299.95,
#   276.41,
#   298.64,
#   294.38,
#   276.07,
#   292.45,
#   274.68,
#   304.84,
#   275.53,
#   300.43,
#   295.77,
#   288.86,
#   296.67,
#   297.69,
#   303.83,
#   295.43,
#   297.29,
#   294.01,
#   294.84,
#   279.28,
#   300.38,
#   288.37,
#   300.02,
#   285.94,
#   298.62,
#   288.2,
#   272.56,
#   294.68,
#   291.97,
#   291.81,
#   273.59,
#   296.5,
#   294.26,
#   278.79,
#   279.07,
#   304.89,
#   294.64,
#   302.97,
#   288.41,
#   298.48,
#   303.95,
#   290.45,
#   264.35,
#   298.18,
#   278.97,
#   286.12,
#   299.21,
#   279.69,
#   295.31,
#   297.64,
#   274.04,
#   285.62,
#   303.92,
#   300.06,
#   278.85,
#   302.17,
#   296.2,
#   294.09,
#   300.98,
#   297.7,
#   288.03,
#   295.03,
#   295.35,
#   280.41,
#   279.29,
#   297.46,
#   286.66,
#   289.09,
#   283.1,
#   302.18,
#   275.35,
#   280.97,
#   301.85,
#   300.2,
#   291.6,
#   294.82,
#   299.97,
#   286,
#   282.61,
#   297.31,
#   290.29,
#   288.79,
#   290.94,
#   269.96,
#   278.01,
#   296.23,
#   286.91,
#   294.23,
#   299.26,
#   306.2,
#   289.89,
#   293.24,
#   301.19,
#   299.37,
#   302.17,
#   299.43,
#   294.96,
#   290.75,
#   285.37,
#   299.41,
#   283.11,
#   288.13,
#   297.1,
#   303.18,
#   290.47,
#   273.27,
#   305.3,
#   302.2,
#   299.72,
#   291.28,
#   301.16,
#   292.52,
#   286.75,
#   278.23,
#   302.73,
#   301.62,
#   296.79,
#   293.67,
#   296.88,
#   293.72,
#   284.09,
#   301.17,
#   296.16,
#   275.16,
#   298.93,
#   302.02,
#   273.1,
#   301.03,
#   297.11,
#   288.15,
#   303.58,
#   275.66,
#   294.62,
#   292.73,
#   290.45,
#   296.91,
#   291.26,
#   300.01,
#   289.26,
#   284.54,
#   304.22,
#   287.82,
#   295.38,
#   305.91,
#   291.93,
#   279.44,
#   307.71,
#   290.32,
#   274.5,
#   289.99,
#   297.03,
#   297.21,
#   272.81,
#   291.72,
#   287.92,
#   293.43,
#   287.36,
#   277.1,
#   286.25,
#   280.07,
#   298.11,
#   281.8,
#   290.56,
#   278.27,
#   292.29,
#   295.99,
#   296.76,
#   282.03,
#   292.32,
#   301.92,
#   294.43,
#   296.02,
#   293.41,
#   292.73,
#   278.14,
#   301.77,
#   300.52,
#   289.44,
#   296.92,
#   292.6,
#   290.52,
#   289.87,
#   281.98,
#   281.13,
#   287.14,
#   296.01,
#   294.9,
#   298.56,
#   281.6,
#   298.84,
#   281.81,
#   281.49,
#   295.92,
#   287.21,
#   276.02,
#   281.38,
#   286.97,
#   295.56,
#   292.42,
#   294.39,
#   283.46,
#   283.47,
#   282.75,
#   293.7,
#   287.89,
#   281.03,
#   287.49,
#   297.58,
#   300.33,
#   290.12,
#   299.25,
#   290.04,
#   298.94,
#   279.15,
#   278.42,
#   295.09,
#   280.88,
#   276.61,
#   297.56,
#   284.64,
#   302.56,
#   298.31,
#   288.47,
#   296.9,
#   295.95,
#   304.32,
#   285.07,
#   274.09,
#   297.27,
#   304.76,
#   275.64,
#   302.49,
#   297.49,
#   301.71,
#   302.41,
#   301.09,
#   301.96,
#   305.2,
#   307.93,
#   300.52,
#   301.82,
#   285.38,
#   288,
#   278.33,
#   287.56,
#   293.34,
#   284.49,
#   285.4,
#   302.08,
#   283.22,
#   295.5,
#   292.44,
#   298.86,
#   289.41,
#   295.17,
#   301.48,
#   289.05,
#   273.78,
#   285.85,
#   281.24,
#   286.24,
#   282.57,
#   281.94,
#   292.48,
#   303.65,
#   296.15,
#   304.51,
#   288.82,
#   286.9,
#   289.72,
#   297.57,
#   293.44,
#   281.59,
#   280.74,
#   301.31,
#   302.88,
#   291.01,
#   289.21,
#   293.2,
#   298.8,
#   292.61,
#   301.49,
#   289.5,
#   291.46,
#   286.88,
#   292.14,
#   264.42,
#   294.3,
#   282.44,
#   295.44,
#   291.12,
#   290.59,
#   293.46,
#   299.13,
#   300.49,
#   293.24,
#   292.87,
#   302.16,
#   303.97,
#   298.33,
#   292.18,
#   284.39,
#   276.43,
#   292.94,
#   297.23,
#   298.12,
#   292.95,
#   289.46,
#   281.82,
#   299.29,
#   304.24,
#   278.38,
#   304.3,
#   281.16,
#   293.86,
#   299.64,
#   283.97,
#   297.68,
#   299.4,
#   293.28,
#   279.28,
#   302.21,
#   283.19,
#   292.23,
#   298.03,
#   308.99,
#   290.79,
#   303.7,
#   307.9,
#   301.94,
#   284.79,
#   274.87,
#   306.32,
#   299.36,
#   294.16,
#   306.5,
#   280.76,
#   297.24,
#   293.79,
#   285.34,
#   297.59,
#   285.23,
#   290.13,
#   296.59,
#   282.19,
#   292.8,
#   294.7,
#   301.2,
#   295.75,
#   305.13,
#   292.03,
#   279.56,
#   285.31,
#   302.09,
#   305.99,
#   296.38,
#   291.04,
#   286.36,
#   294.1,
#   297.21,
#   300.2,
#   282.57,
#   299.42],
#  'Humidity': [62,
#   70,
#   78,
#   43,
#   54,
#   58,
#   27,
#   63,
#   62,
#   91,
#   63,
#   76,
#   59,
#   79,
#   88,
#   61,
#   67,
#   88,
#   80,
#   47,
#   70,
#   49,
#   51,
#   89,
#   64,
#   53,
#   86,
#   52,
#   78,
#   78,
#   87,
#   75,
#   22,
#   93,
#   67,
#   79,
#   93,
#   52,
#   69,
#   73,
#   73,
#   25,
#   52,
#   62,
#   53,
#   28,
#   70,
#   85,
#   75,
#   54,
#   75,
#   40,
#   87,
#   75,
#   76,
#   92,
#   80,
#   92,
#   32,
#   13,
#   72,
#   85,
#   67,
#   76,
#   69,
#   73,
#   62,
#   72,
#   73,
#   84,
#   80,
#   80,
#   54,
#   83,
#   8,
#   73,
#   41,
#   86,
#   71,
#   50,
#   97,
#   45,
#   67,
#   89,
#   84,
#   89,
#   52,
#   75,
#   78,
#   47,
#   83,
#   59,
#   90,
#   89,
#   46,
#   79,
#   54,
#   77,
#   80,
#   96,
#   84,
#   78,
#   86,
#   83,
#   78,
#   69,
#   59,
#   77,
#   83,
#   68,
#   80,
#   23,
#   73,
#   55,
#   84,
#   92,
#   98,
#   97,
#   77,
#   73,
#   80,
#   91,
#   75,
#   56,
#   32,
#   60,
#   72,
#   14,
#   70,
#   64,
#   76,
#   14,
#   78,
#   84,
#   61,
#   100,
#   21,
#   86,
#   96,
#   16,
#   69,
#   92,
#   77,
#   72,
#   32,
#   55,
#   71,
#   62,
#   77,
#   53,
#   71,
#   89,
#   81,
#   76,
#   88,
#   96,
#   88,
#   62,
#   98,
#   41,
#   18,
#   99,
#   87,
#   91,
#   53,
#   71,
#   93,
#   23,
#   80,
#   93,
#   93,
#   79,
#   94,
#   82,
#   55,
#   73,
#   82,
#   79,
#   93,
#   38,
#   43,
#   91,
#   63,
#   43,
#   29,
#   97,
#   77,
#   35,
#   68,
#   38,
#   27,
#   94,
#   81,
#   45,
#   77,
#   85,
#   80,
#   45,
#   92,
#   96,
#   99,
#   100,
#   77,
#   84,
#   66,
#   19,
#   24,
#   94,
#   87,
#   16,
#   66,
#   48,
#   85,
#   76,
#   91,
#   98,
#   86,
#   74,
#   58,
#   87,
#   93,
#   56,
#   75,
#   24,
#   78,
#   52,
#   25,
#   89,
#   98,
#   87,
#   39,
#   87,
#   90,
#   68,
#   86,
#   91,
#   21,
#   84,
#   29,
#   94,
#   87,
#   65,
#   93,
#   97,
#   76,
#   35,
#   80,
#   89,
#   68,
#   93,
#   39,
#   60,
#   16,
#   68,
#   92,
#   93,
#   67,
#   83,
#   84,
#   94,
#   73,
#   36,
#   32,
#   62,
#   79,
#   90,
#   96,
#   95,
#   54,
#   84,
#   76,
#   76,
#   81,
#   17,
#   95,
#   84,
#   77,
#   77,
#   82,
#   47,
#   70,
#   84,
#   81,
#   91,
#   82,
#   76,
#   67,
#   25,
#   70,
#   89,
#   68,
#   28,
#   78,
#   73,
#   77,
#   65,
#   69,
#   74,
#   62,
#   91,
#   43,
#   96,
#   39,
#   94,
#   82,
#   71,
#   44,
#   83,
#   83,
#   84,
#   75,
#   67,
#   73,
#   74,
#   92,
#   76,
#   93,
#   80,
#   45,
#   71,
#   92,
#   74,
#   11,
#   76,
#   83,
#   29,
#   66,
#   70,
#   68,
#   91,
#   70,
#   78,
#   59,
#   77,
#   81,
#   71,
#   71,
#   79,
#   100,
#   80,
#   87,
#   16,
#   63,
#   13,
#   76,
#   60,
#   84,
#   71,
#   74,
#   53,
#   87,
#   68,
#   69,
#   87,
#   75,
#   89,
#   68,
#   78,
#   55,
#   75,
#   93,
#   93,
#   58,
#   65,
#   88,
#   68,
#   94,
#   68,
#   92,
#   86,
#   37,
#   77,
#   95,
#   72,
#   65,
#   94,
#   87,
#   79,
#   80,
#   67,
#   90,
#   24,
#   71,
#   98,
#   92,
#   51,
#   29,
#   75,
#   93,
#   82,
#   94,
#   82,
#   78,
#   53,
#   63,
#   78,
#   88,
#   93,
#   90,
#   76,
#   62,
#   80,
#   87,
#   78,
#   58,
#   87,
#   77,
#   91,
#   46,
#   92,
#   76,
#   30,
#   64,
#   95,
#   42,
#   86,
#   93,
#   79,
#   67,
#   86,
#   93,
#   100,
#   54,
#   88,
#   67,
#   88,
#   79,
#   48,
#   28,
#   86,
#   24,
#   28,
#   93,
#   92,
#   54,
#   88,
#   13,
#   70,
#   44,
#   63,
#   25,
#   65,
#   36,
#   89,
#   74,
#   41,
#   83,
#   72,
#   36,
#   65,
#   73,
#   78,
#   70,
#   14,
#   42,
#   87,
#   64,
#   84,
#   79,
#   63,
#   58,
#   83,
#   51,
#   86,
#   73,
#   64,
#   96,
#   34,
#   88,
#   86,
#   95,
#   80,
#   93,
#   100,
#   87,
#   98,
#   39,
#   87,
#   92,
#   39,
#   15,
#   77,
#   39,
#   51,
#   66,
#   92,
#   80,
#   95,
#   87,
#   90,
#   63,
#   48,
#   69,
#   87,
#   83,
#   24,
#   61,
#   45,
#   62,
#   70,
#   95,
#   49,
#   79,
#   72,
#   77,
#   73,
#   65,
#   83,
#   71,
#   72,
#   67,
#   15,
#   74,
#   79,
#   54,
#   13,
#   82,
#   61,
#   94,
#   95,
#   41,
#   97,
#   37,
#   63,
#   93,
#   85,
#   63,
#   50,
#   33,
#   90,
#   51,
#   81,
#   81,
#   84,
#   81,
#   99,
#   44,
#   74,
#   92,
#   48,
#   56,
#   15,
#   94,
#   63,
#   54,
#   60,
#   58,
#   69,
#   20,
#   80,
#   73,
#   17,
#   90,
#   83,
#   78,
#   96,
#   36,
#   88,
#   81,
#   69,
#   83,
#   90,
#   99,
#   9,
#   98,
#   64,
#   41,
#   94,
#   47,
#   73,
#   74,
#   90,
#   93,
#   81,
#   100,
#   69,
#   89,
#   98,
#   84],
#  'Cloudiness': [16,
#   75,
#   75,
#   4,
#   34,
#   4,
#   20,
#   100,
#   0,
#   98,
#   81,
#   88,
#   1,
#   90,
#   8,
#   54,
#   53,
#   90,
#   100,
#   62,
#   44,
#   38,
#   100,
#   8,
#   100,
#   20,
#   18,
#   1,
#   71,
#   0,
#   100,
#   0,
#   1,
#   90,
#   0,
#   26,
#   100,
#   1,
#   23,
#   10,
#   100,
#   64,
#   79,
#   1,
#   0,
#   40,
#   0,
#   100,
#   99,
#   1,
#   98,
#   13,
#   14,
#   8,
#   100,
#   100,
#   98,
#   100,
#   100,
#   24,
#   21,
#   48,
#   99,
#   100,
#   75,
#   97,
#   100,
#   71,
#   90,
#   98,
#   20,
#   18,
#   1,
#   57,
#   1,
#   1,
#   0,
#   34,
#   100,
#   1,
#   18,
#   73,
#   78,
#   100,
#   52,
#   100,
#   29,
#   99,
#   3,
#   42,
#   5,
#   88,
#   90,
#   100,
#   11,
#   20,
#   46,
#   11,
#   42,
#   100,
#   16,
#   97,
#   100,
#   90,
#   10,
#   20,
#   0,
#   16,
#   68,
#   40,
#   75,
#   43,
#   66,
#   36,
#   98,
#   40,
#   60,
#   100,
#   2,
#   90,
#   0,
#   100,
#   74,
#   92,
#   40,
#   0,
#   0,
#   0,
#   22,
#   77,
#   100,
#   14,
#   56,
#   100,
#   15,
#   81,
#   1,
#   100,
#   100,
#   0,
#   12,
#   17,
#   86,
#   99,
#   57,
#   0,
#   100,
#   4,
#   100,
#   65,
#   33,
#   100,
#   20,
#   98,
#   100,
#   0,
#   69,
#   25,
#   100,
#   1,
#   24,
#   100,
#   36,
#   43,
#   88,
#   31,
#   90,
#   66,
#   90,
#   99,
#   90,
#   40,
#   100,
#   98,
#   90,
#   1,
#   0,
#   85,
#   0,
#   9,
#   91,
#   40,
#   91,
#   0,
#   64,
#   100,
#   22,
#   1,
#   90,
#   21,
#   100,
#   94,
#   15,
#   2,
#   60,
#   81,
#   55,
#   100,
#   90,
#   100,
#   66,
#   100,
#   1,
#   98,
#   70,
#   60,
#   0,
#   40,
#   90,
#   9,
#   40,
#   0,
#   77,
#   99,
#   99,
#   100,
#   22,
#   40,
#   28,
#   0,
#   19,
#   22,
#   95,
#   15,
#   5,
#   0,
#   100,
#   100,
#   98,
#   7,
#   0,
#   100,
#   23,
#   34,
#   3,
#   100,
#   1,
#   100,
#   48,
#   85,
#   88,
#   0,
#   100,
#   88,
#   2,
#   75,
#   88,
#   100,
#   75,
#   100,
#   15,
#   6,
#   0,
#   17,
#   59,
#   95,
#   4,
#   96,
#   30,
#   77,
#   85,
#   93,
#   100,
#   92,
#   100,
#   90,
#   54,
#   100,
#   94,
#   72,
#   100,
#   53,
#   12,
#   100,
#   99,
#   98,
#   5,
#   15,
#   84,
#   18,
#   70,
#   100,
#   100,
#   100,
#   0,
#   85,
#   100,
#   99,
#   49,
#   22,
#   100,
#   100,
#   75,
#   2,
#   100,
#   8,
#   1,
#   100,
#   0,
#   88,
#   14,
#   67,
#   100,
#   40,
#   100,
#   75,
#   99,
#   34,
#   48,
#   100,
#   62,
#   50,
#   73,
#   96,
#   69,
#   100,
#   0,
#   62,
#   0,
#   100,
#   100,
#   10,
#   0,
#   100,
#   100,
#   100,
#   20,
#   88,
#   75,
#   100,
#   99,
#   34,
#   0,
#   56,
#   99,
#   64,
#   20,
#   94,
#   100,
#   75,
#   100,
#   97,
#   4,
#   5,
#   3,
#   75,
#   75,
#   98,
#   0,
#   97,
#   53,
#   1,
#   89,
#   98,
#   8,
#   42,
#   98,
#   50,
#   0,
#   100,
#   5,
#   51,
#   100,
#   95,
#   91,
#   97,
#   0,
#   94,
#   100,
#   0,
#   74,
#   3,
#   87,
#   57,
#   9,
#   56,
#   3,
#   10,
#   100,
#   60,
#   90,
#   47,
#   1,
#   100,
#   100,
#   27,
#   0,
#   95,
#   100,
#   1,
#   100,
#   85,
#   92,
#   79,
#   1,
#   86,
#   23,
#   100,
#   57,
#   9,
#   75,
#   1,
#   100,
#   99,
#   61,
#   100,
#   97,
#   100,
#   2,
#   5,
#   69,
#   11,
#   92,
#   100,
#   85,
#   100,
#   100,
#   100,
#   100,
#   93,
#   2,
#   75,
#   27,
#   90,
#   40,
#   93,
#   75,
#   19,
#   0,
#   100,
#   9,
#   97,
#   90,
#   95,
#   33,
#   90,
#   18,
#   38,
#   49,
#   98,
#   100,
#   92,
#   58,
#   72,
#   1,
#   0,
#   90,
#   100,
#   21,
#   44,
#   100,
#   40,
#   44,
#   95,
#   99,
#   90,
#   81,
#   100,
#   90,
#   100,
#   7,
#   0,
#   61,
#   71,
#   100,
#   91,
#   93,
#   5,
#   100,
#   35,
#   100,
#   67,
#   20,
#   99,
#   4,
#   40,
#   100,
#   62,
#   15,
#   14,
#   54,
#   26,
#   93,
#   19,
#   79,
#   100,
#   81,
#   100,
#   24,
#   100,
#   100,
#   40,
#   0,
#   59,
#   0,
#   0,
#   73,
#   5,
#   1,
#   99,
#   8,
#   94,
#   100,
#   90,
#   21,
#   2,
#   1,
#   100,
#   34,
#   82,
#   75,
#   4,
#   100,
#   94,
#   15,
#   63,
#   0,
#   99,
#   20,
#   40,
#   0,
#   4,
#   66,
#   0,
#   20,
#   100,
#   54,
#   26,
#   21,
#   100,
#   51,
#   0,
#   100,
#   100,
#   71,
#   100,
#   100,
#   68,
#   100,
#   0,
#   1,
#   99,
#   75,
#   100,
#   100,
#   80,
#   100,
#   88,
#   34,
#   100,
#   20,
#   21,
#   70,
#   97,
#   100,
#   82,
#   96,
#   100,
#   8,
#   66,
#   89,
#   100,
#   100,
#   0,
#   100,
#   0,
#   79,
#   45,
#   6,
#   30,
#   100,
#   100,
#   100,
#   97,
#   1,
#   26,
#   40,
#   100,
#   94],
#  'Wind Speed': [2.16,
#   2.24,
#   3.6,
#   4.94,
#   4.81,
#   2.52,
#   2.86,
#   3.94,
#   3.64,
#   2.57,
#   1.44,
#   1.6,
#   1.76,
#   4.51,
#   2.68,
#   7.96,
#   1.36,
#   2.57,
#   0.99,
#   0.45,
#   1.61,
#   1.56,
#   1.63,
#   6.96,
#   6.35,
#   1.34,
#   2.17,
#   0,
#   5.19,
#   2.57,
#   4.53,
#   5,
#   5.14,
#   0,
#   1.62,
#   5.67,
#   1.79,
#   1.09,
#   3.94,
#   2.36,
#   6.24,
#   1.5,
#   0.89,
#   0,
#   5.14,
#   8.89,
#   1.65,
#   7.1,
#   3.52,
#   1.35,
#   2.51,
#   1.57,
#   3.71,
#   1.64,
#   1.72,
#   2.8,
#   8.8,
#   2.19,
#   6.22,
#   2.75,
#   2.14,
#   3.45,
#   1.29,
#   4.31,
#   3.09,
#   5.74,
#   4.71,
#   4.13,
#   5.14,
#   3.26,
#   2.33,
#   5.38,
#   0.89,
#   8.29,
#   3.58,
#   0.55,
#   5.72,
#   1.79,
#   2.26,
#   1.24,
#   3.98,
#   1.77,
#   4.65,
#   2.61,
#   2.9,
#   4.48,
#   0.97,
#   10.73,
#   4.86,
#   3.94,
#   2.81,
#   2.06,
#   1.79,
#   1.75,
#   0.45,
#   6.38,
#   1.79,
#   6.08,
#   3.39,
#   3.71,
#   0.69,
#   8.88,
#   7.32,
#   1.34,
#   4.07,
#   7.72,
#   0.74,
#   7.75,
#   2.33,
#   6.41,
#   3.6,
#   4.57,
#   10.58,
#   2.49,
#   0.53,
#   2.1,
#   1.62,
#   8.95,
#   6.36,
#   10.67,
#   8.14,
#   2.89,
#   6.38,
#   2.03,
#   5.13,
#   8.91,
#   5.49,
#   2.83,
#   2.54,
#   5.6,
#   8.2,
#   3.4,
#   1.9,
#   0.95,
#   4.04,
#   1.03,
#   7.2,
#   1.42,
#   7.33,
#   5.14,
#   2.65,
#   1.75,
#   2.96,
#   1.3,
#   2.38,
#   3.51,
#   1.34,
#   3.09,
#   4.64,
#   2.08,
#   2.55,
#   6.78,
#   2.61,
#   0.47,
#   1.57,
#   1.06,
#   1.13,
#   3.64,
#   0.42,
#   3.13,
#   7.9,
#   0.61,
#   10.68,
#   1.77,
#   2.91,
#   2.7,
#   3.6,
#   3.89,
#   5.14,
#   2.98,
#   9.77,
#   1.54,
#   3.79,
#   0.45,
#   1.17,
#   3.58,
#   1.88,
#   4.19,
#   0.8,
#   2.01,
#   2.79,
#   0.96,
#   4.81,
#   5,
#   3.32,
#   3.81,
#   1.64,
#   4.12,
#   5.14,
#   5.92,
#   2.61,
#   2.42,
#   6.97,
#   3.61,
#   1.39,
#   1.45,
#   5.32,
#   1.24,
#   2.97,
#   3.57,
#   1.42,
#   3.09,
#   1.54,
#   3,
#   0.33,
#   3.18,
#   2.02,
#   2.57,
#   12.35,
#   1.28,
#   1.54,
#   5.08,
#   3.47,
#   2.88,
#   2.24,
#   3.62,
#   2.23,
#   0.94,
#   4.76,
#   1.24,
#   1.03,
#   4.31,
#   1.36,
#   1.35,
#   3.36,
#   4.75,
#   1.35,
#   3.21,
#   0.91,
#   4.04,
#   1.54,
#   4.59,
#   1.49,
#   5.66,
#   0.9,
#   4.79,
#   6.78,
#   1.79,
#   5.66,
#   1.53,
#   1.39,
#   3.37,
#   3.75,
#   0.52,
#   2.83,
#   0,
#   4.27,
#   7.78,
#   2.06,
#   1.69,
#   1.29,
#   1.84,
#   1.22,
#   2.73,
#   3.36,
#   2.72,
#   2.58,
#   2.24,
#   0.9,
#   0.6,
#   2.37,
#   1.93,
#   0.67,
#   4.47,
#   4.04,
#   5.45,
#   1.72,
#   4.52,
#   5.95,
#   4.3,
#   7.63,
#   6.9,
#   1.18,
#   5,
#   0.72,
#   3.07,
#   2.65,
#   4.47,
#   0.6,
#   5.29,
#   4.98,
#   5.69,
#   1.02,
#   9.08,
#   0.45,
#   7.34,
#   3.58,
#   4.41,
#   2.57,
#   7.81,
#   2.3,
#   3.19,
#   9.77,
#   4.02,
#   3.46,
#   1.03,
#   12.35,
#   3.49,
#   5.63,
#   1.86,
#   0.47,
#   3.22,
#   0.84,
#   1.34,
#   4.98,
#   3.13,
#   0.45,
#   1.83,
#   3.43,
#   1.97,
#   6.78,
#   2.89,
#   10.75,
#   7.9,
#   2.97,
#   10.05,
#   3.6,
#   1.54,
#   3.83,
#   0.41,
#   2.19,
#   1.48,
#   4.61,
#   7.38,
#   3.22,
#   2.58,
#   11.32,
#   1.5,
#   4.02,
#   2.84,
#   2.14,
#   5.92,
#   7.37,
#   2.44,
#   3.61,
#   1.32,
#   6.69,
#   6.69,
#   0.98,
#   2.57,
#   7.65,
#   5.43,
#   2.43,
#   5.04,
#   0.27,
#   0.89,
#   7.2,
#   5.9,
#   1.98,
#   7.75,
#   3.79,
#   2.68,
#   2.87,
#   2.92,
#   3.58,
#   4.44,
#   5.69,
#   2.95,
#   3.75,
#   0.45,
#   1.47,
#   2.33,
#   2.61,
#   2.21,
#   3.9,
#   2.69,
#   1.07,
#   2.68,
#   9.94,
#   0.77,
#   0.9,
#   1.69,
#   2.89,
#   4.5,
#   0.67,
#   0.89,
#   4.25,
#   2.42,
#   4.44,
#   1.81,
#   4.09,
#   1.66,
#   0.45,
#   3.11,
#   2.12,
#   2.78,
#   0.98,
#   6.29,
#   0.38,
#   2.06,
#   3.1,
#   1.14,
#   2.46,
#   2.57,
#   4.39,
#   1.88,
#   4.22,
#   1.38,
#   8.2,
#   4.12,
#   0.89,
#   1.51,
#   1.82,
#   1.44,
#   2.66,
#   5.21,
#   2.85,
#   1.61,
#   1.29,
#   0.52,
#   2.59,
#   1.32,
#   2.62,
#   7.73,
#   2.83,
#   3.38,
#   3.31,
#   2.2,
#   1.29,
#   0.98,
#   2.21,
#   1.03,
#   0.72,
#   6.73,
#   4.62,
#   3.26,
#   2.08,
#   3.7,
#   4.92,
#   1.81,
#   1.37,
#   2.57,
#   1.54,
#   2.47,
#   6.58,
#   3.77,
#   2.84,
#   1.02,
#   6.87,
#   1.07,
#   3.48,
#   6.96,
#   3.38,
#   2.9,
#   4.87,
#   5.12,
#   5.5,
#   1.46,
#   2.78,
#   0.44,
#   3.19,
#   5.14,
#   1.3,
#   2.6,
#   2.88,
#   8.09,
#   6.32,
#   2.34,
#   1.07,
#   1.42,
#   5.91,
#   1.05,
#   2.27,
#   0.99,
#   4.5,
#   5.09,
#   1.22,
#   1.91,
#   5.98,
#   3.51,
#   10.32,
#   1.34,
#   2.06,
#   3.67,
#   2.36,
#   2.24,
#   2.5,
#   5.86,
#   1.78,
#   5.79,
#   2.74,
#   8.2,
#   3.12,
#   2.59,
#   1.44,
#   0.55,
#   3.59,
#   2.35,
#   2.61,
#   3.65,
#   3.9,
#   4.43,
#   7.32,
#   0.8,
#   0,
#   3.36,
#   0.45,
#   8.52,
#   2.91,
#   2.93,
#   1.29,
#   3.85,
#   1.56,
#   0.45,
#   0.7,
#   0.39,
#   0.45,
#   2.24,
#   0.96,
#   7.43,
#   8.01,
#   0.48,
#   6.33,
#   9.26,
#   6.84,
#   3.91,
#   2.57,
#   1.41,
#   6.71,
#   3.58,
#   6.28,
#   1.59,
#   3.03,
#   5.66,
#   6.17,
#   2.28,
#   2.95,
#   2.98,
#   0.87,
#   6.45,
#   1.08,
#   3.84,
#   8.2,
#   3.26,
#   10.59,
#   0.46,
#   3.84,
#   6.2,
#   3.15,
#   2.06,
#   7.36,
#   9.14,
#   3.71,
#   3.03,
#   4.15,
#   4.66,
#   1.68,
#   1.37,
#   7.41,
#   7.35,
#   1.03,
#   3.54,
#   1.62,
#   3.38,
#   3.75,
#   2.09,
#   3.64,
#   1.08,
#   6.82,
#   5.32,
#   0.71,
#   1.41,
#   0.53,
#   0.72,
#   0.72,
#   0.78,
#   0.81,
#   3.02,
#   2.9,
#   1.9,
#   4.74,
#   3.65,
#   1,
#   2.23,
#   4.63,
#   0.92,
#   1.54,
#   1.82,
#   2.21]}

# %%
weather_df = pd.DataFrame(weather_dict)
weather_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed
# 0    Busselton -33.6500  115.3333    290.83        62          16        2.16
# 1        Kapaa  22.0752 -159.3190    299.33        70          75        2.24
# 2        Vaini -21.2000 -175.2000    300.24        78          75        3.60
# 3      Bakchar  57.0186   82.0711    277.25        43           4        4.94
# 4  New Norfolk -42.7826  147.0587    286.88        54          34        4.81

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(city_data_df['Lat'], city_data_df['Max Temp'])
plt.title(f'City Latitude vs. Max Temperature {date.today()}')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.grid(True)
plt.savefig('Max_temp.png', bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-61085cbaa5f8> in <module>
#       1 plt.scatter(city_data_df['Lat'], city_data_df['Max Temp'])
# ----> 2 plt.title(f'City Latitude vs. Max Temperature {date.today()}')
#       3 plt.xlabel('Latitude')
#       4 plt.ylabel('Max Temperature (F)')
#       5 plt.grid(True)
#
# AttributeError: 'list' object has no attribute 'today'

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(weather_df['Lat'], weather_df['Humidity'], edgecolor="blue", linewidths=1, marker="0",
           alpha=0.8, label="Cities")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("City Latitude vs. Humidity (05/19/2021)")
plt.savefig("Humidity.png")

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
